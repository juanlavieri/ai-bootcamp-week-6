# %%
# Initial imports
import requests
from dotenv import load_dotenv
import os
import json
import urllib.parse

# %% [markdown]
# ### Use the `load_dotenv()` method from the `dotenv` package to load and export the environment variables

# %%
load_dotenv()
# Out:
# True

# %% [markdown]
# ### Use the `os.getenv` function to retrieve the environment variable named `TMDB_API_KEY`. Store as a Python variable named `api_key`

# %%
api_key = os.getenv('TMDB_API_KEY')

# %% [markdown]
# ### Use the `type` function to confirm the retrieval of the API key.

# %%
print(type(api_key))
# Out:
# <class 'str'>

# %% [markdown]
# ### Concatenate `request_url` with the `api_key` variable

# %%
# Search The Movie Database for a movie title
# Documentation: https://developer.themoviedb.org/docs/search-and-query-for-details
movie_title = 'Inception' 
request_url = f"https://api.themoviedb.org/3/search/movie?api_key={api_key}&query={movie_title}"

# Save a movie title to search for as a variable
encoded_title = urllib.parse.quote(movie_title)


# Concatenate request_url, title, and api_key. Store as new variable
request_url = f"https://api.themoviedb.org/3/search/movie?api_key={api_key}&query={encoded_title}"

# %% [markdown]
# ### Execute GET request with API key

# %%
# Execute get request
response = requests.get(request_url)
movie_data = response.json()

# Optional: Print the response to see the structure and data
print(movie_data)
# Out:
# {'page': 1, 'results': [{'adult': False, 'backdrop_path': '/8ZTVqvKDQ8emSGUEMjsS4yHAwrp.jpg', 'genre_ids': [28, 878, 12], 'id': 27205, 'original_language': 'en', 'original_title': 'Inception', 'overview': 'Cobb, a skilled thief who commits corporate espionage by infiltrating the subconscious of his targets is offered a chance to regain his old life as payment for a task considered to be impossible: "inception", the implantation of another person\'s idea into a target\'s subconscious.', 'popularity': 137.535, 'poster_path': '/oYuLEt3zVCKq57qu2F8dT7NIa6f.jpg', 'release_date': '2010-07-15', 'title': 'Inception', 'video': False, 'vote_average': 8.4, 'vote_count': 34791}, {'adult': False, 'backdrop_path': '/JeGkRdNsOuMrgwBdtB0hp763MU.jpg', 'genre_ids': [18, 53], 'id': 613092, 'original_language': 'es', 'original_title': 'El crack cero', 'overview': 'Madrid, Spain, 1975; shortly after the end of the Franco dictatorship. Six months after the mysterious death of his lover, a prestigious tailor, a married woman visits the office of the young Germán Areta, a former police officer turned private detective, to request his professional services.', 'popularity': 4.69, 'poster_path': '/kzgPu2CMxBr4YZZxC1Off4cUfR9.jpg', 'release_date': '2019-10-04', 'title': 'The Crack: Inception', 'video': False, 'vote_average': 6.7, 'vote_count': 36}, {'adult': False, 'backdrop_path': None, 'genre_ids': [16, 28, 53, 878], 'id': 64956, 'original_language': 'en', 'original_title': 'Inception: The Cobol Job', 'overview': 'This "Inception" prequel unfolds courtesy of a beautiful Motion Comic, and explains how Cobb, Arthur and Nash were enlisted by Cobol Engineering.', 'popularity': 9.68, 'poster_path': '/sNxqwtyHMNQwKWoFYDqcYTui5Ok.jpg', 'release_date': '2010-12-07', 'title': 'Inception: The Cobol Job', 'video': False, 'vote_average': 7.3, 'vote_count': 290}, {'adult': False, 'backdrop_path': None, 'genre_ids': [], 'id': 350632, 'original_language': 'en', 'original_title': 'Nātyārambham', 'overview': 'On certain Adavus: the basic steps in Bharatanatyam. The first part covers Tatta Adavu, Natta Adavu, Visharu Adavu , Tatti Metti Adavu and Teermanam Adavu.', 'popularity': 0.6, 'poster_path': None, 'release_date': '', 'title': 'The Inception of Dramatic Representation', 'video': True, 'vote_average': 5.8, 'vote_count': 3}, {'adult': False, 'backdrop_path': None, 'genre_ids': [35], 'id': 542438, 'original_language': 'en', 'original_title': 'Bikini Inception', 'overview': "Two flunky Janitors in an Arctic Lab perform unauthorized experiments transporting them to a beach dream world in Malibu California w/50 beautiful young girls and a female Brazilian PhD Student wearing only a bra and panties. A '67 Muscle car races chases horses guns fights surfing, sumo wrestler, wolf monster, underwater scenes tons of gorgeous models. Sexy sci-fi fun.", 'popularity': 1.486, 'poster_path': '/mNASlEOFX2c9upxaSbgeKFvIr1L.jpg', 'release_date': '2015-05-19', 'title': 'Bikini Inception', 'video': False, 'vote_average': 7.0, 'vote_count': 1}, {'adult': False, 'backdrop_path': None, 'genre_ids': [10402], 'id': 973484, 'original_language': 'en', 'original_title': 'Inception: Music from the Motion Picture', 'overview': 'The Special Features Blu-ray disc contains a lossless DTS-HD MA 5.1 surround mix of the Inception soundtrack.', 'popularity': 0.947, 'poster_path': '/7uM4DyRVAcgagvhZoWrkrqMPbqV.jpg', 'release_date': '2010-12-07', 'title': 'Inception: Music from the Motion Picture', 'video': True, 'vote_average': 6.0, 'vote_count': 1}, {'adult': False, 'backdrop_path': None, 'genre_ids': [], 'id': 250845, 'original_language': 'en', 'original_title': 'WWA The Inception', 'overview': 'The first World Wrestling Allstars pay per view, live from Sydney, Australia! A tournament titled "7 Deadly Sins", each round having a stipulation match, the winner will be crowned the first ever WWA Heavyweight Champion! Wrestlers such as Jeff Jarrett, Road Dogg, Jerry Lawler all compete in the tournament, wit ...

# %% [markdown]
# ### Display JSON to screen using `json.dumps()`

# %%
# Print the JSON results
print(json.dumps(movie_data, indent=4, sort_keys=True))
# Out:
# {
#     "page": 1,
#     "results": [
#         {
#             "adult": false,
#             "backdrop_path": "/8ZTVqvKDQ8emSGUEMjsS4yHAwrp.jpg",
#             "genre_ids": [
#                 28,
#                 878,
#                 12
#             ],
#             "id": 27205,
#             "original_language": "en",
#             "original_title": "Inception",
#             "overview": "Cobb, a skilled thief who commits corporate espionage by infiltrating the subconscious of his targets is offered a chance to regain his old life as payment for a task considered to be impossible: \"inception\", the implantation of another person's idea into a target's subconscious.",
#             "popularity": 137.535,
#             "poster_path": "/oYuLEt3zVCKq57qu2F8dT7NIa6f.jpg",
#             "release_date": "2010-07-15",
#             "title": "Inception",
#             "video": false,
#             "vote_average": 8.4,
#             "vote_count": 34791
#         },
#         {
#             "adult": false,
#             "backdrop_path": "/JeGkRdNsOuMrgwBdtB0hp763MU.jpg",
#             "genre_ids": [
#                 18,
#                 53
#             ],
#             "id": 613092,
#             "original_language": "es",
#             "original_title": "El crack cero",
#             "overview": "Madrid, Spain, 1975; shortly after the end of the Franco dictatorship. Six months after the mysterious death of his lover, a prestigious tailor, a married woman visits the office of the young Germ\u00e1n Areta, a former police officer turned private detective, to request his professional services.",
#             "popularity": 4.69,
#             "poster_path": "/kzgPu2CMxBr4YZZxC1Off4cUfR9.jpg",
#             "release_date": "2019-10-04",
#             "title": "The Crack: Inception",
#             "video": false,
#             "vote_average": 6.7,
#             "vote_count": 36
#         },
#         {
#             "adult": false,
#             "backdrop_path": null,
#             "genre_ids": [
#                 16,
#                 28,
#                 53,
#                 878
#             ],
#             "id": 64956,
#             "original_language": "en",
#             "original_title": "Inception: The Cobol Job",
#             "overview": "This \"Inception\" prequel unfolds courtesy of a beautiful Motion Comic, and explains how Cobb, Arthur and Nash were enlisted by Cobol Engineering.",
#             "popularity": 9.68,
#             "poster_path": "/sNxqwtyHMNQwKWoFYDqcYTui5Ok.jpg",
#             "release_date": "2010-12-07",
#             "title": "Inception: The Cobol Job",
#             "video": false,
#             "vote_average": 7.3,
#             "vote_count": 290
#         },
#         {
#             "adult": false,
#             "backdrop_path": null,
#             "genre_ids": [],
#             "id": 350632,
#             "original_language": "en",
#             "original_title": "N\u0101ty\u0101rambham",
#             "overview": "On certain Adavus: the basic steps in Bharatanatyam. The first part covers Tatta Adavu, Natta Adavu, Visharu Adavu , Tatti Metti Adavu and Teermanam Adavu.",
#             "popularity": 0.6,
#             "poster_path": null,
#             "release_date": "",
#             "title": "The Inception of Dramatic Representation",
#             "video": true,
#             "vote_average": 5.8,
#             "vote_count": 3
#         },
#         {
#             "adult": false,
#             "backdrop_path": null,
#             "genre_ids": [
#                 35
#             ],
#             "id": 542438,
#             "original_language": "en",
#             "original_title": "Bikini Inception",
#             "overview": "Two flunky Janitors in an Arctic Lab perform unauthorized experiments transporting them to a beach dream world in Malibu California w/50 beautiful young girls and a female Brazilian PhD Student wearing only a bra and panties. A '67 Muscle car races chases horses guns fights surfing, sumo wrestler, wolf monster, underwater scenes tons of gorgeous models. Sexy sci-fi fun.",
#             "popularity": 1.486,
#             "poster_path": "/mNASlEOFX2c9upxaSbgeKFvIr1L.jpg",
#             "release_date": "2015-05-19",
#             "title": "Bikini Inception",
#             "video": false,
#             "vote_average": 7.0,
#             "vote_count": 1
#         },
#         {
#             "adult": false,
#             "backdrop_path": null,
#             "genre_ids": [
#                 10402
#             ],
#             "id": 973484,
#             "original_language": "en",
#             "original_title": "Inception: Music from the Motion Picture",
#             "overview": "The Special Features Blu-ray disc contains a lossless DTS-HD MA 5.1 surround mix of the Inception soundtrack.",
#             "popularity": 0.947,
#             "poster_path": "/7uM4DyRVAcgagvhZoWrkrqMPbqV.jpg",
#             "release_date": "2010-12-07",
#             "title": "Inception: Music from the Motion Picture",
#             "video": true,
#             "vote_average": 6.0,
#             "vote_count": 1
#         },
#         {
#             "adult": false,
#             "backdrop_path": null,
#             "genre_ids": [],
#             "id": 250845,
#             "original_language": "en",
#             "original_title": "WWA The Inception",
#             "overview": "The first World Wrestling Allstars pay per view, live from Sydney, Australia! A tournament titled \"7 Deadly Sins\", each round having a stipulation match, the winner will be crowned the first ever WWA Heavyweight Champion! Wrestlers such as Jeff Jarrett, Road Dogg, Jerry Lawler all compete in the tournament, with the WWA Commissioner, Bret Hart not too far away to make sure nothing gets to far out of hand!",
#             "popularity": 0.933,
#             "poster_path": null,
#             "release_date": "2001-10-26",
#             "title": "WWA The Inception",
#             "video": true,
#             "vote_average": 3.1,
#             "vote_count": 5
#         }
#     ],
#     "total_pages": 1,
#     "total_results": 7
# }

# %% [markdown]
# ### Bonus: Retrieve Movie Credits Data

# %%
# Create a function that retrieves a movie's credits
def get_movie_credits(movie_id, api_key):
    """
    Retrieves the credits for a given movie from The Movie Database.

    Args:
    movie_id (str): The ID of the movie.
    api_key (str): Your TMDB API key.

    Returns:
    dict: The credits of the movie.
    """
    # Prepare the API URL
    credits_url = f"https://api.themoviedb.org/3/movie/{movie_id}/credits?api_key={api_key}"

    # Execute GET request
    response = requests.get(credits_url)
    credits_data = response.json()

    # Return the results
    return credits_data

# %%
movie_title = 'Elemental'

# Encode the movie title to be URL-safe
encoded_title = urllib.parse.quote(movie_title)

# Form the search URL
search_url = f"https://api.themoviedb.org/3/search/movie?api_key={api_key}&query={encoded_title}"

# Execute GET request
response = requests.get(search_url)
search_results = response.json()

# Extract the movie ID
# This assumes that the first result is the correct movie
# You might need to adjust this logic based on actual search results
if search_results['results']:
    movie_id = search_results['results'][0]['id']
    print("Movie ID for 'Elemental':", movie_id)
else:
    print("Movie not found")
# Out:
# Movie ID for 'Elemental': 976573

# %%
# Use get_credits function for Elemental movie_id
get_movie_credits(movie_id, api_key)
# Out:
# {'id': 976573,
#  'cast': [{'adult': False,
#    'gender': 1,
#    'id': 1087262,
#    'known_for_department': 'Acting',
#    'name': 'Leah Lewis',
#    'original_name': 'Leah Lewis',
#    'popularity': 14.173,
#    'profile_path': '/liV9OXUeo7T19hhjFlqTELtETnW.jpg',
#    'cast_id': 5,
#    'character': 'Ember Lumen (voice)',
#    'credit_id': '631bd27f65e0a200893de33e',
#    'order': 0},
#   {'adult': False,
#    'gender': 2,
#    'id': 1639848,
#    'known_for_department': 'Acting',
#    'name': 'Mamoudou Athie',
#    'original_name': 'Mamoudou Athie',
#    'popularity': 19.638,
#    'profile_path': '/iPx1s7EuBEmty7MXdKSBpEBsGYT.jpg',
#    'cast_id': 4,
#    'character': 'Wade Ripple (voice)',
#    'credit_id': '631bd276c4f55200917b06c8',
#    'order': 1},
#   {'adult': False,
#    'gender': 2,
#    'id': 1236458,
#    'known_for_department': 'Art',
#    'name': 'Ronnie del Carmen',
#    'original_name': 'Ronnie del Carmen',
#    'popularity': 6.357,
#    'profile_path': '/lPCmkQK76DOgkmcRjg9394QPyAu.jpg',
#    'cast_id': 8,
#    'character': 'Bernie Lumen (voice)',
#    'credit_id': '6422e2c208cf8700fd8803ad',
#    'order': 2},
#   {'adult': False,
#    'gender': 1,
#    'id': 2073564,
#    'known_for_department': 'Acting',
#    'name': 'Shila Ommi',
#    'original_name': 'Shila Ommi',
#    'popularity': 3.455,
#    'profile_path': '/i9m2RGrANNxidj0bVKlSs0zHPNX.jpg',
#    'cast_id': 9,
#    'character': 'Cinder Lumen (voice)',
#    'credit_id': '6422e2cc2dc9dc00fd1c88f9',
#    'order': 3},
#   {'adult': False,
#    'gender': 1,
#    'id': 63234,
#    'known_for_department': 'Acting',
#    'name': 'Wendi McLendon-Covey',
#    'original_name': 'Wendi McLendon-Covey',
#    'popularity': 15.697,
#    'profile_path': '/bXDG1QhUwnWa9621rOf1dO3OKoC.jpg',
#    'cast_id': 10,
#    'character': 'Gale (voice)',
#    'credit_id': '6422e2db8d22fc00a9df0a59',
#    'order': 4},
#   {'adult': False,
#    'gender': 1,
#    'id': 11514,
#    'known_for_department': 'Acting',
#    'name': "Catherine O'Hara",
#    'original_name': "Catherine O'Hara",
#    'popularity': 27.057,
#    'profile_path': '/gI2RyymLJ9ZrhEyJSD5EqSvFpCX.jpg',
#    'cast_id': 11,
#    'character': 'Brook Ripple (voice)',
#    'credit_id': '6422e2e78d22fc007c009b88',
#    'order': 5},
#   {'adult': False,
#    'gender': 0,
#    'id': 3983226,
#    'known_for_department': 'Acting',
#    'name': 'Mason Wertheimer',
#    'original_name': 'Mason Wertheimer',
#    'popularity': 2.215,
#    'profile_path': '/rhXmrh7dWkCAj23MhGfI79jcbjN.jpg',
#    'cast_id': 12,
#    'character': 'Clod (voice)',
#    'credit_id': '6422e3062dc9dc007f0e3b33',
#    'order': 6},
#   {'adult': False,
#    'gender': 2,
#    'id': 1217619,
#    'known_for_department': 'Acting',
#    'name': 'Ronobir Lahiri',
#    'original_name': 'Ronobir Lahiri',
#    'popularity': 3.136,
#    'profile_path': '/uZQu5zBGxE62uGP7qaGhjQ79bn3.jpg',
#    'cast_id': 42,
#    'character': 'Harold (voice)',
#    'credit_id': '646e200051e6ab011db530ee',
#    'order': 7},
#   {'adult': False,
#    'gender': 1,
#    'id': 1576334,
#    'known_for_department': 'Acting',
#    'name': 'Wilma Bonet',
#    'original_name': 'Wilma Bonet',
#    'popularity': 3.969,
#    'profile_path': None,
#    'cast_id': 43,
#    'character': 'Flarrietta (voice)',
#    'credit_id': '646e200b51e6ab013ab9f0ae',
#    'order': 8},
#   {'adult': False,
#    'gender': 2,
#    'id': 1663974,
#    'known_for_department': 'Acting',
#    'name': 'Joe Pera',
#    'original_name': 'Joe Pera',
#    'popularity': 1.796,
#    'profile_path': '/lzf1mnclmHo4y53ZpvtlkWgFunZ.jpg',
#    'cast_id': 13,
#    'character': 'Fern (voice)',
#    'credit_id': '6422e31c6a3448007bb6b578',
#    'order': 9},
#   {'adult': False,
#    'gender': 2,
#    'id': 157067,
#    'known_for_department': 'Acting',
#    'name': 'Matthew Yang King',
#    'original_name': 'Matthew Yang King',
#    'popularity': 10.366,
#    'profile_path': '/jcLJIw0s2uP4PSnH5E8oM3pUyiV.jpg',
#    'cast_id': 44,
#    'character': 'Alan / Lutz / Earth Pruner (voice)',
#    'credit_id': '646e201ea5046e01894367ac',
#    'order': 10},
#   {'adult': False,
#    'gender': 1,
#    'id': 4078463,
#    'known_for_department': 'Acting',
#    'name': 'Clara Lin Ding',
#    'original_name': 'Clara Lin Ding',
#    'popularity': 0.75,
#    'profile_path': None,
#    'cast_id': 45,
#    'character': 'Little Kid Ember (voice)',
#    'credit_id': '646e2033d185720120831482',
#    'order': 11},
#   {'adult': False,
#    'gender': 1,
#    'id': 1937823,
#    'known_for_department': 'Acting',
#    'name': 'Reagan To',
#    'original_name': 'Reagan To',
#    'popularity': 0.6,
#    'profile_path': None,
#    'cast_id': 46,
#    'character': 'Big Kid Ember (voice)',
#    'credit_id': '646e20459661fc013a27f748',
#    'order': 12},
#   {'adult': False,
#    'gender': 2,
#    'id': 4078465,
#    'known_for_department': 'Acting',
#    'name': 'Jeff Lapensee',
#    'original_name': 'Jeff Lapensee',
#    'popularity': 0.6,
#    'profile_path': None,
#    'cast_id': 47,
#    'character': 'Sparkler Customer (voice)',
#    'credit_id': '646e205fa5046e01058d8c73',
#    'order': 13},
#   {'adult': False,
#    'gender': 0,
#    'id': 1997753,
#    'known_for_department': 'Editing',
#    'name': 'Ben Morris',
#    'original_name': 'Ben Morris',
#    'popularity': 0.6,
#    'profile_path': None,
#    'cast_id': 48,
#    'character': 'Wood Immigration Official (voice)',
#    'credit_id': '646e2079c3514c2b0a34790f',
#    'order': 14},
#   {'adult': False,
#    'gender': 1,
#    'id': 1211955,
#    'known_for_department': 'Acting',
#    'name': 'Alex Kapp',
#    'original_name': 'Alex Kapp',
#    'popularity': 7.229,
#    'profile_path': '/qpVxC6GgYaTg6iyPWV93u0i4JKK.jpg',
#    'cast_id': 50,
#    'character': 'Customer / Delivery Person / Earth Landlord (voice)',
#    'credit_id': '646e20ab54a0980138664c86',
#    'order': 15},
#   {'adult': False,
#    'gender': 2,
#    'id': 1906860,
#    'known_for_department': 'Acting',
#    'name': 'P.L. Brown',
#    'original_name': 'P.L. Brown',
#    'popularity': 2.841,
#    'profile_path': '/6sH4laBWYn3rPg6BQSe5mDYJBSe.jpg',
#    'cast_id': 51,
#    'character': 'Doorman (voice)',
#    'credit_id': '646e20bad1857200e5a64f16',
#    'order': 16},
#   {'adult': False,
#    'gender': 2,
#    'id': 13477,
#    'known_for_department': 'Acting',
#    'name': 'Jonathan Adams',
#    'original_name': 'Jonathan Adams',
#    'popularity': 9.192,
#    'profile_path': '/mkgyl2MciZ14wsYi6zedyj6hnR8.jpg',
#    'cast_id': 111,
#    'character': 'Flarry (voice)',
#    'credit_id': '64f4248677d23b00cb877cab',
#    'order': 17}],
#  'crew': [{'adult': False,
#    'gender': 2,
#    'id': 153,
#    'known_for_department': 'Sound',
#    'name': 'Thomas Newman',
#    'original_name': 'Thomas Newman',
#    'popularity': 2.136,
#    'profile_path': '/j8rIiOSdBjtDL5vji8m5BtChZou.jpg',
#    'credit_id': '63e2cbf6af85de0081c88304',
#    'department': 'Sound',
#    'job': 'Original Music Composer'},
#   {'adult': False,
#    'gender': 2,
#    'id': 153,
#    'known_for_department': 'Sound',
#    'name': 'Thomas Newman',
#    'original_name': 'Thomas Newman',
#    'popularity': 2.136,
#    'profile_path': '/j8rIiOSdBjtDL5vji8m5BtChZou.jpg',
#    'credit_id': '646e1f4a54a09800e4118be8',
#    'department': 'Sound',
#    'job': 'Conductor'},
#   {'adult': False,
#    'gender': 2,
#    'id': 7763,
#    'known_for_department': 'Sound',
#    'name': 'Ren Klyce',
#    'original_name': 'Ren Klyce',
#    'popularity': 1.62,
#    'profile_path': '/tMDHEVa05pe3od1NMpfplPVPnxD.jpg',
#    'credit_id': '646e1f8451e6ab0157da103d',
#    'department': 'Sound',
#    'job': 'Sound Designer'},
#   {'adult': False,
#    'gender': 2,
#    'id': 7763,
#    'known_for_department': 'Sound',
#    'name': 'Ren Klyce',
#    'original_name': 'Ren Klyce',
#    'popularity': 1.62,
#    'profile_path': '/tMDHEVa05pe3od1NMpfplPVPnxD.jpg',
#    'credit_id': '6497e84a62f33500e912a0df',
#    'department': 'Sound',
#    'job': 'Supervising Sound Editor'},
#   {'adult': False,
#    'gender': 2,
#    'id': 7883,
#    'known_for_department': 'Art',
#    'name': 'Ralph Eggleston',
#    'original_name': 'Ralph Eggleston',
#    'popularity': 4.858,
#    'profile_path': '/28ZxW5tHMuWYK8T3I0xLfVAF9yw.jpg',
#    'credit_id': '64330bfd4539d000777db36e',
#    'department': 'Crew',
#    'job': 'In Memory Of'},
#   {'adult': False,
#    'gender': 0,
#    'id': 7894,
#    'known_for_department': 'Lighting',
#    'name': 'Jean-Claude Kalache',
#    'original_name': 'Jean-Claude Kalache',
#    'popularity': 3.645,
#    'profile_path': None,
#    'credit_id': '64528d4ad8f44e0dadf42523',
#    'department': 'Camera',
#    'job': 'Director of Photography'},
#   {'adult': False,
#    'gender': 0,
#    'id': 8053,
#    'known_for_department': 'Visual Effects',
#    'name': 'Michael Venturini',
#    'original_name': 'Michael Venturini',
#    'popularity': 0.882,
#    'profile_path': None,
#    'credit_id': '6452a147d48cee0136d8c791',
#    'department': 'Visual Effects',
#    'job': 'Animation Supervisor'},
#   {'adult': False,
#    'gender': 1,
#    'id': 8056,
#    'known_for_department': 'Visual Effects',
#    'name': 'Kureha Yokoo',
#    'original_name': 'Kureha Yokoo',
#    'popularity': 2.171,
#    'profile_path': '/iVAzdPsvxhMNM6ISWOBAcLqiHlE.jpg',
#    'credit_id': '6452a15287a27a01723c2c29',
#    'department': 'Visual Effects',
#    'job': 'Animation Supervisor'},
#   {'adult': False,
#    'gender': 2,
#    'id': 12890,
#    'known_for_department': 'Writing',
#    'name': 'Pete Docter',
#    'original_name': 'Pete Docter',
#    'popularity': 9.376,
#    'profile_path': '/xz46mHzo8apkVMxmrkMQvqakOL0.jpg',
#    'credit_id': '628271dff5c82400a5677988',
#    'department': 'Production',
#    'job': 'Executive Producer'},
#   {'adult': False,
#    'gender': 2,
#    'id': 21198,
#    'known_for_department': 'Acting',
#    'name': 'Peter Sohn',
#    'original_name': 'Peter Sohn',
#    'popularity': 12.118,
#    'profile_path': '/8cQGViF2lXlcsAIvFUMWboXYXIu.jpg',
#    'credit_id': '62825bad8d77c40066cc3365',
#    'department': 'Directing',
#    'job': 'Director'},
#   {'adult': False,
#    'gender': 2,
#    'id': 21198,
#    'known_for_department': 'Acting',
#    'name': 'Peter Sohn',
#    'original_name': 'Peter Sohn',
#    'popularity': 12.118,
#    'profile_path': '/8cQGViF2lXlcsAIvFUMWboXYXIu.jpg',
#    'credit_id': '6422e3b42dc9dc00bf5a2100',
#    'department': 'Writing',
#    'job': 'Story'},
#   {'adult': False,
#    'gender': 2,
#    'id': 57673,
#    'known_for_department': 'Production',
#    'name': 'Kevin Reher',
#    'original_name': 'Kevin Reher',
#    'popularity': 4.915,
#    'profile_path': None,
#    'credit_id': '6486164e028f140101622e9c',
#    'department': 'Production',
#    'job': 'Casting'},
#   {'adult': False,
#    'gender': 2,
#    'id': 59363,
#    'known_for_department': 'Editing',
#    'name': 'Stephen Schaffer',
#    'original_name': 'Stephen Schaffer',
#    'popularity': 1.96,
#    'profile_path': '/mGfsTkl4JziyG8Qohv3l0ThzKkM.jpg',
#    'credit_id': '64528cebc0442900e2f0e14a',
#    'department': 'Editing',
#    'job': 'Editor'},
#   {'adult': False,
#    'gender': 2,
#    'id': 60279,
#    'known_for_department': 'Acting',
#    'name': 'Fred Tatasciore',
#    'original_name': 'Fred Tatasciore',
#    'popularity': 21.396,
#    'profile_path': '/busoEz4khUJ0hOoKHexjXwGrsit.jpg',
#    'credit_id': '648da9acc2ff3d00c599c222',
#    'department': 'Sound',
#    'job': 'ADR & Dubbing'},
#   {'adult': False,
#    'gender': 2,
#    'id': 113916,
#    'known_for_department': 'Acting',
#    'name': 'Scott Menville',
#    'original_name': 'Scott Menville',
#    'popularity': 10.991,
#    'profile_path': '/eI5OhQUfeTgcrikz1cfFhVNhs5u.jpg',
#    'credit_id': '648da99bc3c891014ebd76ad',
#    'department': 'Sound',
#    'job': 'ADR & Dubbing'},
#   {'adult': False,
#    'gender': 1,
#    'id': 94820,
#    'known_for_department': 'Acting',
#    'name': 'Jessica DiCicco',
#    'original_name': 'Jessica DiCicco',
#    'popularity': 5.235,
#    'profile_path': '/7I9Ma8iV7KyiH7enKWquu7tGgah.jpg',
#    'credit_id': '648da91726346200ca19ec9c',
#    'department': 'Sound',
#    'job': 'ADR & Dubbing'},
#   {'adult': False,
#    'gender': 1,
#    'id': 116315,
#    'known_for_department': 'Acting',
#    'name': 'Kari Wahlgren',
#    'original_name': 'Kari Wahlgren',
#    'popularity': 11.006,
#    'profile_path': '/olk68V9rMrJPdXLQvvLRIGRS7tU.jpg',
#    'credit_id': '648da9ce42bf01013bbcb647',
#    'department': 'Sound',
#    'job': 'ADR & Dubbing'},
#   {'adult': False,
#    'gender': 2,
#    'id': 117824,
#    'known_for_department': 'Acting',
#    'name': 'Assaf Cohen',
#    'original_name': 'Assaf Cohen',
#    'popularity': 5.213,
#    'profile_path': '/aoYndszi7wKCWNJr2R8j6Elw55A.jpg',
#    'credit_id': '648da90f42bf0100ae312335',
#    'department': 'Sound',
#    'job': 'ADR & Dubbing'},
#   {'adult': False,
#    'gender': 1,
#    'id': 186605,
#    'known_for_department': 'Production',
#    'name': 'Terri Douglas',
#    'original_name': 'Terri Douglas',
#    'popularity': 1.512,
#    'profile_path': '/6yRCc5oKalchZuRvVJJbEDNmLEd.jpg',
#    'credit_id': '648da91d42bf01013bbcb61d',
#    'department': 'Sound',
#    'job': 'ADR & Dubbing'},
#   {'adult': False,
#    'gender': 0,
#    'id': 225985,
#    'known_for_department': 'Writing',
#    'name': 'Raymond Wong',
#    'original_name': 'Raymond Wong',
#    'popularity': 2.11,
#    'profile_path': None,
#    'credit_id': '6497e6d4b3440900ad52ba21',
#    'department': 'Visual Effects',
#    'job': 'Modelling Supervisor'},
#   {'adult': False,
#    'gender': 2,
#    'id': 958055,
#    'known_for_department': 'Writing',
#    'name': 'Jason Katz',
#    'original_name': 'Jason Katz',
#    'popularity': 2.286,
#    'profile_path': None,
#    'credit_id': '64528d67c044290185712f6c',
#    'department': 'Writing',
#    'job': 'Story Supervisor'},
#   {'adult': False,
#    'gender': 1,
#    'id': 963497,
#    'known_for_department': 'Production',
#    'name': 'Natalie Lyon',
#    'original_name': 'Natalie Lyon',
#    'popularity': 3.136,
#    'profile_path': None,
#    'credit_id': '64914b33559d220139bf76a9',
#    'department': 'Production',
#    'job': 'Casting'},
#   {'adult': False,
#    'gender': 1,
#    'id': 970529,
#    'known_for_department': 'Visual Effects',
#    'name': 'Denise Ream',
#    'original_name': 'Denise Ream',
#    'popularity': 2.871,
#    'profile_path': None,
#    'credit_id': '62825bbb031a1d14ad4e18a3',
#    'department': 'Production',
#    'job': 'Producer'},
#   {'adult': False,
#    'gender': 1,
#    'id': 1103533,
#    'known_for_department': 'Acting',
#    'name': 'Alisha Mullally',
#    'original_name': 'Alisha Mullally',
#    'popularity': 1.147,
#    'profile_path': None,
#    'credit_id': '648da9a4559d2200ff109be4',
#    'department': 'Sound',
#    'job': 'ADR & Dubbing'},
#   {'adult': False,
#    'gender': 1,
#    'id': 1212954,
#    'known_for_department': 'Writing',
#    'name': 'Kat Likkel',
#    'original_name': 'Kat Likkel',
#    'popularity': 2.532,
#    'profile_path': None,
#    'credit_id': '6422e3548d22fc00a9df0a86',
#    'department': 'Writing',
#    'job': 'Screenplay'},
#   {'adult': False,
#    'gender': 1,
#    'id': 1212954,
#    'known_for_department': 'Writing',
#    'name': 'Kat Likkel',
#    'original_name': 'Kat Likkel',
#    'popularity': 2.532,
#    'profile_path': None,
#    'credit_id': '6422e3696a34480086269425',
#    'department': 'Writing',
#    'job': 'Story'},
#   {'adult': False,
#    'gender': 2,
#    'id': 1217803,
#    'known_for_department': 'Acting',
#    'name': 'Arif S. Kinchen',
#    'original_name': 'Arif S. Kinchen',
#    'popularity': 3.668,
#    'profile_path': '/rY16iqdy5lJIyEMoL941NdzUlEr.jpg',
#    'credit_id': '648da978559d2200ff109bd7',
#    'department': 'Sound',
#    'job': 'ADR & Dubbing'},
#   {'adult': False,
#    'gender': 2,
#    'id': 1218983,
#    'known_for_department': 'Writing',
#    'name': 'Don Shank',
#    'original_name': 'Don Shank',
#    'popularity': 1.414,
#    'profile_path': None,
#    'credit_id': '642314106a3448008626aaa8',
#    'department': 'Art',
#    'job': 'Production Design'},
#   {'adult': False,
#    'gender': 2,
#    'id': 1219225,
#    'known_for_department': 'Writing',
#    'name': 'John Hoberg',
#    'original_name': 'John Hoberg',
#    'popularity': 1.407,
#    'profile_path': None,
#    'credit_id': '6422e3496a344800ef311f22',
#    'department': 'Writing',
#    'job': 'Screenplay'},
#   {'adult': False,
#    'gender': 2,
#    'id': 1219225,
#    'known_for_department': 'Writing',
#    'name': 'John Hoberg',
#    'original_name': 'John Hoberg',
#    'popularity': 1.407,
#    'profile_path': None,
#    'credit_id': '6422e3638d22fc007c009bac',
#    'department': 'Writing',
#    'job': 'Story'},
#   {'adult': False,
#    'gender': 1,
#    'id': 1222181,
#    'known_for_department': 'Writing',
#    'name': 'Brenda Hsueh',
#    'original_name': 'Brenda Hsueh',
#    'popularity': 2.86,
#    'profile_path': None,
#    'credit_id': '6422e35b2dc9dc007c07857f',
#    'department': 'Writing',
#    'job': 'Screenplay'},
#   {'adult': False,
#    'gender': 1,
#    'id': 1222181,
#    'known_for_department': 'Writing',
#    'name': 'Brenda Hsueh',
#    'original_name': 'Brenda Hsueh',
#    'popularity': 2.86,
#    'profile_path': None,
#    'credit_id': '6422e37008cf8700a015e9b2',
#    'department': 'Writing',
#    'job': 'Story'},
#   {'adult': False,
#    'gender': 1,
#    'id': 1451088,
#    'known_for_department': 'Acting',
#    'name': 'Karen Huie',
#    'original_name': 'Karen Huie',
#    'popularity': 3.78,
#    'profile_path': '/aJfKOnA80bfgLEh9oacjdGIq6Or.jpg',
#    'credit_id': '648da96f2f8d09011d23c2aa',
#    'department': 'Sound',
#    'job': 'ADR & Dubbing'},
#   {'adult': False,
#    'gender': 2,
#    'id': 1512665,
#    'known_for_department': 'Sound',
#    'name': 'Heikki Kossi',
#    'original_name': 'Heikki Kossi',
#    'popularity': 1.725,
#    'profile_path': '/6VipnMFz9whg3WKRGld7KJDGTlo.jpg',
#    'credit_id': '64a850a866a0d300c66d5b42',
#    'department': 'Sound',
#    'job': 'Foley Artist'},
#   {'adult': False,
#    'gender': 2,
#    'id': 1645150,
#    'known_for_department': 'Crew',
#    'name': 'Matt Walker',
#    'original_name': 'Matt Walker',
#    'popularity': 0.654,
#    'profile_path': None,
#    'credit_id': '6497e8c16f43ec00ac3b426c',
#    'department': 'Crew',
#    'job': 'Executive Music Producer'},
#   {'adult': False,
#    'gender': 0,
#    'id': 1694608,
#    'known_for_department': 'Lighting',
#    'name': 'Luke Martorelli',
#    'original_name': 'Luke Martorelli',
#    'popularity': 1.459,
#    'profile_path': None,
#    'credit_id': '6497e76a62f33500e912a07e',
#    'department': 'Lighting',
#    'job': 'Lighting Supervisor'},
#   {'adult': False,
#    'gender': 2,
#    'id': 1742712,
#    'known_for_department': 'Editing',
#    'name': 'Thomas Gonzales',
#    'original_name': 'Thomas Gonzales',
#    'popularity': 1.145,
#    'profile_path': None,
#    'credit_id': '646e1efea5046e00e5b86c21',
#    'department': 'Crew',
#    'job': 'In Memory Of'},
#   {'adult': False,
#    'gender': 0,
#    'id': 1806625,
#    'known_for_department': 'Visual Effects',
#    'name': 'Austin Madison',
#    'original_name': 'Austin Madison',
#    'popularity': 1.188,
#    'profile_path': None,
#    'credit_id': '648da9852f8d09011d23c2b0',
#    'department': 'Sound',
#    'job': 'ADR & Dubbing'},
#   {'adult': False,
#    'gender': 0,
#    'id': 1976191,
#    'known_for_department': 'Sound',
#    'name': 'Coya Elliott',
#    'original_name': 'Coya Elliott',
#    'popularity': 2.165,
#    'profile_path': None,
#    'credit_id': '6497e841bbd0b001066eda66',
#    'department': 'Sound',
#    'job': 'Supervising Sound Editor'},
#   {'adult': False,
#    'gender': 0,
#    'id': 1993267,
#    'known_for_department': 'Visual Effects',
#    'name': 'Stephen Marshall',
#    'original_name': 'Stephen Marshall',
#    'popularity': 1.13,
#    'profile_path': None,
#    'credit_id': '6423147d53466100aa0159c5',
#    'department': 'Visual Effects',
#    'job': 'Effects Supervisor'},
#   {'adult': False,
#    'gender': 0,
#    'id': 1993271,
#    'known_for_department': 'Visual Effects',
#    'name': 'Jon Reisch',
#    'original_name': 'Jon Reisch',
#    'popularity': 0.6,
#    'profile_path': None,
#    'credit_id': '646e1fb933a3760175d4e6b4',
#    'department': 'Visual Effects',
#    'job': 'Effects Supervisor'},
#   {'adult': False,
#    'gender': 2,
#    'id': 1993327,
#    'known_for_department': 'Crew',
#    'name': 'Sanjay Bakshi',
#    'original_name': 'Sanjay Bakshi',
#    'popularity': 0.6,
#    'profile_path': None,
#    'credit_id': '6423145c2dc9dc00fd1c9d32',
#    'department': 'Visual Effects',
#    'job': 'Visual Effects Supervisor'},
#   {'adult': False,
#    'gender': 0,
#    'id': 1993343,
#    'known_for_department': 'Visual Effects',
#    'name': 'Jacob Brooks',
#    'original_name': 'Jacob Brooks',
#    'popularity': 0.6,
#    'profile_path': None,
#    'credit_id': '6497e8e9b3440900c54f4623',
#    'department': 'Crew',
#    'job': 'Thanks'},
#   {'adult': False,
#    'gender': 0,
#    'id': 1993360,
#    'known_for_department': 'Visual Effects',
#    'name': 'Cathleen Carmean',
#    'original_name': 'Cathleen Carmean',
#    'popularity': 1.6,
#    'profile_path': None,
#    'credit_id': '6497e576955c6500ac8943e2',
#    'department': 'Visual Effects',
#    'job': 'Animation Supervisor'},
#   {'adult': False,
#    'gender': 1,
#    'id': 1993614,
#    'known_for_department': 'Visual Effects',
#    'name': 'Amber Rudolph',
#    'original_name': 'Amber Rudolph',
#    'popularity': 0.6,
#    'profile_path': None,
#    'credit_id': '646e1f0aa5046e012469e818',
#    'department': 'Crew',
#    'job': 'In Memory Of'},
#   {'adult': False,
#    'gender': 0,
#    'id': 1993615,
#    'known_for_department': 'Visual Effects',
#    'name': 'Allison Rutland',
#    'original_name': 'Allison Rutland',
#    'popularity': 0.631,
#    'profile_path': None,
#    'credit_id': '6423149323be4600c0f6f062',
#    'department': 'Visual Effects',
#    'job': 'Animation Director'},
#   {'adult': False,
#    'gender': 0,
#    'id': 1995030,
#    'known_for_department': 'Directing',
#    'name': 'Jahkeeli Garnett',
#    'original_name': 'Jahkeeli Garnett',
#    'popularity': 1.4,
#    'profile_path': None,
#    'credit_id': '6497e62d6f43ec00ffa2a98a',
#    'department': 'Visual Effects',
#    'job': 'Layout Supervisor'},
#   {'adult': False,
#    'gender': 0,
#    'id': 1997753,
#    'known_for_department': 'Editing',
#    'name': 'Ben Morris',
#    'original_name': 'Ben Morris',
#    'popularity': 0.6,
#    'profile_path': None,
#    'credit_id': '6497e61b62f3350127468483',
#    'department': 'Editing',
#    'job': 'First Assistant Editor'},
#   {'adult': False,
#    'gender': 0,
#    'id': 1998989,
#    'known_for_department': 'Visual Effects',
#    'name': 'Dave Strick',
#    'original_name': 'Dave Strick',
#    'popularity': 0.607,
#    'profile_path': None,
#    'credit_id': '6497e682bbd0b000c8a327a9',
#    'department': 'Visual Effects',
#    'job': 'Character Modelling Supervisor'},
#   {'adult': False,
#    'gender': 1,
#    'id': 2001859,
#    'known_for_department': 'Lighting',
#    'name': 'Amy Rae Jones',
#    'original_name': 'Amy Rae Jones',
#    'popularity': 0.6,
#    'profile_path': None,
#    'credit_id': '6497e7606f6a9900e5d2f31e',
#    'department': 'Lighting',
#    'job': 'Lighting Supervisor'},
#   {'adult': False,
#    'gender': 0,
#    'id': 2008327,
#    'known_for_department': 'Production',
#    'name': 'David Juan Bianchi',
#    'original_name': 'David Juan Bianchi',
#    'popularity': 1.391,
#    'profile_path': None,
#    'credit_id': '64528d3a87a27a00e38efbee',
#    'department': 'Camera',
#    'job': 'Director of Photography'},
#   {'adult': False,
#    'gender': 0,
#    'id': 2134663,
#    'known_for_department': 'Visual Effects',
#    'name': 'Cari Reiche',
#    'original_name': 'Cari Reiche',
#    'popularity': 1.176,
#    'profile_path': None,
#    'credit_id': '6497e55562f335014628e1fc',
#    'department': 'Visual Effects',
#    'job': 'Animation'},
#   {'adult': False,
#    'gender': 0,
#    'id': 2147612,
#    'known_for_department': 'Sound',
#    'name': 'Shinnosuke Miyazawa',
#    'original_name': 'Shinnosuke Miyazawa',
#    'popularity': 0.861,
#    'profile_path': None,
#    'credit_id': '6497e87a62f3350108188037',
#    'department': 'Sound',
#    'job': 'Music Editor'},
#   {'adult': False,
#    'gender': 2,
#    'id': 2172384,
#    'known_for_department': 'Acting',
#    'name': 'Cole Massie',
#    'original_name': 'Cole Massie',
#    'popularity': 1.712,
#    'profile_path': None,
#    'credit_id': '648da98f559d2200ff109bdc',
#    'department': 'Sound',
#    'job': 'ADR & Dubbing'},
#   {'adult': False,
#    'gender': 0,
#    'id': 2492290,
#    'known_for_department': 'Acting',
#    'name': 'Secunda Wood',
#    'original_name': 'Secunda Wood',
#    'popularity': 2.289,
#    'profile_path': '/kQ8PehWzNbD6J6emTvl6gl8IXAB.jpg',
#    'credit_id': '648da9d4c2ff3d011cb92f05',
#    'department': 'Sound',
#    'job': 'ADR & Dubbing'},
#   {'adult': False,
#    'gender': 0,
#    'id': 2648999,
#    'known_for_department': 'Directing',
#    'name': 'Cara Brody',
#    'original_name': 'Cara Brody',
#    'popularity': 1.38,
#    'profile_path': None,
#    'credit_id': '6497e5646f6a990102fbb226',
#    'department': 'Directing',
#    'job': 'Script Supervisor'},
#   {'adult': False,
#    'gender': 2,
#    'id': 2754590,
#    'known_for_department': 'Acting',
#    'name': 'Innocent Ekakitie',
#    'original_name': 'Innocent Ekakitie',
#    'popularity': 3.135,
#    'profile_path': '/8jm0JECrAwXHHj7lpIs8kLGE5hQ.jpg',
#    'credit_id': '648da9462f8d0900c6658622',
#    'department': 'Sound',
#    'job': 'ADR & Dubbing'},
#   {'adult': False,
#    'gender': 2,
#    'id': 2827641,
#    'known_for_department': 'Writing',
#    'name': 'Le Tang',
#    'original_name': 'Le Tang',
#    'popularity': 1.345,
#    'profile_path': None,
#    'credit_id': '6497e5f762f3350108187f16',
#    'department': 'Writing',
#    'job': 'Story Artist'},
#   {'adult': False,
#    'gender': 1,
#    'id': 2998024,
#    'known_for_department': 'Acting',
#    'name': 'Maya Tuttle',
#    'original_name': 'Maya Tuttle',
#    'popularity': 1.691,
#    'profile_path': '/5hoy9xjZftmC9Q3Jzl5QCglGs29.jpg',
#    'credit_id': '648da9c42f8d090100a9f20e',
#    'department': 'Sound',
#    'job': 'ADR & Dubbing'},
#   {'adult': False,
#    'gender': 1,
#    'id': 3106557,
#    'known_for_department': 'Visual Effects',
#    'name': 'Rebecca Euphrat',
#    'original_name': 'Rebecca Euphrat',
#    'popularity': 0.6,
#    'profile_path': None,
#    'credit_id': '6497e7e7eb79c200c56dc96b',
#    'department': 'Visual Effects',
#    'job': 'Animation'},
#   {'adult': False,
#    'gender': 0,
#    'id': 3222733,
#    'known_for_department': 'Acting',
#    'name': 'Heather Eisner',
#    'original_name': 'Heather Eisner',
#    'popularity': 1.936,
#    'profile_path': None,
#    'credit_id': '6497e810b3440900e2721562',
#    'department': 'Crew',
#    'job': 'Post Production Supervisor'},
#   {'adult': False,
#    'gender': 0,
#    'id': 3242711,
#    'known_for_department': 'Directing',
#    'name': 'McKenna Jean Harris',
#    'original_name': 'McKenna Jean Harris',
#    'popularity': 0.706,
#    'profile_path': None,
#    'credit_id': '6497e5d6eb79c200ad71b58e',
#    'department': 'Production',
#    'job': 'Associate Producer'},
#   {'adult': False,
#    'gender': 1,
#    'id': 3463962,
#    'known_for_department': 'Production',
#    'name': 'Lexi Diamond',
#    'original_name': 'Lexi Diamond',
#    'popularity': 1.4,
#    'profile_path': None,
#    'credit_id': '648da9ecc2ff3d00e2e00072',
#    'department': 'Sound',
#    'job': 'ADR Coordinator'},
#   {'adult': False,
#    'gender': 0,
#    'id': 4078461,
#    'known_for_department': 'Crew',
#    'name': 'J. Garett Sheldrew',
#    'original_name': 'J. Garett Sheldrew',
#    'popularity': 0.98,
#    'profile_path': None,
#    'credit_id': '646e1f2133a37600e67cb11e',
#    'department': 'Crew',
#    'job': 'In Memory Of'},
#   {'adult': False,
#    'gender': 0,
#    'id': 4107452,
#    'known_for_department': 'Acting',
#    'name': 'Dylan Buccieri',
#    'original_name': 'Dylan Buccieri',
#    'popularity': 0.6,
#    'profile_path': None,
#    'credit_id': '648da90642bf01013bbcb613',
#    'department': 'Sound',
#    'job': 'ADR & Dubbing'},
#   {'adult': False,
#    'gender': 3,
#    'id': 4107463,
#    'known_for_department': 'Sound',
#    'name': 'Kai Ava Hauser',
#    'original_name': 'Kai Ava Hauser',
#    'popularity': 0.711,
#    'profile_path': None,
#    'credit_id': '648da9612f8d09013af9b2bb',
#    'department': 'Sound',
#    'job': 'ADR & Dubbing'},
#   {'adult': False,
#    'gender': 0,
#    'id': 4107470,
#    'known_for_department': 'Acting',
#    'name': 'Krysta Gonzales',
#    'original_name': 'Krysta Gonzales',
#    'popularity': 0.6,
#    'profile_path': None,
#    'credit_id': '648da95342bf0100e49e4842',
#    'department': 'Sound',
#    'job': 'ADR & Dubbing'},
#   {'adult': False,
#    'gender': 0,
#    'id': 4129966,
#    'known_for_department': 'Visual Effects',
#    'name': 'John Legrande',
#    'original_name': 'John Legrande',
#    'popularity': 1.38,
#    'profile_path': None,
#    'credit_id': '6497e65eeb79c200ad71b5cf',
#    'department': 'Visual Effects',
#    'job': 'Animation Technical Director'},
#   {'adult': False,
#    'gender': 0,
#    'id': 4129973,
#    'known_for_department': 'Visual Effects',
#    'name': 'Arnold Moon',
#    'original_name': 'Arnold Moon',
#    'popularity': 0.6,
#    'profile_path': None,
#    'credit_id': '6497e73e6f43ec00e27de13d',
#    'department': 'Visual Effects',
#    'job': 'Animation Technical Director'},
#   {'adult': False,
#    'gender': 0,
#    'id': 4129974,
#    'known_for_department': 'Crew',
#    'name': 'Kevin Chun',
#    'original_name': 'Kevin Chun',
#    'popularity': 0.6,
#    'profile_path': None,
#    'credit_id': '6497e92abbd0b000c8a328d2',
#    'department': 'Crew',
#    'job': 'Thanks'}]}

# %%
# House of Flying Daggers request
# Save a movie title to search for as a variable
movie_title = 'House of Flying Daggers'

# Concatenate request_url, title, and api_key. Store as new variable
request_url = f"https://api.themoviedb.org/3/search/movie?api_key={api_key}&query={movie_title}"


# Execute get request
response = requests.get(request_url)


# Get movie ID
movie_data = response.json()
movie_id = movie_data['results'][0]['id']



# Call get_credits function
get_movie_credits(movie_id, api_key)
# Out:
# {'id': 9550,
#  'cast': [{'adult': False,
#    'gender': 2,
#    'id': 43661,
#    'known_for_department': 'Acting',
#    'name': 'Takeshi Kaneshiro',
#    'original_name': 'Takeshi Kaneshiro',
#    'popularity': 10.925,
#    'profile_path': '/mOxNGub5nW9i35FQrg6gltW3PQd.jpg',
#    'cast_id': 1,
#    'character': 'Jin',
#    'credit_id': '52fe4508c3a36847f80b8575',
#    'order': 0},
#   {'adult': False,
#    'gender': 2,
#    'id': 25246,
#    'known_for_department': 'Acting',
#    'name': 'Andy Lau',
#    'original_name': 'Andy Lau',
#    'popularity': 31.503,
#    'profile_path': '/nuxyCdWRUrKt31yGgo5w8637x3h.jpg',
#    'cast_id': 16,
#    'character': 'Leo',
#    'credit_id': '52fe4508c3a36847f80b85bd',
#    'order': 1},
#   {'adult': False,
#    'gender': 1,
#    'id': 1339,
#    'known_for_department': 'Acting',
#    'name': 'Zhang Ziyi',
#    'original_name': 'Zhang Ziyi',
#    'popularity': 19.448,
#    'profile_path': '/6DUCAJzpw06VoAA9VWrvB2g4dpq.jpg',
#    'cast_id': 3,
#    'character': 'Xiao Mei',
#    'credit_id': '52fe4508c3a36847f80b8579',
#    'order': 2},
#   {'adult': False,
#    'gender': 1,
#    'id': 57912,
#    'known_for_department': 'Acting',
#    'name': 'Song Dandan',
#    'original_name': 'Song Dandan',
#    'popularity': 5.1,
#    'profile_path': '/giBUpVl1xpjIlUrnQYtZ4qToIhS.jpg',
#    'cast_id': 4,
#    'character': 'Yee',
#    'credit_id': '52fe4508c3a36847f80b857d',
#    'order': 3},
#   {'adult': False,
#    'gender': 2,
#    'id': 1517431,
#    'known_for_department': 'Acting',
#    'name': 'Hongfei Zhao',
#    'original_name': 'Hongfei Zhao',
#    'popularity': 3.868,
#    'profile_path': '/19QXbUQkDZEuzWn6zvO7sLOwe0b.jpg',
#    'cast_id': 18,
#    'character': 'Xiao Bu Kuai',
#    'credit_id': '5739425092514149ae00055e',
#    'order': 4},
#   {'adult': False,
#    'gender': 2,
#    'id': 1571927,
#    'known_for_department': 'Acting',
#    'name': 'Jun Guo',
#    'original_name': 'Jun Guo',
#    'popularity': 2.158,
#    'profile_path': '/lzE5O2qiRo89qzPF7ecgJC4v49Z.jpg',
#    'cast_id': 19,
#    'character': 'Police Officer',
#    'credit_id': '57394270c3a36831620001a7',
#    'order': 5},
#   {'adult': False,
#    'gender': 1,
#    'id': 1620869,
#    'known_for_department': 'Acting',
#    'name': 'Zhang Shu',
#    'original_name': 'Zhang Shu',
#    'popularity': 1.268,
#    'profile_path': '/oLsIRj7wGF3FMWnvxJW8yrBdEnj.jpg',
#    'cast_id': 20,
#    'character': 'Performer',
#    'credit_id': '573942789251416036000180',
#    'order': 6},
#   {'adult': False,
#    'gender': 2,
#    'id': 1620870,
#    'known_for_department': 'Acting',
#    'name': 'Jiusheng Wang',
#    'original_name': 'Jiusheng Wang',
#    'popularity': 3.664,
#    'profile_path': '/p7i376UgQzJlyclZBaGh6qAPAs0.jpg',
#    'cast_id': 21,
#    'character': 'Performer',
#    'credit_id': '573942849251412070001b80',
#    'order': 7},
#   {'adult': False,
#    'gender': 2,
#    'id': 1620872,
#    'known_for_department': 'Acting',
#    'name': 'Zhengyong Zhang',
#    'original_name': 'Zhengyong Zhang',
#    'popularity': 2.896,
#    'profile_path': '/zejFveClm5WC1VKUZ5ssXO83UOW.jpg',
#    'cast_id': 22,
#    'character': 'Performer',
#    'credit_id': '57394294c3a3684d4900239a',
#    'order': 8},
#   {'adult': False,
#    'gender': 2,
#    'id': 1620873,
#    'known_for_department': 'Acting',
#    'name': 'Yongxin Wang',
#    'original_name': 'Yongxin Wang',
#    'popularity': 0.98,
#    'profile_path': None,
#    'cast_id': 23,
#    'character': 'Performer',
#    'credit_id': '573942a29251413656000a5a',
#    'order': 9},
#   {'adult': False,
#    'gender': 0,
#    'id': 1620874,
#    'known_for_department': 'Acting',
#    'name': 'Dong Liu',
#    'original_name': 'Dong Liu',
#    'popularity': 0.6,
#    'profile_path': None,
#    'cast_id': 24,
#    'character': 'Shield Warrior',
#    'credit_id': '573942ab9251414b0300161f',
#    'order': 10},
#   {'adult': False,
#    'gender': 1,
#    'id': 1620875,
#    'known_for_department': 'Acting',
#    'name': 'Qi Zi',
#    'original_name': 'Qi Zi',
#    'popularity': 1.094,
#    'profile_path': None,
#    'cast_id': 25,
#    'character': 'Performer',
#    'credit_id': '573942b99251414b03001628',
#    'order': 11},
#   {'adult': False,
#    'gender': 0,
#    'id': 1620876,
#    'known_for_department': 'Acting',
#    'name': 'Xuedong Qu',
#    'original_name': 'Xuedong Qu',
#    'popularity': 0.622,
#    'profile_path': None,
#    'cast_id': 26,
#    'character': 'Performer',
#    'credit_id': '573942c0c3a3684d490023a5',
#    'order': 12},
#   {'adult': False,
#    'gender': 0,
#    'id': 2834467,
#    'known_for_department': 'Acting',
#    'name': 'Liping Tian',
#    'original_name': 'Liping Tian',
#    'popularity': 0.6,
#    'profile_path': None,
#    'cast_id': 32,
#    'character': 'Performer',
#    'credit_id': '5f99fde866565a0036b90e5d',
#    'order': 13},
#   {'adult': False,
#    'gender': 0,
#    'id': 2834469,
#    'known_for_department': 'Acting',
#    'name': 'Hongwei Zhao',
#    'original_name': 'Hongwei Zhao',
#    'popularity': 0.6,
#    'profile_path': None,
#    'cast_id': 33,
#    'character': 'Performer',
#    'credit_id': '5f99fdf6e942ee0038ab1ddf',
#    'order': 14},
#   {'adult': False,
#    'gender': 0,
#    'id': 2834470,
#    'known_for_department': 'Acting',
#    'name': 'Huang Weina',
#    'original_name': 'Huang Weina',
#    'popularity': 0.6,
#    'profile_path': None,
#    'cast_id': 34,
#    'character': 'Performer',
#    'credit_id': '5f99fe02b4a543003735b2e8',
#    'order': 15},
#   {'adult': False,
#    'gender': 0,
#    'id': 2834471,
#    'known_for_department': 'Acting',
#    'name': 'Ge Dan',
#    'original_name': 'Ge Dan',
#    'popularity': 0.6,
#    'profile_path': None,
#    'cast_id': 35,
#    'character': 'Performer',
#    'credit_id': '5f99fe0d2866fa003744ada5',
#    'order': 16},
#   {'adult': False,
#    'gender': 0,
#    'id': 2834472,
#    'known_for_department': 'Acting',
#    'name': 'Yang Xiadong',
#    'original_name': 'Yang Xiadong',
#    'popularity': 0.6,
#    'profile_path': None,
#    'cast_id': 36,
#    'character': 'Performer',
#    'credit_id': '5f99fe3587ae7b0034e0a4c5',
#    'order': 17},
#   {'adult': False,
#    'gender': 0,
#    'id': 2834474,
#    'known_for_department': 'Acting',
#    'name': 'Shang Yisha',
#    'original_name': 'Shang Yisha',
#    'popularity': 0.6,
#    'profile_path': None,
#    'cast_id': 37,
#    'character': 'Performer',
#    'credit_id': '5f99fe409f5dfb0032266a53',
#    'order': 18},
#   {'adult': False,
#    'gender': 0,
#    'id': 2834475,
#    'known_for_department': 'Acting',
#    'name': 'Liu Ying',
#    'original_name': 'Liu Ying',
#    'popularity': 0.6,
#    'profile_path': None,
#    'cast_id': 38,
#    'character': 'Performer',
#    'credit_id': '5f99fe606f8d95003672d6f5',
#    'order': 19},
#   {'adult': False,
#    'gender': 0,
#    'id': 2834477,
#    'known_for_department': 'Acting',
#    'name': 'Huang Jingwen',
#    'original_name': 'Huang Jingwen',
#    'popularity': 0.6,
#    'profile_path': None,
#    'cast_id': 39,
#    'character': 'Performer',
#    'credit_id': '5f99fe6e4c1d9a003762cab4',
#    'order': 20},
#   {'adult': False,
#    'gender': 0,
#    'id': 2834478,
#    'known_for_department': 'Acting',
#    'name': 'Zhang Kejia',
#    'original_name': 'Zhang Kejia',
#    'popularity': 0.6,
#    'profile_path': None,
#    'cast_id': 40,
#    'character': 'Performer',
#    'credit_id': '5f99fe824cbe120034beb468',
#    'order': 21},
#   {'adult': False,
#    'gender': 0,
#    'id': 2834480,
#    'known_for_department': 'Acting',
#    'name': 'Luo Tianyou',
#    'original_name': 'Luo Tianyou',
#    'popularity': 0.6,
#    'profile_path': None,
#    'cast_id': 41,
#    'character': 'Performer',
#    'credit_id': '5f99fe90992fe600372c81bc',
#    'order': 22},
#   {'adult': False,
#    'gender': 0,
#    'id': 2834483,
#    'known_for_department': 'Acting',
#    'name': 'Zhu Lin',
#    'original_name': 'Zhu Lin',
#    'popularity': 0.6,
#    'profile_path': None,
#    'cast_id': 42,
#    'character': 'Performer',
#    'credit_id': '5f99feb566565a0036b91096',
#    'order': 23},
#   {'adult': False,
#    'gender': 0,
#    'id': 2834484,
#    'known_for_department': 'Acting',
#    'name': 'Hu Jiwei',
#    'original_name': 'Hu Jiwei',
#    'popularity': 0.6,
#    'profile_path': None,
#    'cast_id': 43,
#    'character': 'Performer',
#    'credit_id': '5f99fec2a5046e0039837464',
#    'order': 24},
#   {'adult': False,
#    'gender': 0,
#    'id': 2834485,
#    'known_for_department': 'Acting',
#    'name': 'Hong Yu',
#    'original_name': 'Hong Yu',
#    'popularity': 0.6,
#    'profile_path': None,
#    'cast_id': 44,
#    'character': 'Performer',
#    'credit_id': '5f99fed466a7c3003695b967',
#    'order': 25},
#   {'adult': False,
#    'gender': 2,
#    'id': 122190,
#    'known_for_department': 'Acting',
#    'name': 'Hao Bojie',
#    'original_name': 'Hao Bojie',
#    'popularity': 0.6,
#    'profile_path': '/jFnhlb7lffXGVclmoyFhNmLnmgo.jpg',
#    'cast_id': 45,
#    'character': 'Wang Wu',
#    'credit_id': '5f99fef66eecee00378e2fbb',
#    'order': 26},
#   {'adult': False,
#    'gender': 0,
#    'id': 2834488,
#    'known_for_department': 'Acting',
#    'name': 'Zhu Jiajun',
#    'original_name': 'Zhu Jiajun',
#    'popularity': 0.6,
#    'profile_path': None,
#    'cast_id': 46,
#    'character': 'Performer',
#    'credit_id': '5f99ff0a66565a0037b93f9f',
#    'order': 27},
#   {'adult': False,
#    'gender': 0,
#    'id': 2834489,
#    'known_for_department': 'Acting',
#    'name': 'Xu Ge',
#    'original_name': 'Xu Ge',
#    'popularity': 0.6,
#    'profile_path': None,
#    'cast_id': 47,
#    'character': 'Performer',
#    'credit_id': '5f99ff1337b3a900380beb60',
#    'order': 28},
#   {'adult': False,
#    'gender': 0,
#    'id': 2834492,
#    'known_for_department': 'Acting',
#    'name': 'Chou Jingxiu',
#    'original_name': 'Chou Jingxiu',
#    'popularity': 0.6,
#    'profile_path': None,
#    'cast_id': 48,
#    'character': 'Performer',
#    'credit_id': '5f99ff2366565a0036b91182',
#    'order': 29},
#   {'adult': False,
#    'gender': 0,
#    'id': 2834493,
#    'known_for_department': 'Acting',
#    'name': 'Guo Cuifang',
#    'original_name': 'Guo Cuifang',
#    'popularity': 0.6,
#    'profile_path': None,
#    'cast_id': 49,
#    'character': 'Performer',
#    'credit_id': '5f99ff2f87ae7b0037e0e153',
#    'order': 30},
#   {'adult': False,
#    'gender': 1,
#    'id': 1251618,
#    'known_for_department': 'Acting',
#    'name': 'Chengyuan Li',
#    'original_name': 'Chengyuan Li',
#    'popularity': 4.362,
#    'profile_path': '/qqDZJB9KnzKRWHYmZBXff0fzqzV.jpg',
#    'cast_id': 50,
#    'character': 'Performer',
#    'credit_id': '5f99ff4287ae7b0037e0e1b1',
#    'order': 31},
#   {'adult': False,
#    'gender': 0,
#    'id': 2834494,
#    'known_for_department': 'Acting',
#    'name': 'Zhang Shuo',
#    'original_name': 'Zhang Shuo',
#    'popularity': 0.6,
#    'profile_path': None,
#    'cast_id': 51,
#    'character': 'Performer',
#    'credit_id': '5f99ff5566a7c3003695ba19',
#    'order': 32},
#   {'adult': False,
#    'gender': 0,
#    'id': 2834495,
#    'known_for_department': 'Acting',
#    'name': 'Zhang Jidong',
#    'original_name': 'Zhang Jidong',
#    'popularity': 0.6,
#    'profile_path': None,
#    'cast_id': 52,
#    'character': 'Performer',
#    'credit_id': '5f99ff6166565a0036b911bd',
#    'order': 33},
#   {'adult': False,
#    'gender': 2,
#    'id': 1418476,
#    'known_for_department': 'Acting',
#    'name': 'Li Qiang',
#    'original_name': 'Li Qiang',
#    'popularity': 2.634,
#    'profile_path': '/6pOx4SnAFDn9mKRyWGAPlX7KFFP.jpg',
#    'cast_id': 53,
#    'character': 'Performer',
#    'credit_id': '5f99ff83aad9c20036d538d6',
#    'order': 34},
#   {'adult': False,
#    'gender': 0,
#    'id': 2834498,
#    'known_for_department': 'Acting',
#    'name': 'Fu Yang',
#    'original_name': 'Fu Yang',
#    'popularity': 0.6,
#    'profile_path': None,
#    'cast_id': 54,
#    'character': 'Performer',
#    'credit_id': '5f99ff971fb94f00373b414d',
#    'order': 35},
#   {'adult': False,
#    'gender': 2,
#    'id': 2856891,
#    'known_for_department': 'Acting',
#    'name': 'Yang Guang',
#    'original_name': 'Yang Guang',
#    'popularity': 0.84,
#    'profile_path': None,
#    'cast_id': 89,
#    'character': 'Performer',
#    'credit_id': '6427e9d8a3e4ba00779318c6',
#    'order': 36},
#   {'adult': False,
#    'gender': 2,
#    'id': 1620878,
#    'known_for_department': 'Acting',
#    'name': 'Wen Yang',
#    'original_name': 'Wen Yang',
#    'popularity': 0.6,
#    'profile_path': None,
#    'cast_id': 90,
#    'character': 'Performer',
#    'credit_id': '6529404b544c410dd6758e09',
#    'order': 37},
#   {'adult': False,
#    'gender': 0,
#    'id': 2834500,
#    'known_for_department': 'Acting',
#    'name': 'Chen Liang',
#    'original_name': 'Chen Liang',
#    'popularity': 0.6,
#    'profile_path': None,
#    'cast_id': 57,
#    'character': 'Performer',
#    'credit_id': '5f99ffe8aad9c20039d50c85',
#    'order': 38},
#   {'adult': False,
#    'gender': 0,
#    'id': 2834501,
#    'known_for_department': 'Acting',
#    'name': 'Lin Xiuqiang',
#    'original_name': 'Lin Xiuqiang',
#    'popularity': 0.6,
#    'profile_path': None,
#    'cast_id': 58,
#    'character': 'Performer',
#    'credit_id': '5f99fff866565a0037b9448a',
#    'order': 39},
#   {'adult': False,
#    'gender': 0,
#    'id': 2834503,
#    'known_for_department': 'Acting',
#    'name': 'Wang Kun',
#    'original_name': 'Wang Kun',
#    'popularity': 0.6,
#    'profile_path': None,
#    'cast_id': 59,
#    'character': 'Performer',
#    'credit_id': '5f9a0020a5046e0039837634',
#    'order': 40},
#   {'adult': False,
#    'gender': 0,
#    'id': 2834504,
#    'known_for_department': 'Acting',
#    'name': 'Li Meng',
#    'original_name': 'Li Meng',
#    'popularity': 0.6,
#    'profile_path': None,
#    'cast_id': 60,
#    'character': 'Performer',
#    'credit_id': '5f9a00359f5dfb003526bc76',
#    'order': 41},
#   {'adult': False,
#    'gender': 0,
#    'id': 2834505,
#    'known_for_department': 'Acting',
#    'name': 'Dong Ming',
#    'original_name': 'Dong Ming',
#    'popularity': 0.6,
#    'profile_path': None,
#    'cast_id': 61,
#    'character': 'Performer',
#    'credit_id': '5f9a003f66a7c3003995e033',
#    'order': 42},
#   {'adult': False,
#    'gender': 0,
#    'id': 1620879,
#    'known_for_department': 'Acting',
#    'name': 'Zheng Xiao-Dong',
#    'original_name': 'Zheng Xiao-Dong',
#    'popularity': 0.6,
#    'profile_path': '/gxuSiSY4BaGFRhhNoKgUc1ZXDpI.jpg',
#    'cast_id': 62,
#    'character': 'Performer',
#    'credit_id': '5f9a00536332f7003a81791a',
#    'order': 43},
#   {'adult': False,
#    'gender': 0,
#    'id': 2834506,
#    'known_for_department': 'Acting',
#    'name': 'Song Chacha',
#    'original_name': 'Song Chacha',
#    'popularity': 0.6,
#    'profile_path': None,
#    'cast_id': 63,
#    'character': 'Performer',
#    'credit_id': '5f9a00606f8d95003672db48',
#    'order': 44},
#   {'adult': False,
#    'gender': 1,
#    'id': 2834507,
#    'known_for_department': 'Acting',
#    'name': 'Wang Xuanyi',
#    'original_name': 'Wang Xuanyi',
#    'popularity': 0.6,
#    'profile_path': '/oXTvbAjsOgIwTsHiaolKLLRrAuY.jpg',
#    'cast_id': 64,
#    'character': 'Performer',
#    'credit_id': '5f9a006d992fe6003a2c9ed6',
#    'order': 45},
#   {'adult': False,
#    'gender': 0,
#    'id': 2834508,
#    'known_for_department': 'Acting',
#    'name': 'Huang Xueying',
#    'original_name': 'Huang Xueying',
#    'popularity': 0.6,
#    'profile_path': None,
#    'cast_id': 65,
#    'character': 'Performer',
#    'credit_id': '5f9a007aa5046e0036835784',
#    'order': 46}],
#  'crew': [{'adult': False,
#    'gender': 2,
#    'id': 607,
#    'known_for_department': 'Directing',
#    'name': 'Zhang Yimou',
#    'original_name': 'Zhang Yimou',
#    'popularity': 3.885,
#    'profile_path': '/uU5vECl94jDQYjiRk4eOpVRMEi9.jpg',
#    'credit_id': '52fe4508c3a36847f80b85b9',
#    'department': 'Directing',
#    'job': 'Director'},
#   {'adult': False,
#    'gender': 2,
#    'id': 607,
#    'known_for_department': 'Directing',
#    'name': 'Zhang Yimou',
#    'original_name': 'Zhang Yimou',
#    'popularity': 3.885,
#    'profile_path': '/uU5vECl94jDQYjiRk4eOpVRMEi9.jpg',
#    'credit_id': '52fe4508c3a36847f80b85a1',
#    'department': 'Production',
#    'job': 'Producer'},
#   {'adult': False,
#    'gender': 2,
#    'id': 607,
#    'known_for_department': 'Directing',
#    'name': 'Zhang Yimou',
#    'original_name': 'Zhang Yimou',
#    'popularity': 3.885,
#    'profile_path': '/uU5vECl94jDQYjiRk4eOpVRMEi9.jpg',
#    'credit_id': '52fe4508c3a36847f80b858f',
#    'department': 'Writing',
#    'job': 'Author'},
#   {'adult': False,
#    'gender': 0,
#    'id': 1335,
#    'known_for_department': 'Writing',
#    'name': 'Bin Wang',
#    'original_name': 'Bin Wang',
#    'popularity': 1.205,
#    'profile_path': None,
#    'credit_id': '52fe4508c3a36847f80b8589',
#    'department': 'Writing',
#    'job': 'Author'},
#   {'adult': False,
#    'gender': 2,
#    'id': 1351,
#    'known_for_department': 'Production',
#    'name': 'Bill Kong Chi-Keung',
#    'original_name': 'Bill Kong Chi-Keung',
#    'popularity': 2.339,
#    'profile_path': '/AoxbtYjHoPo9QLGiSto3DUHDl64.jpg',
#    'credit_id': '52fe4508c3a36847f80b8595',
#    'department': 'Production',
#    'job': 'Producer'},
#   {'adult': False,
#    'gender': 0,
#    'id': 1353,
#    'known_for_department': 'Production',
#    'name': 'Zhang Weiping',
#    'original_name': 'Zhang Weiping',
#    'popularity': 0.677,
#    'profile_path': None,
#    'credit_id': '52fe4508c3a36847f80b859b',
#    'department': 'Production',
#    'job': 'Executive Producer'},
#   {'adult': False,
#    'gender': 0,
#    'id': 1355,
#    'known_for_department': 'Production',
#    'name': 'Zhang Zhenyan',
#    'original_name': 'Zhang Zhenyan',
#    'popularity': 0.732,
#    'profile_path': None,
#    'credit_id': '625264a341465c366414e94f',
#    'department': 'Production',
#    'job': 'Associate Producer'},
#   {'adult': False,
#    'gender': 2,
#    'id': 1358,
#    'known_for_department': 'Art',
#    'name': 'Tingxiao Huo',
#    'original_name': 'Tingxiao Huo',
#    'popularity': 1.571,
#    'profile_path': '/yzCO7xYsOtE9NfGyLeY33BVW4aM.jpg',
#    'credit_id': '625264d7ab684900678e0602',
#    'department': 'Art',
#    'job': 'Production Design'},
#   {'adult': False,
#    'gender': 2,
#    'id': 12455,
#    'known_for_department': 'Sound',
#    'name': 'Shigeru Umebayashi',
#    'original_name': 'Shigeru Umebayashi',
#    'popularity': 2.104,
#    'profile_path': None,
#    'credit_id': '52fe4508c3a36847f80b85a7',
#    'department': 'Sound',
#    'job': 'Original Music Composer'},
#   {'adult': False,
#    'gender': 0,
#    'id': 17379,
#    'known_for_department': 'Editing',
#    'name': 'Cheng Long',
#    'original_name': 'Cheng Long',
#    'popularity': 0.6,
#    'profile_path': None,
#    'credit_id': '5feb5faea14e10003b1a4483',
#    'department': 'Editing',
#    'job': 'Editor'},
#   {'adult': False,
#    'gender': 1,
#    'id': 21907,
#    'known_for_department': 'Costume & Make-Up',
#    'name': 'Emi Wada',
#    'original_name': 'Emi Wada',
#    'popularity': 1.4,
#    'profile_path': '/uY8XgNflHlyYsYDBGdA0uiBArAC.jpg',
#    'credit_id': '598b5da69251414bb40361c1',
#    'department': 'Costume & Make-Up',
#    'job': 'Costume Design'},
#   {'adult': False,
#    'gender': 0,
#    'id': 28095,
#    'known_for_department': 'Visual Effects',
#    'name': 'Eddy Wong',
#    'original_name': 'Eddy Wong',
#    'popularity': 0.764,
#    'profile_path': None,
#    'credit_id': '62526762fd6300489b61b325',
#    'department': 'Visual Effects',
#    'job': 'Visual Effects Supervisor'},
#   {'adult': False,
#    'gender': 2,
#    'id': 57913,
#    'known_for_department': 'Camera',
#    'name': 'Zhao Xiaoding',
#    'original_name': 'Zhao Xiaoding',
#    'popularity': 2.391,
#    'profile_path': '/fIHt9A62ZVZcmrF8KirxOrg1CxQ.jpg',
#    'credit_id': '532ed9889251413a8500340a',
#    'department': 'Camera',
#    'job': 'Director of Photography'},
#   {'adult': False,
#    'gender': 0,
#    'id': 75151,
#    'known_for_department': 'Sound',
#    'name': 'Glenn Newnham',
#    'original_name': 'Glenn Newnham',
#    'popularity': 1.22,
#    'profile_path': None,
#    'credit_id': '625265dc09191b1351e6deae',
#    'department': 'Sound',
#    'job': 'Sound Editor'},
#   {'adult': False,
#    'gender': 2,
#    'id': 1292186,
#    'known_for_department': 'Sound',
#    'name': 'Roger Savage',
#    'original_name': 'Roger Savage',
#    'popularity': 0.921,
#    'profile_path': None,
#    'credit_id': '625265f256b9f7005035e82b',
#    'department': 'Sound',
#    'job': 'Sound Supervisor'},
#   {'adult': False,
#    'gender': 0,
#    'id': 1394754,
#    'known_for_department': 'Visual Effects',
#    'name': 'Kirsty Millar',
#    'original_name': 'Kirsty Millar',
#    'popularity': 0.6,
#    'profile_path': None,
#    'credit_id': '625266eb68b1ea00a6642916',
#    'department': 'Visual Effects',
#    'job': 'Visual Effects Supervisor'},
#   {'adult': False,
#    'gender': 0,
#    'id': 1395454,
#    'known_for_department': 'Visual Effects',
#    'name': 'Ineke Majoor',
#    'original_name': 'Ineke Majoor',
#    'popularity': 0.6,
#    'profile_path': None,
#    'credit_id': '625266d5a055ef47c7954cad',
#    'department': 'Visual Effects',
#    'job': 'Visual Effects Producer'},
#   {'adult': False,
#    'gender': 0,
#    'id': 1401698,
#    'known_for_department': 'Visual Effects',
#    'name': 'Andy Brown',
#    'original_name': 'Andy Brown',
#    'popularity': 0.828,
#    'profile_path': None,
#    'credit_id': '62526651c7a7e01269dc99f7',
#    'department': 'Visual Effects',
#    'job': 'Visual Effects Supervisor'},
#   {'adult': False,
#    'gender': 2,
#    'id': 1402931,
#    'known_for_department': 'Visual Effects',
#    'name': 'David Booth',
#    'original_name': 'David Booth',
#    'popularity': 1.4,
#    'profile_path': None,
#    'credit_id': '6252661f68b1ea134eb2de27',
#    'department': 'Visual Effects',
#    'job': 'Visual Effects'},
#   {'adult': False,
#    'gender': 0,
#    'id': 1411234,
#    'known_for_department': 'Visual Effects',
#    'name': 'Kent Boswell',
#    'original_name': 'Kent Boswell',
#    'popularity': 0.6,
#    'profile_path': None,
#    'credit_id': '625266368e2e000e2a51c3b6',
#    'department': 'Visual Effects',
#    'job': 'Visual Effects Production Manager'},
#   {'adult': False,
#    'gender': 0,
#    'id': 1418300,
#    'known_for_department': 'Visual Effects',
#    'name': 'Murray Pope',
#    'original_name': 'Murray Pope',
#    'popularity': 0.6,
#    'profile_path': None,
#    'credit_id': '625267222f1be038ab6b3482',
#    'department': 'Visual Effects',
#    'job': 'Visual Effects Producer'},
#   {'adult': False,
#    'gender': 0,
#    'id': 1438651,
#    'known_for_department': 'Visual Effects',
#    'name': 'Naomi Mitchell',
#    'original_name': 'Naomi Mitchell',
#    'popularity': 0.6,
#    'profile_path': None,
#    'credit_id': '62526703447f9c0067b58eed',
#    'department': 'Visual Effects',
#    'job': 'Visual Effects Producer'},
#   {'adult': False,
#    'gender': 0,
#    'id': 1445951,
#    'known_for_department': 'Costume & Make-Up',
#    'name': 'Yang Xiaohai',
#    'original_name': 'Yang Xiaohai',
#    'popularity': 0.6,
#    'profile_path': None,
#    'credit_id': '6252657791b53000667fddce',
#    'department': 'Costume & Make-Up',
#    'job': 'Makeup Artist'},
#   {'adult': False,
#    'gender': 2,
#    'id': 1445966,
#    'known_for_department': 'Sound',
#    'name': 'Jing Tao',
#    'original_name': 'Jing Tao',
#    'popularity': 1.788,
#    'profile_path': None,
#    'credit_id': '62526606fd630047e01ef692',
#    'department': 'Sound',
#    'job': 'Sound'},
#   {'adult': False,
#    'gender': 0,
#    'id': 1646255,
#    'known_for_department': 'Sound',
#    'name': 'Jo Mion',
#    'original_name': 'Jo Mion',
#    'popularity': 0.6,
#    'profile_path': None,
#    'credit_id': '625265c52f1be02fa9b6f49f',
#    'department': 'Sound',
#    'job': 'Sound Editor'},
#   {'adult': False,
#    'gender': 0,
#    'id': 1758847,
#    'known_for_department': 'Visual Effects',
#    'name': 'Victor Wong',
#    'original_name': 'Victor Wong',
#    'popularity': 0.6,
#    'profile_path': None,
#    'credit_id': '6252677f09191b00a08ceeb9',
#    'department': 'Visual Effects',
#    'job': 'Visual Effects Supervisor'},
#   {'adult': False,
#    'gender': 0,
#    'id': 2096072,
#    'known_for_department': 'Art',
#    'name': 'Bin Zhao',
#    'original_name': 'Bin Zhao',
#    'popularity': 0.6,
#    'profile_path': None,
#    'credit_id': '6252653067e0f70068b85d18',
#    'department': 'Art',
#    'job': 'Art Direction'},
#   {'adult': False,
#    'gender': 2,
#    'id': 2150045,
#    'known_for_department': 'Acting',
#    'name': 'Feng Li',
#    'original_name': 'Feng Li',
#    'popularity': 0.6,
#    'profile_path': None,
#    'credit_id': '6549eedb6beaea00c9fdcfa9',
#    'department': 'Writing',
#    'job': 'Scenario Writer'},
#   {'adult': False,
#    'gender': 2,
#    'id': 2500020,
#    'known_for_department': 'Visual Effects',
#    'name': 'Kang Jong-ik',
#    'original_name': 'Kang Jong-ik',
#    'popularity': 0.6,
#    'profile_path': None,
#    'credit_id': '625266918258fc0051bb390a',
#    'department': 'Visual Effects',
#    'job': 'Visual Effects Supervisor'},
#   {'adult': False,
#    'gender': 0,
#    'id': 2711815,
#    'known_for_department': 'Visual Effects',
#    'name': 'Fiona Crawford',
#    'original_name': 'Fiona Crawford',
#    'popularity': 0.84,
#    'profile_path': None,
#    'credit_id': '6252666b8e2e000e2a51c477',
#    'department': 'Visual Effects',
#    'job': 'Visual Effects Producer'},
#   {'adult': False,
#    'gender': 0,
#    'id': 2752857,
#    'known_for_department': 'Sound',
#    'name': 'Vic Kaspar',
#    'original_name': 'Vic Kaspar',
#    'popularity': 0.988,
#    'profile_path': None,
#    'credit_id': '625265b18e2e00006a4ee182',
#    'department': 'Sound',
#    'job': 'Sound Editor'},
#   {'adult': False,
#    'gender': 2,
#    'id': 3500547,
#    'known_for_department': 'Art',
#    'name': 'Han Zhong',
#    'original_name': 'Han Zhong',
#    'popularity': 0.6,
#    'profile_path': None,
#    'credit_id': '62526506904f6d0dd5979a79',
#    'department': 'Art',
#    'job': 'Supervising Art Director'},
#   {'adult': False,
#    'gender': 0,
#    'id': 3500551,
#    'known_for_department': 'Visual Effects',
#    'name': 'Angie Lam',
#    'original_name': 'Angie Lam',
#    'popularity': 0.6,
#    'profile_path': None,
#    'credit_id': '625266bc2f1be04a4ef8e1ea',
#    'department': 'Visual Effects',
#    'job': 'Visual Effects Supervisor'}]}

# %%
# Howl's Moving Castle request
# Save a movie title to search for as a variable
movie_title = "Howl's Moving Castle"

# Concatenate request_url, title, and api_key. Store as new variable
request_url = f"https://api.themoviedb.org/3/search/movie?api_key={api_key}&query={movie_title}"


# Execute get request
response = requests.get(request_url)


# Get movie ID
movie_data = response.json()
movie_id = movie_data['results'][0]['id']


# Call get_credits function
get_movie_credits(movie_id, api_key)
# Out:
# {'id': 4935,
#  'cast': [{'adult': False,
#    'gender': 1,
#    'id': 533325,
#    'known_for_department': 'Acting',
#    'name': 'Chieko Baisho',
#    'original_name': 'Chieko Baisho',
#    'popularity': 8.128,
#    'profile_path': '/b8ANR4WfdUZtoU4ktlnMFzbq759.jpg',
#    'cast_id': 220,
#    'character': 'Sophie (voice)',
#    'credit_id': '5dfef0f665686e001893f35f',
#    'order': 0},
#   {'adult': False,
#    'gender': 2,
#    'id': 12670,
#    'known_for_department': 'Acting',
#    'name': 'Takuya Kimura',
#    'original_name': 'Takuya Kimura',
#    'popularity': 16.558,
#    'profile_path': '/sswCg8kvFsgSaVJwcIKKe4K7jOe.jpg',
#    'cast_id': 221,
#    'character': 'Howl (voice)',
#    'credit_id': '5dfef1079824c80015e114c7',
#    'order': 1},
#   {'adult': False,
#    'gender': 2,
#    'id': 20338,
#    'known_for_department': 'Acting',
#    'name': 'Akihiro Miwa',
#    'original_name': 'Akihiro Miwa',
#    'popularity': 5.142,
#    'profile_path': '/pCfBeLJigKnUWOAy7hsdBR7K0UV.jpg',
#    'cast_id': 222,
#    'character': 'Witch of the Waste (voice)',
#    'credit_id': '5dfef125d1a8930012887548',
#    'order': 2},
#   {'adult': False,
#    'gender': 2,
#    'id': 19592,
#    'known_for_department': 'Acting',
#    'name': 'Tatsuya Gashûin',
#    'original_name': 'Tatsuya Gashûin',
#    'popularity': 3.515,
#    'profile_path': '/fLqIdkShknsJmZy4EfBWuWyHN4C.jpg',
#    'cast_id': 223,
#    'character': 'Calcifer (voice)',
#    'credit_id': '5dfef134d1a8930019893ef0',
#    'order': 3},
#   {'adult': False,
#    'gender': 2,
#    'id': 225730,
#    'known_for_department': 'Acting',
#    'name': 'Ryunosuke Kamiki',
#    'original_name': 'Ryunosuke Kamiki',
#    'popularity': 15.507,
#    'profile_path': '/ut7ewXjdgUmgkhJ1EtbOo9tbc7s.jpg',
#    'cast_id': 224,
#    'character': 'Markl (voice)',
#    'credit_id': '5dfef14726dac1001260dba7',
#    'order': 4},
#   {'adult': False,
#    'gender': 2,
#    'id': 40449,
#    'known_for_department': 'Acting',
#    'name': 'Mitsunori Isaki',
#    'original_name': 'Mitsunori Isaki',
#    'popularity': 1.773,
#    'profile_path': '/qg7TOjxWW2UMvUJglQ7fyLlE3gI.jpg',
#    'cast_id': 249,
#    'character': 'Kosho (voice)',
#    'credit_id': '642548ad8de0ae01134e3469',
#    'order': 5},
#   {'adult': False,
#    'gender': 2,
#    'id': 40450,
#    'known_for_department': 'Acting',
#    'name': 'Yo Oizumi',
#    'original_name': 'Yo Oizumi',
#    'popularity': 23.339,
#    'profile_path': '/qw5KLuww2AEAk6JEssEkJY3wBn1.jpg',
#    'cast_id': 228,
#    'character': 'Prince Justin / Turnip Head (voice)',
#    'credit_id': '5dfef1f59824c80017e154b3',
#    'order': 6},
#   {'adult': False,
#    'gender': 2,
#    'id': 40451,
#    'known_for_department': 'Acting',
#    'name': 'Akio Otsuka',
#    'original_name': 'Akio Otsuka',
#    'popularity': 18.217,
#    'profile_path': '/fBgebh93VAJC9lIVdB8JmFtdixL.jpg',
#    'cast_id': 230,
#    'character': 'King of Ingary (voice)',
#    'credit_id': '5dfef21665686e001893f508',
#    'order': 7},
#   {'adult': False,
#    'gender': 2,
#    'id': 40452,
#    'known_for_department': 'Acting',
#    'name': 'Daijirô Harada',
#    'original_name': 'Daijirô Harada',
#    'popularity': 12.438,
#    'profile_path': '/i1r0vuDmUgz7LgqR1qXkP0vO9MH.jpg',
#    'cast_id': 231,
#    'character': 'Heen (voice)',
#    'credit_id': '5dfef24bd1a89300198941f6',
#    'order': 8},
#   {'adult': False,
#    'gender': 1,
#    'id': 40453,
#    'known_for_department': 'Acting',
#    'name': 'Haruko Katō',
#    'original_name': 'Haruko Katō',
#    'popularity': 6.004,
#    'profile_path': '/WyeP5PbPEDeQI83Mq1NYwB87mk.jpg',
#    'cast_id': 225,
#    'character': 'Madame Suliman (voice)',
#    'credit_id': '5dfef15a26dac1001461c1ad',
#    'order': 9},
#   {'adult': False,
#    'gender': 2,
#    'id': 1251324,
#    'known_for_department': 'Acting',
#    'name': 'Makoto Yasumura',
#    'original_name': 'Makoto Yasumura',
#    'popularity': 2.231,
#    'profile_path': '/22rs0o1A5rERY0HE6GsvSRAIBdg.jpg',
#    'cast_id': 250,
#    'character': '(voice)',
#    'credit_id': '64254978c04429026b121f57',
#    'order': 10},
#   {'adult': False,
#    'gender': 2,
#    'id': 1253093,
#    'known_for_department': 'Acting',
#    'name': 'Manabu Muraji',
#    'original_name': 'Manabu Muraji',
#    'popularity': 3.776,
#    'profile_path': '/l3YxHOtIEWjULyol8A36xLfBZKN.jpg',
#    'cast_id': 251,
#    'character': '(voice)',
#    'credit_id': '6425498ec04429026b121f5e',
#    'order': 11},
#   {'adult': False,
#    'gender': 1,
#    'id': 2844828,
#    'known_for_department': 'Acting',
#    'name': 'Keiko Tsukamoto',
#    'original_name': 'Keiko Tsukamoto',
#    'popularity': 1.4,
#    'profile_path': None,
#    'cast_id': 252,
#    'character': '(voice)',
#    'credit_id': '64254999a3e4ba00f23334a8',
#    'order': 12},
#   {'adult': False,
#    'gender': 1,
#    'id': 2023580,
#    'known_for_department': 'Acting',
#    'name': 'Yayoi Kazuki',
#    'original_name': 'Yayoi Kazuki',
#    'popularity': 0.934,
#    'profile_path': None,
#    'cast_id': 226,
#    'character': '(voice)',
#    'credit_id': '5dfef16b9824c80015e1150c',
#    'order': 13},
#   {'adult': False,
#    'gender': 2,
#    'id': 1246258,
#    'known_for_department': 'Acting',
#    'name': 'Seiji Sasaki',
#    'original_name': 'Seiji Sasaki',
#    'popularity': 1.733,
#    'profile_path': '/iPEfwEUZdBagnEVEiSx18IL4aA3.jpg',
#    'cast_id': 253,
#    'character': '(voice)',
#    'credit_id': '642549eaa3e4ba00f23334c8',
#    'order': 14},
#   {'adult': False,
#    'gender': 2,
#    'id': 1252722,
#    'known_for_department': 'Acting',
#    'name': 'Hiroshi Takahashi',
#    'original_name': 'Hiroshi Takahashi',
#    'popularity': 0.6,
#    'profile_path': None,
#    'cast_id': 254,
#    'character': '(voice)',
#    'credit_id': '64254a30960cde0126336283',
#    'order': 15},
#   {'adult': False,
#    'gender': 1,
#    'id': 1253451,
#    'known_for_department': 'Acting',
#    'name': 'Mayuno Yasokawa',
#    'original_name': 'Mayuno Yasokawa',
#    'popularity': 1.4,
#    'profile_path': '/nnyAx35H2LKQ7OC0Qwc6BleA9xu.jpg',
#    'cast_id': 227,
#    'character': '(voice)',
#    'credit_id': '5dfef17c26dac100176174dc',
#    'order': 16},
#   {'adult': False,
#    'gender': 1,
#    'id': 71644,
#    'known_for_department': 'Acting',
#    'name': 'Rio Kanno',
#    'original_name': 'Rio Kanno',
#    'popularity': 6.082,
#    'profile_path': '/5H4tWYZGCex99MYzKO1EZ8CAzUp.jpg',
#    'cast_id': 229,
#    'character': '(voice)',
#    'credit_id': '5dfef205d1a8930012887797',
#    'order': 17},
#   {'adult': False,
#    'gender': 2,
#    'id': 3985888,
#    'known_for_department': 'Acting',
#    'name': 'Kojiro Takahashi',
#    'original_name': 'Kojiro Takahashi',
#    'popularity': 0.6,
#    'profile_path': None,
#    'cast_id': 255,
#    'character': '(voice)',
#    'credit_id': '64254a816905fb0077f02ddd',
#    'order': 18},
#   {'adult': False,
#    'gender': 2,
#    'id': 3985890,
#    'known_for_department': 'Acting',
#    'name': 'Akiyoshi Sakurai',
#    'original_name': 'Akiyoshi Sakurai',
#    'popularity': 0.6,
#    'profile_path': None,
#    'cast_id': 256,
#    'character': '(voice)',
#    'credit_id': '64254af9960cde01263362e1',
#    'order': 19},
#   {'adult': False,
#    'gender': 1,
#    'id': 3677798,
#    'known_for_department': 'Acting',
#    'name': 'Momoko Kurita',
#    'original_name': 'Momoko Kurita',
#    'popularity': 0.6,
#    'profile_path': None,
#    'cast_id': 257,
#    'character': '(voice)',
#    'credit_id': '64254b436905fb01032217cf',
#    'order': 20},
#   {'adult': False,
#    'gender': 1,
#    'id': 2856721,
#    'known_for_department': 'Acting',
#    'name': 'Mina Meguro',
#    'original_name': 'Mina Meguro',
#    'popularity': 0.679,
#    'profile_path': '/mx1n8cmUTMT0oZH4zyqo3zx84MN.jpg',
#    'cast_id': 258,
#    'character': '(voice)',
#    'credit_id': '64254b58c044290298cda117',
#    'order': 21},
#   {'adult': False,
#    'gender': 2,
#    'id': 3985894,
#    'known_for_department': 'Acting',
#    'name': 'Yasuhiro Ohara',
#    'original_name': 'Yasuhiro Ohara',
#    'popularity': 0.6,
#    'profile_path': None,
#    'cast_id': 259,
#    'character': '(voice)',
#    'credit_id': '64254b7dc0442902130490a3',
#    'order': 22},
#   {'adult': False,
#    'gender': 2,
#    'id': 3985895,
#    'known_for_department': 'Acting',
#    'name': 'Akio Tanaka',
#    'original_name': 'Akio Tanaka',
#    'popularity': 0.6,
#    'profile_path': None,
#    'cast_id': 260,
#    'character': '(voice)',
#    'credit_id': '64254bc037b3a9009777cd65',
#    'order': 23},
#   {'adult': False,
#    'gender': 1,
#    'id': 2856737,
#    'known_for_department': 'Acting',
#    'name': 'Rina Yamada',
#    'original_name': 'Rina Yamada',
#    'popularity': 1.38,
#    'profile_path': None,
#    'cast_id': 261,
#    'character': '(voice)',
#    'credit_id': '64254bf5a3e4ba0077922980',
#    'order': 24},
#   {'adult': False,
#    'gender': 1,
#    'id': 1247802,
#    'known_for_department': 'Acting',
#    'name': 'Tomoe Hanba',
#    'original_name': 'Tomoe Hanba',
#    'popularity': 3.856,
#    'profile_path': '/tj3HV3vbvfY53SjG1XQjyqa6hyE.jpg',
#    'cast_id': 262,
#    'character': '(voice)',
#    'credit_id': '64254c0b960cde00e0bba949',
#    'order': 25},
#   {'adult': False,
#    'gender': 0,
#    'id': 2856725,
#    'known_for_department': 'Acting',
#    'name': 'Naoto Kaji',
#    'original_name': 'Naoto Kaji',
#    'popularity': 0.656,
#    'profile_path': None,
#    'cast_id': 263,
#    'character': '(voice)',
#    'credit_id': '64254c1a37b3a900b6bc1e57',
#    'order': 26},
#   {'adult': False,
#    'gender': 2,
#    'id': 3131047,
#    'known_for_department': 'Acting',
#    'name': 'Teruo Seki',
#    'original_name': 'Teruo Seki',
#    'popularity': 1.4,
#    'profile_path': '/cbQIunOxd5jWfCqWvoN8nVnP408.jpg',
#    'cast_id': 264,
#    'character': '(voice)',
#    'credit_id': '64254c21c0442902130490e8',
#    'order': 27},
#   {'adult': False,
#    'gender': 0,
#    'id': 2856724,
#    'known_for_department': 'Acting',
#    'name': 'Shinobu Katabuchi',
#    'original_name': 'Shinobu Katabuchi',
#    'popularity': 0.6,
#    'profile_path': None,
#    'cast_id': 265,
#    'character': '(voice)',
#    'credit_id': '64254c318de0ae00978ba91e',
#    'order': 28},
#   {'adult': False,
#    'gender': 1,
#    'id': 3985896,
#    'known_for_department': 'Acting',
#    'name': 'Masako Inui',
#    'original_name': 'Masako Inui',
#    'popularity': 0.6,
#    'profile_path': None,
#    'cast_id': 266,
#    'character': '(voice)',
#    'credit_id': '64254c4e8de0ae01134e3665',
#    'order': 29},
#   {'adult': False,
#    'gender': 2,
#    'id': 1253081,
#    'known_for_department': 'Acting',
#    'name': 'Yohei Ohbayashi',
#    'original_name': 'Yohei Ohbayashi',
#    'popularity': 1.818,
#    'profile_path': None,
#    'cast_id': 267,
#    'character': '(voice)',
#    'credit_id': '64254c82a3e4ba00779229b9',
#    'order': 30},
#   {'adult': False,
#    'gender': 2,
#    'id': 3985900,
#    'known_for_department': 'Acting',
#    'name': 'Takeshi Miyajima',
#    'original_name': 'Takeshi Miyajima',
#    'popularity': 0.6,
#    'profile_path': None,
#    'cast_id': 268,
#    'character': '(voice)',
#    'credit_id': '64254ce037b3a9011365549c',
#    'order': 31},
#   {'adult': False,
#    'gender': 1,
#    'id': 3320560,
#    'known_for_department': 'Acting',
#    'name': 'Yukiko Mizuochi',
#    'original_name': 'Yukiko Mizuochi',
#    'popularity': 0.6,
#    'profile_path': None,
#    'cast_id': 269,
#    'character': '(voice)',
#    'credit_id': '64254d20960cde00bdbb2495',
#    'order': 32},
#   {'adult': True,
#    'gender': 1,
#    'id': 2347660,
#    'known_for_department': 'Acting',
#    'name': 'Maki Koizumi',
#    'original_name': 'Maki Koizumi',
#    'popularity': 0.6,
#    'profile_path': '/28Iqrf5oJOYxDOZCE3axi9uOzXV.jpg',
#    'cast_id': 270,
#    'character': '(voice)',
#    'credit_id': '64254d3a6905fb01032218c4',
#    'order': 33},
#   {'adult': False,
#    'gender': 2,
#    'id': 3985902,
#    'known_for_department': 'Acting',
#    'name': 'Nobito Nishioka',
#    'original_name': 'Nobito Nishioka',
#    'popularity': 0.6,
#    'profile_path': None,
#    'cast_id': 271,
#    'character': '(voice)',
#    'credit_id': '64254d7f960cde0126336405',
#    'order': 34},
#   {'adult': False,
#    'gender': 2,
#    'id': 3985905,
#    'known_for_department': 'Acting',
#    'name': 'Teppei Akashi',
#    'original_name': 'Teppei Akashi',
#    'popularity': 0.6,
#    'profile_path': None,
#    'cast_id': 272,
#    'character': '(voice)',
#    'credit_id': '64254dbe6905fb0103221907',
#    'order': 35},
#   {'adult': False,
#    'gender': 1,
#    'id': 3985908,
#    'known_for_department': 'Acting',
#    'name': 'Reiko Onishi',
#    'original_name': 'Reiko Onishi',
#    'popularity': 0.6,
#    'profile_path': None,
#    'cast_id': 273,
#    'character': '(voice)',
#    'credit_id': '64254dd8a3e4ba011148f115',
#    'order': 36},
#   {'adult': False,
#    'gender': 1,
#    'id': 3985910,
#    'known_for_department': 'Acting',
#    'name': 'Yumiko Ogata',
#    'original_name': 'Yumiko Ogata',
#    'popularity': 0.6,
#    'profile_path': None,
#    'cast_id': 274,
#    'character': '(voice)',
#    'credit_id': '64254dfc6905fb009ad74d10',
#    'order': 37},
#   {'adult': False,
#    'gender': 2,
#    'id': 3985911,
#    'known_for_department': 'Acting',
#    'name': 'Hiroyuki Kamikawaji',
#    'original_name': 'Hiroyuki Kamikawaji',
#    'popularity': 0.6,
#    'profile_path': None,
#    'cast_id': 275,
#    'character': '(voice)',
#    'credit_id': '64254e326905fb00e054db7f',
#    'order': 38},
#   {'adult': False,
#    'gender': 2,
#    'id': 3721955,
#    'known_for_department': 'Acting',
#    'name': 'Tomohiko Kiyota',
#    'original_name': 'Tomohiko Kiyota',
#    'popularity': 0.6,
#    'profile_path': None,
#    'cast_id': 276,
#    'character': '(voice)',
#    'credit_id': '64254e5537b3a900d5f9230d',
#    'order': 39},
#   {'adult': False,
#    'gender': 1,
#    'id': 3985917,
#    'known_for_department': 'Acting',
#    'name': 'Kaori Kaneko',
#    'original_name': 'Kaori Kaneko',
#    'popularity': 0.6,
#    'profile_path': None,
#    'cast_id': 277,
#    'character': '(voice)',
#    'credit_id': '64254ea9a3e4ba00d3ac99b4',
#    'order': 40},
#   {'adult': False,
#    'gender': 1,
#    'id': 3985918,
#    'known_for_department': 'Acting',
#    'name': 'Aiko Nakajima',
#    'original_name': 'Aiko Nakajima',
#    'popularity': 0.98,
#    'profile_path': None,
#    'cast_id': 278,
#    'character': '(voice)',
#    'credit_id': '64254f126905fb00e054dbd5',
#    'order': 41},
#   {'adult': False,
#    'gender': 2,
#    'id': 3985920,
#    'known_for_department': 'Acting',
#    'name': 'Jun Kuwahara',
#    'original_name': 'Jun Kuwahara',
#    'popularity': 0.6,
#    'profile_path': None,
#    'cast_id': 279,
#    'character': '(voice)',
#    'credit_id': '64254f4b37b3a900b6bc1f93',
#    'order': 42},
#   {'adult': False,
#    'gender': 2,
#    'id': 2084077,
#    'known_for_department': 'Acting',
#    'name': 'Yuta Kobayashi',
#    'original_name': 'Yuta Kobayashi',
#    'popularity': 0.6,
#    'profile_path': None,
#    'cast_id': 280,
#    'character': '(voice)',
#    'credit_id': '64254f9ac044290213049233',
#    'order': 43},
#   {'adult': False,
#    'gender': 1,
#    'id': 3985921,
#    'known_for_department': 'Acting',
#    'name': 'Yuko Nomura',
#    'original_name': 'Yuko Nomura',
#    'popularity': 0.6,
#    'profile_path': None,
#    'cast_id': 281,
#    'character': '(voice)',
#    'credit_id': '64254ff2960cde01263364ed',
#    'order': 44},
#   {'adult': False,
#    'gender': 1,
#    'id': 3985922,
#    'known_for_department': 'Acting',
#    'name': 'Tamayo Fukushi',
#    'original_name': 'Tamayo Fukushi',
#    'popularity': 0.6,
#    'profile_path': None,
#    'cast_id': 282,
#    'character': '(voice)',
#    'credit_id': '6425500f8de0ae00978baae5',
#    'order': 45},
#   {'adult': False,
#    'gender': 2,
#    'id': 3985923,
#    'known_for_department': 'Acting',
#    'name': 'Atsushi Takeya',
#    'original_name': 'Atsushi Takeya',
#    'popularity': 0.6,
#    'profile_path': None,
#    'cast_id': 283,
#    'character': '(voice)',
#    'credit_id': '6425502f960cde00e0bbab23',
#    'order': 46},
#   {'adult': False,
#    'gender': 2,
#    'id': 3985924,
#    'known_for_department': 'Acting',
#    'name': 'Yoshifumi Nakagawa',
#    'original_name': 'Yoshifumi Nakagawa',
#    'popularity': 0.6,
#    'profile_path': None,
#    'cast_id': 284,
#    'character': '(voice)',
#    'credit_id': '6425504f6905fb0126084752',
#    'order': 47},
#   {'adult': False,
#    'gender': 2,
#    'id': 2539433,
#    'known_for_department': 'Acting',
#    'name': 'Hiroki Tanaka',
#    'original_name': 'Hiroki Tanaka',
#    'popularity': 2.434,
#    'profile_path': '/387S6uoYHEYENMia2iUophTLSRm.jpg',
#    'cast_id': 286,
#    'character': '(voice)',
#    'credit_id': '642550958de0ae01134e38af',
#    'order': 48},
#   {'adult': False,
#    'gender': 2,
#    'id': 1810263,
#    'known_for_department': 'Acting',
#    'name': 'Yohei Matsukado',
#    'original_name': 'Yohei Matsukado',
#    'popularity': 1.129,
#    'profile_path': None,
#    'cast_id': 287,
#    'character': '(voice)',
#    'credit_id': '642550ffa3e4ba00f2333811',
#    'order': 49},
#   {'adult': False,
#    'gender': 1,
#    'id': 3985926,
#    'known_for_department': 'Acting',
#    'name': 'Akane Fujisaki',
#    'original_name': 'Akane Fujisaki',
#    'popularity': 0.6,
#    'profile_path': None,
#    'cast_id': 289,
#    'character': '(voice)',
#    'credit_id': '6425517f8de0ae00b653312c',
#    'order': 50},
#   {'adult': False,
#    'gender': 1,
#    'id': 1777997,
#    'known_for_department': 'Acting',
#    'name': 'Izumi Matsuoka',
#    'original_name': 'Izumi Matsuoka',
#    'popularity': 2.804,
#    'profile_path': None,
#    'cast_id': 292,
#    'character': '(voice)',
#    'credit_id': '642552528de0ae00f4be9050',
#    'order': 51},
#   {'adult': False,
#    'gender': 2,
#    'id': 3985928,
#    'known_for_department': 'Acting',
#    'name': 'Tomonori Yanagibashi',
#    'original_name': 'Tomonori Yanagibashi',
#    'popularity': 0.6,
#    'profile_path': None,
#    'cast_id': 290,
#    'character': '(voice)',
#    'credit_id': '642551ed37b3a900d5f9247e',
#    'order': 52},
#   {'adult': False,
#    'gender': 2,
#    'id': 1039220,
#    'known_for_department': 'Acting',
#    'name': 'Ken Yasuda',
#    'original_name': 'Ken Yasuda',
#    'popularity': 7.972,
#    'profile_path': '/mSEnXFHj8MnighBVG0yZdKOVyxI.jpg',
#    'cast_id': 293,
#    'character': '(voice)',
#    'credit_id': '64255286960cde00bdbb2685',
#    'order': 53},
#   {'adult': False,
#    'gender': 2,
#    'id': 1060300,
#    'known_for_department': 'Acting',
#    'name': 'Hiroyuki Morisaki',
#    'original_name': 'Hiroyuki Morisaki',
#    'popularity': 2.621,
#    'profile_path': '/ru4N8FltqkZBvtVTTEmnroIinP7.jpg',
#    'cast_id': 285,
#    'character': '(voice)',
#    'credit_id': '64255060a3e4ba0077922b0c',
#    'order': 54},
#   {'adult': False,
#    'gender': 2,
#    'id': 1251804,
#    'known_for_department': 'Acting',
#    'name': 'Shigeyuki Totsugi',
#    'original_name': 'Shigeyuki Totsugi',
#    'popularity': 4.721,
#    'profile_path': '/pK3B7H4qrzLy7nKr0lFKfqNRq91.jpg',
#    'cast_id': 288,
#    'character': '(voice)',
#    'credit_id': '64255116c0442901f0011b3e',
#    'order': 55},
#   {'adult': False,
#    'gender': 2,
#    'id': 1348016,
#    'known_for_department': 'Acting',
#    'name': 'Takuma Otoo',
#    'original_name': 'Takuma Otoo',
#    'popularity': 3.401,
#    'profile_path': '/vVWVFV8JJjQuLOdotFTAgGdFsEp.jpg',
#    'cast_id': 291,
#    'character': '(voice)',
#    'credit_id': '6425523c960cde007711b63e',
#    'order': 56}],
#  'crew': [{'adult': False,
#    'gender': 2,
#    'id': 608,
#    'known_for_department': 'Directing',
#    'name': 'Hayao Miyazaki',
#    'original_name': 'Hayao Miyazaki',
#    'popularity': 17.891,
#    'profile_path': '/mG3cfxtA5jqDc7fpKgyzZMKoXDh.jpg',
#    'credit_id': '52fe43e5c3a36847f8076c63',
#    'department': 'Writing',
#    'job': 'Screenplay'},
#   {'adult': False,
#    'gender': 2,
#    'id': 608,
#    'known_for_department': 'Directing',
#    'name': 'Hayao Miyazaki',
#    'original_name': 'Hayao Miyazaki',
#    'popularity': 17.891,
#    'profile_path': '/mG3cfxtA5jqDc7fpKgyzZMKoXDh.jpg',
#    'credit_id': '52fe43e5c3a36847f8076c5d',
#    'department': 'Directing',
#    'job': 'Director'},
#   {'adult': False,
#    'gender': 2,
#    'id': 608,
#    'known_for_department': 'Directing',
#    'name': 'Hayao Miyazaki',
#    'original_name': 'Hayao Miyazaki',
#    'popularity': 17.891,
#    'profile_path': '/mG3cfxtA5jqDc7fpKgyzZMKoXDh.jpg',
#    'credit_id': '52fe43e5c3a36847f8076cb9',
#    'department': 'Production',
#    'job': 'Executive Producer'},
#   {'adult': False,
#    'gender': 2,
#    'id': 636,
#    'known_for_department': 'Sound',
#    'name': 'Joe Hisaishi',
#    'original_name': 'Joe Hisaishi',
#    'popularity': 9.973,
#    'profile_path': '/dVxq90QHGMKBI3RpZYJlBVM59Nt.jpg',
#    'credit_id': '52fe43e5c3a36847f8076cc5',
#    'department': 'Sound',
#    'job': 'Original Music Composer'},
#   {'adult': False,
#    'gender': 2,
#    'id': 1417,
#    'known_for_department': 'Production',
#    'name': 'Toshio Suzuki',
#    'original_name': 'Toshio Suzuki',
#    'popularity': 11.53,
#    'profile_path': '/7jyzHtQScbQiPyNTP7aAQ9cF75u.jpg',
#    'credit_id': '52fe43e5c3a36847f8076cad',
#    'department': 'Production',
#    'job': 'Producer'},
#   {'adult': False,
#    'gender': 2,
#    'id': 19596,
#    'known_for_department': 'Camera',
#    'name': 'Atsushi Okui',
#    'original_name': 'Atsushi Okui',
#    'popularity': 1.927,
#    'profile_path': None,
#    'credit_id': '52fe43e5c3a36847f8076ccb',
#    'department': 'Camera',
#    'job': 'Director of Photography'},
#   {'adult': False,
#    'gender': 2,
#    'id': 1697,
#    'known_for_department': 'Editing',
#    'name': 'Takeshi Seyama',
#    'original_name': 'Takeshi Seyama',
#    'popularity': 3.0,
#    'profile_path': '/2ZoMQKCyNiUCYo8sy6pDIb30ViV.jpg',
#    'credit_id': '52fe43e5c3a36847f8076cd1',
#    'department': 'Editing',
#    'job': 'Editor'},
#   {'adult': False,
#    'gender': 2,
#    'id': 19598,
#    'known_for_department': 'Art',
#    'name': 'Yoji Takeshige',
#    'original_name': 'Yoji Takeshige',
#    'popularity': 2.025,
#    'profile_path': None,
#    'credit_id': '52fe43e5c3a36847f8076cd7',
#    'department': 'Art',
#    'job': 'Art Direction'},
#   {'adult': False,
#    'gender': 1,
#    'id': 19599,
#    'known_for_department': 'Visual Effects',
#    'name': 'Kaori Fujii',
#    'original_name': 'Kaori Fujii',
#    'popularity': 0.6,
#    'profile_path': None,
#    'credit_id': '55344a0cc3a36834430001cc',
#    'department': 'Visual Effects',
#    'job': 'Animation'},
#   {'adult': False,
#    'gender': 1,
#    'id': 19601,
#    'known_for_department': 'Visual Effects',
#    'name': 'Makiko Futaki',
#    'original_name': 'Makiko Futaki',
#    'popularity': 1.099,
#    'profile_path': None,
#    'credit_id': '55344a5592514125dc00264f',
#    'department': 'Visual Effects',
#    'job': 'Animation'},
#   {'adult': False,
#    'gender': 1,
#    'id': 19601,
#    'known_for_department': 'Visual Effects',
#    'name': 'Makiko Futaki',
#    'original_name': 'Makiko Futaki',
#    'popularity': 1.099,
#    'profile_path': None,
#    'credit_id': '638b7da87d5db50fb78bcb4f',
#    'department': 'Visual Effects',
#    'job': 'Key Animation'},
#   {'adult': False,
#    'gender': 1,
#    'id': 40222,
#    'known_for_department': 'Writing',
#    'name': 'Diana Wynne Jones',
#    'original_name': 'Diana Wynne Jones',
#    'popularity': 1.576,
#    'profile_path': None,
#    'credit_id': '52fe43e5c3a36847f8076ce3',
#    'department': 'Writing',
#    'job': 'Novel'},
#   {'adult': False,
#    'gender': 2,
#    'id': 40454,
#    'known_for_department': 'Production',
#    'name': 'Tomohiko Ishii',
#    'original_name': 'Tomohiko Ishii',
#    'popularity': 0.84,
#    'profile_path': '/v10jSYKmsTDkxX7pEg2khLpl2LR.jpg',
#    'credit_id': '52fe43e5c3a36847f8076cbf',
#    'department': 'Production',
#    'job': 'Producer'},
#   {'adult': False,
#    'gender': 2,
#    'id': 40455,
#    'known_for_department': 'Art',
#    'name': 'Noboru Yoshida',
#    'original_name': 'Noboru Yoshida',
#    'popularity': 1.74,
#    'profile_path': None,
#    'credit_id': '52fe43e5c3a36847f8076cdd',
#    'department': 'Art',
#    'job': 'Art Direction'},
#   {'adult': False,
#    'gender': 2,
#    'id': 78345,
#    'known_for_department': 'Visual Effects',
#    'name': 'Katsuya Kondo',
#    'original_name': 'Katsuya Kondo',
#    'popularity': 2.71,
#    'profile_path': '/su1v2UP7CbBORj8IeuoPIEdpQNL.jpg',
#    'credit_id': '5baacbd50e0a2664d000ff58',
#    'department': 'Visual Effects',
#    'job': 'Animation Supervisor'},
#   {'adult': False,
#    'gender': 2,
#    'id': 78345,
#    'known_for_department': 'Visual Effects',
#    'name': 'Katsuya Kondo',
#    'original_name': 'Katsuya Kondo',
#    'popularity': 2.71,
#    'profile_path': '/su1v2UP7CbBORj8IeuoPIEdpQNL.jpg',
#    'credit_id': '638b7d7b8d77c40086b0b601',
#    'department': 'Visual Effects',
#    'job': 'Key Animation'},
#   {'adult': False,
#    'gender': 2,
#    'id': 77938,
#    'known_for_department': 'Sound',
#    'name': 'Toru Noguchi',
#    'original_name': 'Toru Noguchi',
#    'popularity': 1.518,
#    'profile_path': None,
#    'credit_id': '61811ff9d236e600902b1a81',
#    'department': 'Sound',
#    'job': 'Sound Effects'},
#   {'adult': False,
#    'gender': 0,
#    'id': 78376,
#    'known_for_department': 'Production',
#    'name': 'Nozomu Takahashi',
#    'original_name': 'Nozomu Takahashi',
#    'popularity': 1.594,
#    'profile_path': None,
#    'credit_id': '5baaa67c0e0a2664cc00c430',
#    'department': 'Production',
#    'job': 'Production Manager'},
#   {'adult': False,
#    'gender': 2,
#    'id': 78378,
#    'known_for_department': 'Art',
#    'name': 'Naoya Tanaka',
#    'original_name': 'Naoya Tanaka',
#    'popularity': 2.415,
#    'profile_path': None,
#    'credit_id': '5baab3b80e0a2664d700cfbb',
#    'department': 'Art',
#    'job': 'Background Designer'},
#   {'adult': False,
#    'gender': 2,
#    'id': 34928,
#    'known_for_department': 'Visual Effects',
#    'name': 'Toshihiko Masuda',
#    'original_name': 'Toshihiko Masuda',
#    'popularity': 2.306,
#    'profile_path': None,
#    'credit_id': '5baabffd92514150ee00c507',
#    'department': 'Visual Effects',
#    'job': 'Key Animation'},
#   {'adult': False,
#    'gender': 2,
#    'id': 119237,
#    'known_for_department': 'Sound',
#    'name': 'Shuji Inoue',
#    'original_name': 'Shuji Inoue',
#    'popularity': 1.176,
#    'profile_path': None,
#    'credit_id': '5baaae3a925141510500aa88',
#    'department': 'Sound',
#    'job': 'Sound'},
#   {'adult': False,
#    'gender': 2,
#    'id': 119240,
#    'known_for_department': 'Sound',
#    'name': 'Kazuhiro Wakabayashi',
#    'original_name': 'Kazuhiro Wakabayashi',
#    'popularity': 1.687,
#    'profile_path': None,
#    'credit_id': '5baaae4bc3a3683a9c00c578',
#    'department': 'Sound',
#    'job': 'Sound Director'},
#   {'adult': False,
#    'gender': 2,
#    'id': 144476,
#    'known_for_department': 'Directing',
#    'name': 'Hiromasa Yonebayashi',
#    'original_name': 'Hiromasa Yonebayashi',
#    'popularity': 9.858,
#    'profile_path': '/bV0Xg5JHzTdcCDaLX7fKHn3gYH2.jpg',
#    'credit_id': '5baab5d792514150ff00b088',
#    'department': 'Visual Effects',
#    'job': 'Key Animation'},
#   {'adult': False,
#    'gender': 2,
#    'id': 547985,
#    'known_for_department': 'Art',
#    'name': 'Kazuo Oga',
#    'original_name': 'Kazuo Oga',
#    'popularity': 5.302,
#    'profile_path': None,
#    'credit_id': '5baab324c3a3683aaf00cd90',
#    'department': 'Art',
#    'job': 'Background Designer'},
#   {'adult': False,
#    'gender': 1,
#    'id': 548754,
#    'known_for_department': 'Editing',
#    'name': 'Rie Matsubara',
#    'original_name': 'Rie Matsubara',
#    'popularity': 2.037,
#    'profile_path': None,
#    'credit_id': '5baaa81c0e0a2664df00d522',
#    'department': 'Editing',
#    'job': 'Assistant Editor'},
#   {'adult': False,
#    'gender': 1,
#    'id': 555180,
#    'known_for_department': 'Acting',
#    'name': 'Yuko Sasaki',
#    'original_name': 'Yuko Sasaki',
#    'popularity': 5.274,
#    'profile_path': '/acaWGcmtdPC1Q0NmHcy7fvdjmUO.jpg',
#    'credit_id': '5baacb5c92514150ee00d8ac',
#    'department': 'Visual Effects',
#    'job': 'Animation'},
#   {'adult': False,
#    'gender': 2,
#    'id': 568034,
#    'known_for_department': 'Art',
#    'name': 'Junichi Taniguchi',
#    'original_name': 'Junichi Taniguchi',
#    'popularity': 1.303,
#    'profile_path': None,
#    'credit_id': '5baab1da0e0a2664d700cd2d',
#    'department': 'Art',
#    'job': 'Background Designer'},
#   {'adult': False,
#    'gender': 2,
#    'id': 934817,
#    'known_for_department': 'Sound',
#    'name': 'Mikio Mori',
#    'original_name': 'Mikio Mori',
#    'popularity': 0.6,
#    'profile_path': None,
#    'credit_id': '5baaa77a92514150ff009c92',
#    'department': 'Sound',
#    'job': 'Dolby Consultant'},
#   {'adult': False,
#    'gender': 0,
#    'id': 934821,
#    'known_for_department': 'Production',
#    'name': 'Hiroaki Hirabayashi',
#    'original_name': 'Hiroaki Hirabayashi',
#    'popularity': 0.6,
#    'profile_path': None,
#    'credit_id': '5baaa7f40e0a2664d000c4c3',
#    'department': 'Editing',
#    'job': 'Color Timer'},
#   {'adult': False,
#    'gender': 1,
#    'id': 937796,
#    'known_for_department': 'Art',
#    'name': 'Sayaka Hirahara',
#    'original_name': 'Sayaka Hirahara',
#    'popularity': 2.264,
#    'profile_path': None,
#    'credit_id': '5baab3eec3a3683a9c00d4be',
#    'department': 'Art',
#    'job': 'Background Designer'},
#   {'adult': False,
#    'gender': 2,
#    'id': 1222098,
#    'known_for_department': 'Visual Effects',
#    'name': 'Yuichi Tanaka',
#    'original_name': 'Yuichi Tanaka',
#    'popularity': 1.117,
#    'profile_path': None,
#    'credit_id': '5baac28d92514150eb00cf52',
#    'department': 'Visual Effects',
#    'job': 'Key Animation'},
#   {'adult': False,
#    'gender': 2,
#    'id': 1236311,
#    'known_for_department': 'Visual Effects',
#    'name': 'Kenji Hachizaki',
#    'original_name': 'Kenji Hachizaki',
#    'popularity': 2.55,
#    'profile_path': None,
#    'credit_id': '5baab78f0e0a2664d000dc6e',
#    'department': 'Visual Effects',
#    'job': 'Key Animation'},
#   {'adult': False,
#    'gender': 2,
#    'id': 1320964,
#    'known_for_department': 'Visual Effects',
#    'name': 'Takashi Hashimoto',
#    'original_name': 'Takashi Hashimoto',
#    'popularity': 2.573,
#    'profile_path': None,
#    'credit_id': '61e07d3cc175b20041cd7594',
#    'department': 'Visual Effects',
#    'job': 'Key Animation'},
#   {'adult': False,
#    'gender': 0,
#    'id': 1343979,
#    'known_for_department': 'Editing',
#    'name': 'Megumi Uchida',
#    'original_name': 'Megumi Uchida',
#    'popularity': 1.96,
#    'profile_path': None,
#    'credit_id': '5baaa8250e0a2664c900c33d',
#    'department': 'Editing',
#    'job': 'Assistant Editor'},
#   {'adult': False,
#    'gender': 1,
#    'id': 1352117,
#    'known_for_department': 'Editing',
#    'name': 'Kashiko Kimura',
#    'original_name': 'Kashiko Kimura',
#    'popularity': 1.62,
#    'profile_path': None,
#    'credit_id': '5baaa812c3a3683a9700c156',
#    'department': 'Editing',
#    'job': 'Assistant Editor'},
#   {'adult': False,
#    'gender': 0,
#    'id': 1399122,
#    'known_for_department': 'Sound',
#    'name': 'Gene Radzik',
#    'original_name': 'Gene Radzik',
#    'popularity': 0.6,
#    'profile_path': None,
#    'credit_id': '5baaafc2c3a3683ac900c816',
#    'department': 'Sound',
#    'job': 'Dolby Consultant'},
#   {'adult': False,
#    'gender': 2,
#    'id': 1399330,
#    'known_for_department': 'Visual Effects',
#    'name': 'Masaru Matsuse',
#    'original_name': 'Masaru Matsuse',
#    'popularity': 0.989,
#    'profile_path': None,
#    'credit_id': '5baab88a0e0a2664cc00e8a0',
#    'department': 'Visual Effects',
#    'job': 'Key Animation'},
#   {'adult': False,
#    'gender': 2,
#    'id': 1456609,
#    'known_for_department': 'Visual Effects',
#    'name': 'Hideki Hamasu',
#    'original_name': 'Hideki Hamasu',
#    'popularity': 1.618,
#    'profile_path': None,
#    'credit_id': '5baab5c50e0a2664df00ee48',
#    'department': 'Visual Effects',
#    'job': 'Key Animation'},
#   {'adult': False,
#    'gender': 2,
#    'id': 1456610,
#    'known_for_department': 'Visual Effects',
#    'name': 'Shunsuke Hirota',
#    'original_name': 'Shunsuke Hirota',
#    'popularity': 0.6,
#    'profile_path': None,
#    'credit_id': '5baaca000e0a2664c9010260',
#    'department': 'Visual Effects',
#    'job': 'Animation'},
#   {'adult': False,
#    'gender': 1,
#    'id': 1456614,
#    'known_for_department': 'Visual Effects',
#    'name': 'Megumi Kagawa',
#    'original_name': 'Megumi Kagawa',
#    'popularity': 1.652,
#    'profile_path': None,
#    'credit_id': '5baac0d00e0a2664cc00f347',
#    'department': 'Visual Effects',
#    'job': 'Key Animation'},
#   {'adult': False,
#    'gender': 0,
#    'id': 1456615,
#    'known_for_department': 'Visual Effects',
#    'name': 'Tsutomu Kurita',
#    'original_name': 'Tsutomu Kurita',
#    'popularity': 0.636,
#    'profile_path': None,
#    'credit_id': '5baac0be92514150ee00c6e0',
#    'department': 'Visual Effects',
#    'job': 'Key Animation'},
#   {'adult': False,
#    'gender': 2,
#    'id': 1456616,
#    'known_for_department': 'Visual Effects',
#    'name': 'Kitarou Kousaka',
#    'original_name': 'Kitarou Kousaka',
#    'popularity': 1.734,
#    'profile_path': '/wF0UPY9dL5U1ooszv2kAQVaUWjV.jpg',
#    'credit_id': '568924009251417e1500eb69',
#    'department': 'Visual Effects',
#    'job': 'Animation Director'},
#   {'adult': False,
#    'gender': 0,
#    'id': 1456620,
#    'known_for_department': 'Visual Effects',
#    'name': 'Kazuyoshi Onoda',
#    'original_name': 'Kazuyoshi Onoda',
#    'popularity': 0.685,
#    'profile_path': None,
#    'credit_id': '5baab7000e0a2664cc00e64a',
#    'department': 'Visual Effects',
#    'job': 'Key Animation'},
#   {'adult': False,
#    'gender': 2,
#    'id': 1456623,
#    'known_for_department': 'Visual Effects',
#    'name': 'Shinji Otsuka',
#    'original_name': 'Shinji Otsuka',
#    'popularity': 2.558,
#    'profile_path': None,
#    'credit_id': '5baac154c3a3683aaf00e03a',
#    'department': 'Visual Effects',
#    'job': 'Key Animation'},
#   {'adult': False,
#    'gender': 1,
#    'id': 1456624,
#    'known_for_department': 'Visual Effects',
#    'name': 'Sachiko Sugino',
#    'original_name': 'Sachiko Sugino',
#    'popularity': 0.6,
#    'profile_path': None,
#    'credit_id': '5baab91cc3a3683ac900dbac',
#    'department': 'Visual Effects',
#    'job': 'Key Animation'},
#   {'adult': False,
#    'gender': 2,
#    'id': 1456626,
#    'known_for_department': 'Visual Effects',
#    'name': 'Kenichi Yamada',
#    'original_name': 'Kenichi Yamada',
#    'popularity': 0.6,
#    'profile_path': None,
#    'credit_id': '5baab763c3a3683ac000eb48',
#    'department': 'Visual Effects',
#    'job': 'Key Animation'},
#   {'adult': False,
#    'gender': 2,
#    'id': 1456627,
#    'known_for_department': 'Visual Effects',
#    'name': 'Hiroomi Yamakawa',
#    'original_name': 'Hiroomi Yamakawa',
#    'popularity': 0.6,
#    'profile_path': None,
#    'credit_id': '5baab6b7925141510500ba14',
#    'department': 'Visual Effects',
#    'job': 'Key Animation'},
#   {'adult': False,
#    'gender': 2,
#    'id': 1456629,
#    'known_for_department': 'Visual Effects',
#    'name': 'Eiji Yamamori',
#    'original_name': 'Eiji Yamamori',
#    'popularity': 2.949,
#    'profile_path': None,
#    'credit_id': '5baab5ab0e0a2664d400d522',
#    'department': 'Visual Effects',
#    'job': 'Key Animation'},
#   {'adult': False,
#    'gender': 2,
#    'id': 1456630,
#    'known_for_department': 'Visual Effects',
#    'name': 'Masafumi Yokota',
#    'original_name': 'Masafumi Yokota',
#    'popularity': 1.399,
#    'profile_path': None,
#    'credit_id': '5baab80f0e0a2664da00d2b5',
#    'department': 'Visual Effects',
#    'job': 'Key Animation'},
#   {'adult': False,
#    'gender': 0,
#    'id': 1456631,
#    'known_for_department': 'Visual Effects',
#    'name': 'Hideaki Yoshio',
#    'original_name': 'Hideaki Yoshio',
#    'popularity': 0.759,
#    'profile_path': None,
#    'credit_id': '5baab5b7c3a3683ac000e892',
#    'department': 'Visual Effects',
#    'job': 'Key Animation'},
#   {'adult': False,
#    'gender': 2,
#    'id': 1456632,
#    'known_for_department': 'Visual Effects',
#    'name': 'Shinya Ohira',
#    'original_name': 'Shinya Ohira',
#    'popularity': 6.834,
#    'profile_path': '/m1ZKwGxAbXqwbaemNArFMLz8uph.jpg',
#    'credit_id': '5baab9540e0a2664d700dbc3',
#    'department': 'Visual Effects',
#    'job': 'Key Animation'},
#   {'adult': False,
#    'gender': 1,
#    'id': 1456633,
#    'known_for_department': 'Visual Effects',
#    'name': 'Atsuko Tanaka',
#    'original_name': 'Atsuko Tanaka',
#    'popularity': 2.154,
#    'profile_path': None,
#    'credit_id': '5baab52b92514150ff00afdd',
#    'department': 'Visual Effects',
#    'job': 'Key Animation'},
#   {'adult': False,
#    'gender': 1,
#    'id': 1456775,
#    'known_for_department': 'Art',
#    'name': 'Naomi Kasugai',
#    'original_name': 'Naomi Kasugai',
#    'popularity': 1.024,
#    'profile_path': None,
#    'credit_id': '5baab3abc3a3683a9c00d43a',
#    'department': 'Art',
#    'job': 'Background Designer'},
#   {'adult': False,
#    'gender': 2,
#    'id': 1456777,
#    'known_for_department': 'Visual Effects',
#    'name': 'Kenichi Konishi',
#    'original_name': 'Kenichi Konishi',
#    'popularity': 2.512,
#    'profile_path': '/bgPzpkbm3xjXd5ujTIq36kk6IEa.jpg',
#    'credit_id': '5baab755c3a3683ac900d91b',
#    'department': 'Visual Effects',
#    'job': 'Key Animation'},
#   {'adult': False,
#    'gender': 1,
#    'id': 1456778,
#    'known_for_department': 'Visual Effects',
#    'name': 'Mariko Matsuo',
#    'original_name': 'Mariko Matsuo',
#    'popularity': 0.621,
#    'profile_path': None,
#    'credit_id': '5baab7ff0e0a2664da00d2a1',
#    'department': 'Visual Effects',
#    'job': 'Key Animation'},
#   {'adult': False,
#    'gender': 0,
#    'id': 1456783,
#    'known_for_department': 'Visual Effects',
#    'name': 'Katsutoshi Nakamura',
#    'original_name': 'Katsutoshi Nakamura',
#    'popularity': 0.712,
#    'profile_path': None,
#    'credit_id': '5baac7ee0e0a2664c900fe65',
#    'department': 'Visual Effects',
#    'job': 'Animation'},
#   {'adult': False,
#    'gender': 0,
#    'id': 1456785,
#    'known_for_department': 'Art',
#    'name': 'Masako Osada',
#    'original_name': 'Masako Osada',
#    'popularity': 1.38,
#    'profile_path': None,
#    'credit_id': '5baab3850e0a2664c900d837',
#    'department': 'Art',
#    'job': 'Background Designer'},
#   {'adult': False,
#    'gender': 1,
#    'id': 1456791,
#    'known_for_department': 'Visual Effects',
#    'name': 'Masako Shinohara',
#    'original_name': 'Masako Shinohara',
#    'popularity': 2.221,
#    'profile_path': None,
#    'credit_id': '5baab81c925141510500bc1e',
#    'department': 'Visual Effects',
#    'job': 'Key Animation'},
#   {'adult': False,
#    'gender': 1,
#    'id': 1456794,
#    'known_for_department': 'Visual Effects',
#    'name': 'Keiko Tomizawa',
#    'original_name': 'Keiko Tomizawa',
#    'popularity': 1.4,
#    'profile_path': None,
#    'credit_id': '5baac7fd92514150f500e1ff',
#    'department': 'Visual Effects',
#    'job': 'Animation'},
#   {'adult': False,
#    'gender': 1,
#    'id': 1456795,
#    'known_for_department': 'Visual Effects',
#    'name': 'Michiyo Yasuda',
#    'original_name': 'Michiyo Yasuda',
#    'popularity': 1.4,
#    'profile_path': None,
#    'credit_id': '5baaa70b92514150f500aa55',
#    'department': 'Visual Effects',
#    'job': 'Color Designer'},
#   {'adult': False,
#    'gender': 1,
#    'id': 1456799,
#    'known_for_department': 'Art',
#    'name': 'Junko Ina',
#    'original_name': 'Junko Ina',
#    'popularity': 1.382,
#    'profile_path': None,
#    'credit_id': '5baab29492514150e800a5ca',
#    'department': 'Art',
#    'job': 'Background Designer'},
#   {'adult': False,
#    'gender': 0,
#    'id': 1456825,
#    'known_for_department': 'Visual Effects',
#    'name': 'Akihiko Adachi',
#    'original_name': 'Akihiko Adachi',
#    'popularity': 0.98,
#    'profile_path': None,
#    'credit_id': '553449f7c3a3682223005f26',
#    'department': 'Visual Effects',
#    'job': 'Animation'},
#   {'adult': False,
#    'gender': 0,
#    'id': 1456826,
#    'known_for_department': 'Visual Effects',
#    'name': 'Seiko Azuma',
#    'original_name': 'Seiko Azuma',
#    'popularity': 0.98,
#    'profile_path': None,
#    'credit_id': '55344a0192514125dc002640',
#    'department': 'Visual Effects',
#    'job': 'Animation'},
#   {'adult': False,
#    'gender': 0,
#    'id': 1460783,
#    'known_for_department': 'Visual Effects',
#    'name': 'Yoshitake Iwakami',
#    'original_name': 'Yoshitake Iwakami',
#    'popularity': 0.644,
#    'profile_path': None,
#    'credit_id': '5540b672c3a3681dab00170f',
#    'department': 'Visual Effects',
#    'job': 'Animation Manager'},
#   {'adult': False,
#    'gender': 2,
#    'id': 1473665,
#    'known_for_department': 'Art',
#    'name': 'Osamu Masuyama',
#    'original_name': 'Osamu Masuyama',
#    'popularity': 1.417,
#    'profile_path': None,
#    'credit_id': '5baab3e0c3a3683a9c00d487',
#    'department': 'Art',
#    'job': 'Background Designer'},
#   {'adult': False,
#    'gender': 2,
#    'id': 1489004,
#    'known_for_department': 'Visual Effects',
#    'name': 'Yoshihiro Osugi',
#    'original_name': 'Yoshihiro Osugi',
#    'popularity': 2.436,
#    'profile_path': '/hZ6L3XGyx1krCTgNmu2OQJuGEhK.jpg',
#    'credit_id': '638b7d3ac3aa3f007a10e528',
#    'department': 'Visual Effects',
#    'job': 'Key Animation'},
#   {'adult': False,
#    'gender': 2,
#    'id': 1504818,
#    'known_for_department': 'Production',
#    'name': 'Yosuke Toba',
#    'original_name': 'Yosuke Toba',
#    'popularity': 4.648,
#    'profile_path': None,
#    'credit_id': '5baaa6cd92514150ee009e03',
#    'department': 'Directing',
#    'job': 'Assistant Director'},
#   {'adult': False,
#    'gender': 0,
#    'id': 1554862,
#    'known_for_department': 'Production',
#    'name': 'Motohiro Hatanaka',
#    'original_name': 'Motohiro Hatanaka',
#    'popularity': 0.6,
#    'profile_path': None,
#    'credit_id': '5baaa8710e0a2664d700bffb',
#    'department': 'Production',
#    'job': 'Casting Coordinator'},
#   {'adult': False,
#    'gender': 0,
#    'id': 1581718,
#    'known_for_department': 'Sound',
#    'name': 'Mizuki Ito',
#    'original_name': 'Mizuki Ito',
#    'popularity': 0.84,
#    'profile_path': None,
#    'credit_id': '5baaae2692514150e8009fe7',
#    'department': 'Sound',
#    'job': 'Foley Artist'},
#   {'adult': False,
#    'gender': 2,
#    'id': 1590938,
#    'known_for_department': 'Art',
#    'name': 'Yoichi Nishikawa',
#    'original_name': 'Yoichi Nishikawa',
#    'popularity': 0.6,
#    'profile_path': None,
#    'credit_id': '5baab408925141510c00c45b',
#    'department': 'Art',
#    'job': 'Background Designer'},
#   {'adult': False,
#    'gender': 2,
#    'id': 1602468,
#    'known_for_department': 'Visual Effects',
#    'name': 'Minoru Ohashi',
#    'original_name': 'Minoru Ohashi',
#    'popularity': 2.673,
#    'profile_path': None,
#    'credit_id': '5baac942c3a3683ac900f9a6',
#    'department': 'Visual Effects',
#    'job': 'Animation'},
#   {'adult': False,
#    'gender': 0,
#    'id': 1610869,
#    'known_for_department': 'Editing',
#    'name': 'Chris DeLaGuardia',
#    'original_name': 'Chris DeLaGuardia',
#    'popularity': 1.22,
#    'profile_path': None,
#    'credit_id': '5baaa7e8925141510c00b31e',
#    'department': 'Editing',
#    'job': 'Color Timer'},
#   {'adult': False,
#    'gender': 2,
#    'id': 1716901,
#    'known_for_department': 'Acting',
#    'name': 'Yukinobu Yamada',
#    'original_name': 'Yukinobu Yamada',
#    'popularity': 0.6,
#    'profile_path': None,
#    'credit_id': '5baacb2ac3a3683aaa00f861',
#    'department': 'Visual Effects',
#    'job': 'Animation'},
#   {'adult': False,
#    'gender': 0,
#    'id': 1717783,
#    'known_for_department': 'Sound',
#    'name': 'Akihiko Okase',
#    'original_name': 'Akihiko Okase',
#    'popularity': 2.414,
#    'profile_path': None,
#    'credit_id': '5baaae000e0a2664cc00d901',
#    'department': 'Sound',
#    'job': 'Foley Artist'},
#   {'adult': False,
#    'gender': 2,
#    'id': 1728057,
#    'known_for_department': 'Visual Effects',
#    'name': 'Nobuyuki Takeuchi',
#    'original_name': 'Nobuyuki Takeuchi',
#    'popularity': 1.318,
#    'profile_path': '/d7O7ZwWkmqPFKz32k39S8bw9bzA.jpg',
#    'credit_id': '5baab8e5c3a3683ac000ed19',
#    'department': 'Visual Effects',
#    'job': 'Key Animation'},
#   {'adult': False,
#    'gender': 0,
#    'id': 1778914,
#    'known_for_department': 'Visual Effects',
#    'name': 'Yuuko Fujita',
#    'original_name': 'Yuuko Fujita',
#    'popularity': 0.6,
#    'profile_path': None,
#    'credit_id': '5baacb8c0e0a2664d700f958',
#    'department': 'Visual Effects',
#    'job': 'Animation'},
#   {'adult': False,
#    'gender': 1,
#    'id': 1847891,
#    'known_for_department': 'Visual Effects',
#    'name': 'Ayako Mori',
#    'original_name': 'Ayako Mori',
#    'popularity': 0.6,
#    'profile_path': None,
#    'credit_id': '5baac6bf92514150f500dfac',
#    'department': 'Visual Effects',
#    'job': 'Animation'},
#   {'adult': False,
#    'gender': 0,
#    'id': 1848196,
#    'known_for_department': 'Visual Effects',
#    'name': 'Kaori Tokunaga',
#    'original_name': 'Kaori Tokunaga',
#    'popularity': 0.98,
#    'profile_path': None,
#    'credit_id': '5baac7dd92514150f500e1d1',
#    'department': 'Visual Effects',
#    'job': 'Animation'},
#   {'adult': False,
#    'gender': 0,
#    'id': 1848234,
#    'known_for_department': 'Visual Effects',
#    'name': 'Mayumi Kitamura',
#    'original_name': 'Mayumi Kitamura',
#    'popularity': 0.84,
#    'profile_path': None,
#    'credit_id': '5baac91ec3a3683a9700fc98',
#    'department': 'Visual Effects',
#    'job': 'Animation'},
#   {'adult': False,
#    'gender': 1,
#    'id': 1848246,
#    'known_for_department': 'Visual Effects',
#    'name': 'Rie Usui',
#    'original_name': 'Rie Usui',
#    'popularity': 0.6,
#    'profile_path': None,
#    'credit_id': '6355702b945d36007d687a6d',
#    'department': 'Visual Effects',
#    'job': 'Animation'},
#   {'adult': False,
#    'gender': 0,
#    'id': 1904693,
#    'known_for_department': 'Sound',
#    'name': 'Youmi Kimura',
#    'original_name': 'Youmi Kimura',
#    'popularity': 1.38,
#    'profile_path': None,
#    'credit_id': '5baaa908925141510500a2d8',
#    'department': 'Sound',
#    'job': 'Songs'},
#   {'adult': False,
#    'gender': 2,
#    'id': 2026796,
#    'known_for_department': 'Sound',
#    'name': 'Masaya Kitada',
#    'original_name': 'Masaya Kitada',
#    'popularity': 0.658,
#    'profile_path': None,
#    'credit_id': '5baaae0c925141510c00bb09',
#    'department': 'Sound',
#    'job': 'Foley Artist'},
#   {'adult': False,
#    'gender': 2,
#    'id': 2032142,
#    'known_for_department': 'Visual Effects',
#    'name': 'Shigeru Kimishima',
#    'original_name': 'Shigeru Kimishima',
#    'popularity': 2.053,
#    'profile_path': None,
#    'credit_id': '5baab92c0e0a2664d000df93',
#    'department': 'Visual Effects',
#    'job': 'Key Animation'},
#   {'adult': False,
#    'gender': 0,
#    'id': 2032147,
#    'known_for_department': 'Visual Effects',
#    'name': 'Yasuyuki Kitazawa',
#    'original_name': 'Yasuyuki Kitazawa',
#    'popularity': 0.6,
#    'profile_path': None,
#    'credit_id': '5baacabd0e0a2664df010f8d',
#    'department': 'Visual Effects',
#    'job': 'Animation'},
#   {'adult': False,
#    'gender': 2,
#    'id': 2032242,
#    'known_for_department': 'Visual Effects',
#    'name': 'Hirofumi Masuda',
#    'original_name': 'Hirofumi Masuda',
#    'popularity': 2.275,
#    'profile_path': None,
#    'credit_id': '638b7d618a84d20084790f55',
#    'department': 'Visual Effects',
#    'job': 'Key Animation'},
#   {'adult': False,
#    'gender': 2,
#    'id': 2032263,
#    'known_for_department': 'Visual Effects',
#    'name': 'Katsuya Yamada',
#    'original_name': 'Katsuya Yamada',
#    'popularity': 0.853,
#    'profile_path': None,
#    'credit_id': '5baab6f192514150ff00b240',
#    'department': 'Visual Effects',
#    'job': 'Key Animation'},
#   {'adult': False,
#    'gender': 0,
#    'id': 2125285,
#    'known_for_department': 'Sound',
#    'name': 'Suminobu Hamada',
#    'original_name': 'Suminobu Hamada',
#    'popularity': 0.6,
#    'profile_path': None,
#    'credit_id': '5baaaf7dc3a3683ab500bd4e',
#    'department': 'Sound',
#    'job': 'Sound Recordist'},
#   {'adult': False,
#    'gender': 0,
#    'id': 2127526,
#    'known_for_department': 'Crew',
#    'name': 'Cory Hansen',
#    'original_name': 'Cory Hansen',
#    'popularity': 0.6,
#    'profile_path': None,
#    'credit_id': '5baaa5af92514150eb00a1b1',
#    'department': 'Crew',
#    'job': 'Post Production Supervisor'},
#   {'adult': False,
#    'gender': 0,
#    'id': 2135152,
#    'known_for_department': 'Crew',
#    'name': 'David Candiff',
#    'original_name': 'David Candiff',
#    'popularity': 0.6,
#    'profile_path': None,
#    'credit_id': '5baaa589c3a3683aaa00b314',
#    'department': 'Crew',
#    'job': 'Post-Production Manager'},
#   {'adult': False,
#    'gender': 0,
#    'id': 2135153,
#    'known_for_department': 'Directing',
#    'name': 'Ryosuke Kiyokawa',
#    'original_name': 'Ryosuke Kiyokawa',
#    'popularity': 0.6,
#    'profile_path': None,
#    'credit_id': '5baaa6a9c3a3683aaf00b993',
#    'department': 'Directing',
#    'job': 'Assistant Director'},
#   {'adult': False,
#    'gender': 0,
#    'id': 2135156,
#    'known_for_department': 'Production',
#    'name': 'Ayumi Sato',
#    'original_name': 'Ayumi Sato',
#    'popularity': 0.6,
#    'profile_path': None,
#    'credit_id': '5baaa8ec925141510500a2a9',
#    'department': 'Production',
#    'job': 'Casting Coordinator'},
#   {'adult': False,
#    'gender': 0,
#    'id': 2135157,
#    'known_for_department': 'Production',
#    'name': 'Naomi Yasu',
#    'original_name': 'Naomi Yasu',
#    'popularity': 0.6,
#    'profile_path': None,
#    'credit_id': '5baaa8f70e0a2664d000c5e1',
#    'department': 'Production',
#    'job': 'Casting Coordinator'},
#   {'adult': False,
#    'gender': 0,
#    'id': 2135159,
#    'known_for_department': 'Production',
#    'name': 'Akio Ichimura',
#    'original_name': 'Akio Ichimura',
#    'popularity': 0.6,
#    'profile_path': None,
# ...
#    'known_for_department': 'Visual Effects',
#    'name': 'Daisuke Makino',
#    'original_name': 'Daisuke Makino',
#    'popularity': 0.6,
#    'profile_path': None,
#    'credit_id': '5baac7120e0a2664e200fd52',
#    'department': 'Visual Effects',
#    'job': 'Animation'},
#   {'adult': False,
#    'gender': 0,
#    'id': 2135263,
#    'known_for_department': 'Visual Effects',
#    'name': 'Emiko Iwayanagi',
#    'original_name': 'Emiko Iwayanagi',
#    'popularity': 0.6,
#    'profile_path': None,
#    'credit_id': '5baac722c3a3683a9700f75f',
#    'department': 'Visual Effects',
#    'job': 'Animation'},
#   {'adult': False,
#    'gender': 0,
#    'id': 2135264,
#    'known_for_department': 'Visual Effects',
#    'name': 'Fumie Konno',
#    'original_name': 'Fumie Konno',
#    'popularity': 0.6,
#    'profile_path': None,
#    'credit_id': '5baac731c3a3683ac900f4d1',
#    'department': 'Visual Effects',
#    'job': 'Animation'},
#   {'adult': False,
#    'gender': 0,
#    'id': 2135265,
#    'known_for_department': 'Visual Effects',
#    'name': 'Hiroaki Nakajima',
#    'original_name': 'Hiroaki Nakajima',
#    'popularity': 0.6,
#    'profile_path': None,
#    'credit_id': '5baac76592514150e800c7c4',
#    'department': 'Visual Effects',
#    'job': 'Animation'},
#   {'adult': False,
#    'gender': 0,
#    'id': 2135268,
#    'known_for_department': 'Visual Effects',
#    'name': 'Hisako Yaji',
#    'original_name': 'Hisako Yaji',
#    'popularity': 0.6,
#    'profile_path': None,
#    'credit_id': '5baac7ac92514150f500e18b',
#    'department': 'Visual Effects',
#    'job': 'Animation'},
#   {'adult': False,
#    'gender': 0,
#    'id': 2135269,
#    'known_for_department': 'Visual Effects',
#    'name': 'Jinko Tsuji',
#    'original_name': 'Jinko Tsuji',
#    'popularity': 0.98,
#    'profile_path': None,
#    'credit_id': '5baac7bf925141510500daff',
#    'department': 'Visual Effects',
#    'job': 'Animation'},
#   {'adult': False,
#    'gender': 1,
#    'id': 2135271,
#    'known_for_department': 'Visual Effects',
#    'name': 'Kaori Itou',
#    'original_name': 'Kaori Itou',
#    'popularity': 2.066,
#    'profile_path': None,
#    'credit_id': '5baac7ce92514150f100e1da',
#    'department': 'Visual Effects',
#    'job': 'Animation'},
#   {'adult': False,
#    'gender': 0,
#    'id': 2135273,
#    'known_for_department': 'Visual Effects',
#    'name': 'Keisuke Shimohira',
#    'original_name': 'Keisuke Shimohira',
#    'popularity': 0.98,
#    'profile_path': None,
#    'credit_id': '5baac80f92514150eb00d9c9',
#    'department': 'Visual Effects',
#    'job': 'Animation'},
#   {'adult': False,
#    'gender': 0,
#    'id': 2135275,
#    'known_for_department': 'Visual Effects',
#    'name': 'Kimitoshi Ueno',
#    'original_name': 'Kimitoshi Ueno',
#    'popularity': 0.6,
#    'profile_path': None,
#    'credit_id': '5baac820c3a3683a9c00f4e3',
#    'department': 'Visual Effects',
#    'job': 'Animation'},
#   {'adult': False,
#    'gender': 0,
#    'id': 2135276,
#    'known_for_department': 'Visual Effects',
#    'name': 'Kiyoko Makita',
#    'original_name': 'Kiyoko Makita',
#    'popularity': 0.6,
#    'profile_path': None,
#    'credit_id': '5baac8310e0a2664cc010035',
#    'department': 'Visual Effects',
#    'job': 'Animation'},
#   {'adult': False,
#    'gender': 0,
#    'id': 2135278,
#    'known_for_department': 'Visual Effects',
#    'name': 'Kumiko Ohta',
#    'original_name': 'Kumiko Ohta',
#    'popularity': 0.84,
#    'profile_path': None,
#    'credit_id': '5baac8440e0a2664d000f880',
#    'department': 'Visual Effects',
#    'job': 'Animation'},
#   {'adult': False,
#    'gender': 0,
#    'id': 2135281,
#    'known_for_department': 'Visual Effects',
#    'name': 'Kumiko Tanihira',
#    'original_name': 'Kumiko Tanihira',
#    'popularity': 0.6,
#    'profile_path': None,
#    'credit_id': '5baac8550e0a2664d700f3c1',
#    'department': 'Visual Effects',
#    'job': 'Animation'},
#   {'adult': False,
#    'gender': 0,
#    'id': 2135283,
#    'known_for_department': 'Visual Effects',
#    'name': 'Kumiko Terada',
#    'original_name': 'Kumiko Terada',
#    'popularity': 0.6,
#    'profile_path': None,
#    'credit_id': '5baac86bc3a3683ac900f7f6',
#    'department': 'Visual Effects',
#    'job': 'Animation'},
#   {'adult': False,
#    'gender': 0,
#    'id': 2135284,
#    'known_for_department': 'Visual Effects',
#    'name': 'Kunitoshi Ishii',
#    'original_name': 'Kunitoshi Ishii',
#    'popularity': 0.6,
#    'profile_path': None,
#    'credit_id': '5baac87cc3a3683aaf00ee8f',
#    'department': 'Visual Effects',
#    'job': 'Animation'},
#   {'adult': False,
#    'gender': 0,
#    'id': 2135286,
#    'known_for_department': 'Visual Effects',
#    'name': 'Mai Nakazato',
#    'original_name': 'Mai Nakazato',
#    'popularity': 0.6,
#    'profile_path': None,
#    'credit_id': '5baac88cc3a3683aa200ee4f',
#    'department': 'Visual Effects',
#    'job': 'Animation'},
#   {'adult': False,
#    'gender': 0,
#    'id': 2135287,
#    'known_for_department': 'Visual Effects',
#    'name': 'Makoto Oohara',
#    'original_name': 'Makoto Oohara',
#    'popularity': 0.6,
#    'profile_path': None,
#    'credit_id': '5baac8a2925141510500dc87',
#    'department': 'Visual Effects',
#    'job': 'Animation'},
#   {'adult': False,
#    'gender': 0,
#    'id': 2135288,
#    'known_for_department': 'Visual Effects',
#    'name': 'Masakiyo Yamashita',
#    'original_name': 'Masakiyo Yamashita',
#    'popularity': 0.6,
#    'profile_path': None,
#    'credit_id': '5baac8b592514150eb00db16',
#    'department': 'Visual Effects',
#    'job': 'Animation'},
#   {'adult': False,
#    'gender': 1,
#    'id': 2135289,
#    'known_for_department': 'Directing',
#    'name': 'Masako Sato',
#    'original_name': 'Masako Sato',
#    'popularity': 1.4,
#    'profile_path': None,
#    'credit_id': '5baac8c70e0a2664d000f95d',
#    'department': 'Visual Effects',
#    'job': 'Animation'},
#   {'adult': False,
#    'gender': 0,
#    'id': 2135290,
#    'known_for_department': 'Visual Effects',
#    'name': 'Masami Nakanishi',
#    'original_name': 'Masami Nakanishi',
#    'popularity': 0.6,
#    'profile_path': None,
#    'credit_id': '5baac8d992514150f500e467',
#    'department': 'Visual Effects',
#    'job': 'Animation'},
#   {'adult': False,
#    'gender': 2,
#    'id': 2135291,
#    'known_for_department': 'Visual Effects',
#    'name': 'Masashi Karino',
#    'original_name': 'Masashi Karino',
#    'popularity': 1.155,
#    'profile_path': None,
#    'credit_id': '5baac8e90e0a2664da00f16a',
#    'department': 'Visual Effects',
#    'job': 'Animation'},
#   {'adult': False,
#    'gender': 2,
#    'id': 2135292,
#    'known_for_department': 'Visual Effects',
#    'name': 'Masayuki Shimizu',
#    'original_name': 'Masayuki Shimizu',
#    'popularity': 0.6,
#    'profile_path': None,
#    'credit_id': '5baac8fbc3a3683aa200ef08',
#    'department': 'Visual Effects',
#    'job': 'Animation'},
#   {'adult': False,
#    'gender': 0,
#    'id': 2135293,
#    'known_for_department': 'Visual Effects',
#    'name': 'Maya Fujimori',
#    'original_name': 'Maya Fujimori',
#    'popularity': 0.6,
#    'profile_path': None,
#    'credit_id': '5baac90c92514150ee00d457',
#    'department': 'Visual Effects',
#    'job': 'Animation'},
#   {'adult': False,
#    'gender': 0,
#    'id': 2135294,
#    'known_for_department': 'Visual Effects',
#    'name': 'Mayumi Ohmura',
#    'original_name': 'Mayumi Ohmura',
#    'popularity': 0.6,
#    'profile_path': None,
#    'credit_id': '5baac93192514150eb00dc02',
#    'department': 'Visual Effects',
#    'job': 'Animation'},
#   {'adult': False,
#    'gender': 0,
#    'id': 2135295,
#    'known_for_department': 'Visual Effects',
#    'name': 'Mitsu Noguchi',
#    'original_name': 'Mitsu Noguchi',
#    'popularity': 0.6,
#    'profile_path': None,
#    'credit_id': '5baac95492514150eb00dc50',
#    'department': 'Visual Effects',
#    'job': 'Animation'},
#   {'adult': False,
#    'gender': 0,
#    'id': 2135296,
#    'known_for_department': 'Visual Effects',
#    'name': 'Moyo Takahashi',
#    'original_name': 'Moyo Takahashi',
#    'popularity': 1.294,
#    'profile_path': None,
#    'credit_id': '5baac9650e0a2664c9010161',
#    'department': 'Visual Effects',
#    'job': 'Animation'},
#   {'adult': False,
#    'gender': 2,
#    'id': 2135297,
#    'known_for_department': 'Visual Effects',
#    'name': 'Osamu Miwa',
#    'original_name': 'Osamu Miwa',
#    'popularity': 0.79,
#    'profile_path': None,
#    'credit_id': '5baac97892514150ee00d52e',
#    'department': 'Visual Effects',
#    'job': 'Animation'},
#   {'adult': False,
#    'gender': 0,
#    'id': 2135298,
#    'known_for_department': 'Visual Effects',
#    'name': 'Rie Kondou',
#    'original_name': 'Rie Kondou',
#    'popularity': 0.994,
#    'profile_path': None,
#    'credit_id': '5baac98ac3a3683aaf00f06d',
#    'department': 'Visual Effects',
#    'job': 'Animation'},
#   {'adult': False,
#    'gender': 0,
#    'id': 2135299,
#    'known_for_department': 'Visual Effects',
#    'name': 'Rie Yamamoto',
#    'original_name': 'Rie Yamamoto',
#    'popularity': 0.6,
#    'profile_path': None,
#    'credit_id': '5baac99cc3a3683aa200f058',
#    'department': 'Visual Effects',
#    'job': 'Animation'},
#   {'adult': False,
#    'gender': 0,
#    'id': 2135300,
#    'known_for_department': 'Visual Effects',
#    'name': 'Saho Saito',
#    'original_name': 'Saho Saito',
#    'popularity': 0.6,
#    'profile_path': None,
#    'credit_id': '5baac9af92514150f100e4aa',
#    'department': 'Visual Effects',
#    'job': 'Animation'},
#   {'adult': False,
#    'gender': 0,
#    'id': 2135302,
#    'known_for_department': 'Visual Effects',
#    'name': 'Setsuya Tanabe',
#    'original_name': 'Setsuya Tanabe',
#    'popularity': 0.6,
#    'profile_path': None,
#    'credit_id': '5baac9dc0e0a2664d000fb5b',
#    'department': 'Visual Effects',
#    'job': 'Animation'},
#   {'adult': False,
#    'gender': 2,
#    'id': 2135303,
#    'known_for_department': 'Visual Effects',
#    'name': 'Shinichiro Yamada',
#    'original_name': 'Shinichiro Yamada',
#    'popularity': 0.753,
#    'profile_path': None,
#    'credit_id': '5baac9eec3a3683ac0010a3a',
#    'department': 'Visual Effects',
#    'job': 'Animation'},
#   {'adult': False,
#    'gender': 0,
#    'id': 2135304,
#    'known_for_department': 'Visual Effects',
#    'name': 'Sumie Iwata',
#    'original_name': 'Sumie Iwata',
#    'popularity': 0.6,
#    'profile_path': None,
#    'credit_id': '5baaca11c3a3683ac900fc96',
#    'department': 'Visual Effects',
#    'job': 'Animation'},
#   {'adult': False,
#    'gender': 0,
#    'id': 2135305,
#    'known_for_department': 'Visual Effects',
#    'name': 'Sumie Nishido',
#    'original_name': 'Sumie Nishido',
#    'popularity': 0.6,
#    'profile_path': None,
#    'credit_id': '5baaca240e0a2664e20103f5',
#    'department': 'Visual Effects',
#    'job': 'Animation'},
#   {'adult': False,
#    'gender': 0,
#    'id': 2135306,
#    'known_for_department': 'Visual Effects',
#    'name': 'Takahiro Sugawara',
#    'original_name': 'Takahiro Sugawara',
#    'popularity': 0.6,
#    'profile_path': None,
#    'credit_id': '5baaca36925141510500df7e',
#    'department': 'Visual Effects',
#    'job': 'Animation'},
#   {'adult': False,
#    'gender': 0,
#    'id': 2135308,
#    'known_for_department': 'Visual Effects',
#    'name': 'Takeshi Hiramatsu',
#    'original_name': 'Takeshi Hiramatsu',
#    'popularity': 0.703,
#    'profile_path': None,
#    'credit_id': '5baaca4892514150eb00e002',
#    'department': 'Visual Effects',
#    'job': 'Animation'},
#   {'adult': False,
#    'gender': 0,
#    'id': 2135309,
#    'known_for_department': 'Directing',
#    'name': 'Tetsuaki Matsuda',
#    'original_name': 'Tetsuaki Matsuda',
#    'popularity': 1.13,
#    'profile_path': None,
#    'credit_id': '5baaca5bc3a3683a9c00fa4f',
#    'department': 'Visual Effects',
#    'job': 'Animation'},
#   {'adult': False,
#    'gender': 0,
#    'id': 2135310,
#    'known_for_department': 'Visual Effects',
#    'name': 'Tomoko Miyata',
#    'original_name': 'Tomoko Miyata',
#    'popularity': 0.694,
#    'profile_path': None,
#    'credit_id': '5baaca6c0e0a2664d000fc55',
#    'department': 'Visual Effects',
#    'job': 'Animation'},
#   {'adult': False,
#    'gender': 0,
#    'id': 2135312,
#    'known_for_department': 'Visual Effects',
#    'name': 'Tsutomu Kaichi',
#    'original_name': 'Tsutomu Kaichi',
#    'popularity': 0.6,
#    'profile_path': None,
#    'credit_id': '5baaca8192514150eb00e062',
#    'department': 'Visual Effects',
#    'job': 'Animation'},
#   {'adult': False,
#    'gender': 0,
#    'id': 2135313,
#    'known_for_department': 'Visual Effects',
#    'name': 'Tsutomu Shibutani',
#    'original_name': 'Tsutomu Shibutani',
#    'popularity': 1.173,
#    'profile_path': None,
#    'credit_id': '5baaca9f92514150eb00e0d5',
#    'department': 'Visual Effects',
#    'job': 'Animation'},
#   {'adult': False,
#    'gender': 0,
#    'id': 2135314,
#    'known_for_department': 'Visual Effects',
#    'name': 'Waka Hirota',
#    'original_name': 'Waka Hirota',
#    'popularity': 0.6,
#    'profile_path': None,
#    'credit_id': '5baacaae92514150f500e93e',
#    'department': 'Visual Effects',
#    'job': 'Animation'},
#   {'adult': False,
#    'gender': 1,
#    'id': 2135315,
#    'known_for_department': 'Visual Effects',
#    'name': 'Yoshie Hayashi',
#    'original_name': 'Yoshie Hayashi',
#    'popularity': 0.6,
#    'profile_path': None,
#    'credit_id': '5baacacdc3a3683ac900fde8',
#    'department': 'Visual Effects',
#    'job': 'Animation'},
#   {'adult': False,
#    'gender': 0,
#    'id': 2135316,
#    'known_for_department': 'Visual Effects',
#    'name': 'Yoyoi Toki',
#    'original_name': 'Yoyoi Toki',
#    'popularity': 0.6,
#    'profile_path': None,
#    'credit_id': '5baacadc0e0a2664df010fcd',
#    'department': 'Visual Effects',
#    'job': 'Animation'},
#   {'adult': False,
#    'gender': 0,
#    'id': 2135317,
#    'known_for_department': 'Visual Effects',
#    'name': 'Yukari Umebayashi',
#    'original_name': 'Yukari Umebayashi',
#    'popularity': 0.6,
#    'profile_path': None,
#    'credit_id': '5baacaecc3a3683ac0010bc9',
#    'department': 'Visual Effects',
#    'job': 'Animation'},
#   {'adult': False,
#    'gender': 0,
#    'id': 2135318,
#    'known_for_department': 'Visual Effects',
#    'name': 'Yukari Yamaura',
#    'original_name': 'Yukari Yamaura',
#    'popularity': 0.6,
#    'profile_path': None,
#    'credit_id': '5baacafb925141510c00eff5',
#    'department': 'Visual Effects',
#    'job': 'Animation'},
#   {'adult': False,
#    'gender': 0,
#    'id': 2135319,
#    'known_for_department': 'Visual Effects',
#    'name': 'Yukie Kaneko',
#    'original_name': 'Yukie Kaneko',
#    'popularity': 0.6,
#    'profile_path': None,
#    'credit_id': '5baacb0b0e0a2664da00f5ec',
#    'department': 'Visual Effects',
#    'job': 'Animation'},
#   {'adult': False,
#    'gender': 0,
#    'id': 2135320,
#    'known_for_department': 'Visual Effects',
#    'name': 'Yukiko Kakinuma',
#    'original_name': 'Yukiko Kakinuma',
#    'popularity': 0.6,
#    'profile_path': None,
#    'credit_id': '5baacb1b92514150eb00e1c1',
#    'department': 'Visual Effects',
#    'job': 'Animation'},
#   {'adult': False,
#    'gender': 0,
#    'id': 2135321,
#    'known_for_department': 'Visual Effects',
#    'name': 'Yumiko Kitajima',
#    'original_name': 'Yumiko Kitajima',
#    'popularity': 0.6,
#    'profile_path': None,
#    'credit_id': '5baacb3a92514150ee00d87f',
#    'department': 'Visual Effects',
#    'job': 'Animation'},
#   {'adult': False,
#    'gender': 1,
#    'id': 2135322,
#    'known_for_department': 'Visual Effects',
#    'name': 'Yumiko Suehiro',
#    'original_name': 'Yumiko Suehiro',
#    'popularity': 0.6,
#    'profile_path': None,
#    'credit_id': '5baacb4a0e0a2664d700f8d8',
#    'department': 'Visual Effects',
#    'job': 'Animation'},
#   {'adult': False,
#    'gender': 2,
#    'id': 2135323,
#    'known_for_department': 'Visual Effects',
#    'name': 'Yōhei Nakano',
#    'original_name': 'Yōhei Nakano',
#    'popularity': 0.6,
#    'profile_path': None,
#    'credit_id': '5baacb780e0a2664cc010bf2',
#    'department': 'Visual Effects',
#    'job': 'Animation'},
#   {'adult': False,
#    'gender': 2,
#    'id': 2159673,
#    'known_for_department': 'Visual Effects',
#    'name': 'Atsushi Tamura',
#    'original_name': 'Atsushi Tamura',
#    'popularity': 1.4,
#    'profile_path': None,
#    'credit_id': '60a8e95f501cf20026d3cc6f',
#    'department': 'Visual Effects',
#    'job': 'Key Animation'},
#   {'adult': False,
#    'gender': 1,
#    'id': 3102924,
#    'known_for_department': 'Visual Effects',
#    'name': 'Makiko Suzuki',
#    'original_name': 'Makiko Suzuki',
#    'popularity': 1.176,
#    'profile_path': None,
#    'credit_id': '638b7db8c3aa3f0096e20dc8',
#    'department': 'Visual Effects',
#    'job': 'Key Animation'}]}

# %%
# The Adventures of Priscilla: Queen of the Desert request
# Save a movie title to search for as a variable
movie_title = "The Adventures of Priscilla: Queen of the Desert"

# Concatenate request_url, title, and api_key. Store as new variable
request_url = f"https://api.themoviedb.org/3/search/movie?api_key={api_key}&query={movie_title}"


# Execute get request
response = requests.get(request_url)


# Get movie ID
movie_data = response.json()
movie_id = movie_data['results'][0]['id']


# Call get_credits function
get_movie_credits(movie_id, api_key)
# Out:
# {'id': 2759,
#  'cast': [{'adult': False,
#    'gender': 2,
#    'id': 1331,
#    'known_for_department': 'Acting',
#    'name': 'Hugo Weaving',
#    'original_name': 'Hugo Weaving',
#    'popularity': 22.351,
#    'profile_path': '/lSC8Et0PYi5zeQb3IpPkFje7hgR.jpg',
#    'cast_id': 9,
#    'character': 'Anthony "Tick" Belrose / Mitzi Del Bra',
#    'credit_id': '52fe436ac3a36847f8052ad1',
#    'order': 0},
#   {'adult': False,
#    'gender': 2,
#    'id': 529,
#    'known_for_department': 'Acting',
#    'name': 'Guy Pearce',
#    'original_name': 'Guy Pearce',
#    'popularity': 46.994,
#    'profile_path': '/vTqk6Nh3WgqPubkS23eOlMAwmwa.jpg',
#    'cast_id': 10,
#    'character': 'Adam Whitely / Felicia Jollygoodfellow',
#    'credit_id': '52fe436ac3a36847f8052ad5',
#    'order': 1},
#   {'adult': False,
#    'gender': 2,
#    'id': 28641,
#    'known_for_department': 'Acting',
#    'name': 'Terence Stamp',
#    'original_name': 'Terence Stamp',
#    'popularity': 16.416,
#    'profile_path': '/ept9urkuhPbGndVXkERw39R9oid.jpg',
#    'cast_id': 8,
#    'character': 'Bernadette Bassenger',
#    'credit_id': '52fe436ac3a36847f8052acd',
#    'order': 2},
#   {'adult': False,
#    'gender': 2,
#    'id': 23,
#    'known_for_department': 'Acting',
#    'name': 'Bill Hunter',
#    'original_name': 'Bill Hunter',
#    'popularity': 4.65,
#    'profile_path': '/gvrRsTfx47KupgRwTKp0gqryHPe.jpg',
#    'cast_id': 11,
#    'character': 'Bob Spart',
#    'credit_id': '52fe436ac3a36847f8052ad9',
#    'order': 3},
#   {'adult': False,
#    'gender': 1,
#    'id': 1230360,
#    'known_for_department': 'Acting',
#    'name': 'Sarah Chadwick',
#    'original_name': 'Sarah Chadwick',
#    'popularity': 2.855,
#    'profile_path': '/gvt8ckWJsSsDjr7Uf6MqMQVajIr.jpg',
#    'cast_id': 13,
#    'character': 'Marion Barber',
#    'credit_id': '563623129251413b4600c993',
#    'order': 4},
#   {'adult': False,
#    'gender': 0,
#    'id': 1530258,
#    'known_for_department': 'Acting',
#    'name': 'June Marie Bennett',
#    'original_name': 'June Marie Bennett',
#    'popularity': 0.6,
#    'profile_path': None,
#    'cast_id': 14,
#    'character': 'Shirley',
#    'credit_id': '563627f5c3a3681b4d01cd41',
#    'order': 5},
#   {'adult': False,
#    'gender': 0,
#    'id': 126332,
#    'known_for_department': 'Acting',
#    'name': 'Rebel Penfold-Russell',
#    'original_name': 'Rebel Penfold-Russell',
#    'popularity': 2.003,
#    'profile_path': None,
#    'cast_id': 15,
#    'character': 'Logowoman',
#    'credit_id': '5e27feb12dda890012577332',
#    'order': 6},
#   {'adult': False,
#    'gender': 0,
#    'id': 2241372,
#    'known_for_department': 'Acting',
#    'name': 'John Casey',
#    'original_name': 'John Casey',
#    'popularity': 0.627,
#    'profile_path': None,
#    'cast_id': 16,
#    'character': 'Bartender',
#    'credit_id': '5e27fef14ca6760012408c29',
#    'order': 7},
#   {'adult': False,
#    'gender': 0,
#    'id': 2517522,
#    'known_for_department': 'Acting',
#    'name': 'Murray Davies',
#    'original_name': 'Murray Davies',
#    'popularity': 0.6,
#    'profile_path': None,
#    'cast_id': 17,
#    'character': 'Miner',
#    'credit_id': '5e27ff20c68b6900193f533f',
#    'order': 8},
#   {'adult': False,
#    'gender': 0,
#    'id': 2517523,
#    'known_for_department': 'Acting',
#    'name': 'Frank Cornelius',
#    'original_name': 'Frank Cornelius',
#    'popularity': 0.6,
#    'profile_path': None,
#    'cast_id': 18,
#    'character': 'Piano Player',
#    'credit_id': '5e27ff35c68b6900123f1c66',
#    'order': 9},
#   {'adult': False,
#    'gender': 0,
#    'id': 2517525,
#    'known_for_department': 'Acting',
#    'name': 'Bob Boyce',
#    'original_name': 'Bob Boyce',
#    'popularity': 0.6,
#    'profile_path': None,
#    'cast_id': 19,
#    'character': 'Petrol Station Attendant',
#    'credit_id': '5e27ff484ca676001740f052',
#    'order': 10},
#   {'adult': False,
#    'gender': 0,
#    'id': 2517526,
#    'known_for_department': 'Acting',
#    'name': 'Leighton Picken',
#    'original_name': 'Leighton Picken',
#    'popularity': 0.6,
#    'profile_path': None,
#    'cast_id': 20,
#    'character': 'Young Adam',
#    'credit_id': '5e27ff584ca676001740f0ed',
#    'order': 11},
#   {'adult': False,
#    'gender': 0,
#    'id': 2517527,
#    'known_for_department': 'Acting',
#    'name': 'Maria Kmet',
#    'original_name': 'Maria Kmet',
#    'popularity': 0.6,
#    'profile_path': None,
#    'cast_id': 21,
#    'character': 'Ma',
#    'credit_id': '5e27ff694ca67600144087c8',
#    'order': 12},
#   {'adult': False,
#    'gender': 0,
#    'id': 2517528,
#    'known_for_department': 'Acting',
#    'name': 'Joseph Kmet',
#    'original_name': 'Joseph Kmet',
#    'popularity': 0.6,
#    'profile_path': None,
#    'cast_id': 22,
#    'character': 'Pa',
#    'credit_id': '5e27ff77c68b6900123f1c8f',
#    'order': 13},
#   {'adult': False,
#    'gender': 0,
#    'id': 2517529,
#    'known_for_department': 'Acting',
#    'name': 'Alan Dargin',
#    'original_name': 'Alan Dargin',
#    'popularity': 0.6,
#    'profile_path': None,
#    'cast_id': 23,
#    'character': 'Aboriginal Man',
#    'credit_id': '5e27ff892dda89001957cb7a',
#    'order': 14},
#   {'adult': False,
#    'gender': 1,
#    'id': 2517530,
#    'known_for_department': 'Acting',
#    'name': 'Julia Cortez',
#    'original_name': 'Julia Cortez',
#    'popularity': 0.98,
#    'profile_path': None,
#    'cast_id': 24,
#    'character': 'Cynthia Campos',
#    'credit_id': '5e27ff9a1685da0011e07ba2',
#    'order': 15},
#   {'adult': False,
#    'gender': 0,
#    'id': 144065,
#    'known_for_department': 'Acting',
#    'name': 'Daniel Kellie',
#    'original_name': 'Daniel Kellie',
#    'popularity': 0.83,
#    'profile_path': None,
#    'cast_id': 34,
#    'character': 'Young Ralph',
#    'credit_id': '65159e9e9b861600e24ebdb2',
#    'order': 16},
#   {'adult': False,
#    'gender': 1,
#    'id': 4295710,
#    'known_for_department': 'Acting',
#    'name': 'Hannah Corbett',
#    'original_name': 'Hannah Corbett',
#    'popularity': 0.6,
#    'profile_path': None,
#    'cast_id': 35,
#    'character': "Ralph's Sister",
#    'credit_id': '65159eac9b861600ff6820b0',
#    'order': 17},
#   {'adult': False,
#    'gender': 0,
#    'id': 4295711,
#    'known_for_department': 'Acting',
#    'name': 'Trevor Barrie',
#    'original_name': 'Trevor Barrie',
#    'popularity': 0.98,
#    'profile_path': None,
#    'cast_id': 36,
#    'character': "Ralph's Father",
#    'credit_id': '65159ee60499f200e1c678a6',
#    'order': 18},
#   {'adult': False,
#    'gender': 2,
#    'id': 57904,
#    'known_for_department': 'Acting',
#    'name': 'Kenneth Radley',
#    'original_name': 'Kenneth Radley',
#    'popularity': 5.936,
#    'profile_path': '/jqiM2DbXtNRF3yxRaU2nkYzewEJ.jpg',
#    'cast_id': 37,
#    'character': 'Frank',
#    'credit_id': '65159f0993bd6900e12c80c4',
#    'order': 19}],
#  'crew': [{'adult': False,
#    'gender': 2,
#    'id': 9343,
#    'known_for_department': 'Art',
#    'name': 'Owen Paterson',
#    'original_name': 'Owen Paterson',
#    'popularity': 2.103,
#    'profile_path': None,
#    'credit_id': '651588d7cadb6b02c1d09682',
#    'department': 'Art',
#    'job': 'Production Design'},
#   {'adult': False,
#    'gender': 1,
#    'id': 15329,
#    'known_for_department': 'Costume & Make-Up',
#    'name': 'Lizzy Gardiner',
#    'original_name': 'Lizzy Gardiner',
#    'popularity': 2.299,
#    'profile_path': None,
#    'credit_id': '52fe436ac3a36847f8052adf',
#    'department': 'Costume & Make-Up',
#    'job': 'Costume Design'},
#   {'adult': False,
#    'gender': 2,
#    'id': 26753,
#    'known_for_department': 'Acting',
#    'name': 'Robert Simper',
#    'original_name': 'Robert Simper',
#    'popularity': 0.718,
#    'profile_path': None,
#    'credit_id': '6515a48c9b861600e24ebfa9',
#    'department': 'Crew',
#    'job': 'Stunt Coordinator'},
#   {'adult': False,
#    'gender': 2,
#    'id': 27889,
#    'known_for_department': 'Directing',
#    'name': 'Stephan Elliott',
#    'original_name': 'Stephan Elliott',
#    'popularity': 2.572,
#    'profile_path': '/aqKHRXnsKanLLAJJ6TADSglGHVF.jpg',
#    'credit_id': '52fe436ac3a36847f8052aab',
#    'department': 'Writing',
#    'job': 'Screenplay'},
#   {'adult': False,
#    'gender': 2,
#    'id': 27889,
#    'known_for_department': 'Directing',
#    'name': 'Stephan Elliott',
#    'original_name': 'Stephan Elliott',
#    'popularity': 2.572,
#    'profile_path': '/aqKHRXnsKanLLAJJ6TADSglGHVF.jpg',
#    'credit_id': '52fe436ac3a36847f8052aa5',
#    'department': 'Directing',
#    'job': 'Director'},
#   {'adult': False,
#    'gender': 2,
#    'id': 31856,
#    'known_for_department': 'Camera',
#    'name': 'Brian J. Breheny',
#    'original_name': 'Brian J. Breheny',
#    'popularity': 1.4,
#    'profile_path': None,
#    'credit_id': '52fe436ac3a36847f8052ab1',
#    'department': 'Camera',
#    'job': 'Director of Photography'},
#   {'adult': False,
#    'gender': 2,
#    'id': 26050,
#    'known_for_department': 'Sound',
#    'name': 'Guy Gross',
#    'original_name': 'Guy Gross',
#    'popularity': 1.345,
#    'profile_path': None,
#    'credit_id': '52fe436ac3a36847f8052ab7',
#    'department': 'Sound',
#    'job': 'Original Music Composer'},
#   {'adult': False,
#    'gender': 2,
#    'id': 30209,
#    'known_for_department': 'Production',
#    'name': 'Al Clark',
#    'original_name': 'Al Clark',
#    'popularity': 0.6,
#    'profile_path': None,
#    'credit_id': '52fe436ac3a36847f8052abd',
#    'department': 'Production',
#    'job': 'Producer'},
#   {'adult': False,
#    'gender': 2,
#    'id': 31857,
#    'known_for_department': 'Production',
#    'name': 'Michael Hamlyn',
#    'original_name': 'Michael Hamlyn',
#    'popularity': 1.27,
#    'profile_path': None,
#    'credit_id': '52fe436ac3a36847f8052ac3',
#    'department': 'Production',
#    'job': 'Producer'},
#   {'adult': False,
#    'gender': 1,
#    'id': 31858,
#    'known_for_department': 'Editing',
#    'name': 'Sue Blainey',
#    'original_name': 'Sue Blainey',
#    'popularity': 1.566,
#    'profile_path': None,
#    'credit_id': '52fe436ac3a36847f8052ac9',
#    'department': 'Editing',
#    'job': 'Editor'},
#   {'adult': False,
#    'gender': 0,
#    'id': 61772,
#    'known_for_department': 'Production',
#    'name': 'Faith Martin',
#    'original_name': 'Faith Martin',
#    'popularity': 0.6,
#    'profile_path': None,
#    'credit_id': '6515a541c50ad2010bfc8c33',
#    'department': 'Production',
#    'job': 'Additional Casting'},
#   {'adult': False,
#    'gender': 2,
#    'id': 61796,
#    'known_for_department': 'Camera',
#    'name': 'Peter A. Holland',
#    'original_name': 'Peter A. Holland',
#    'popularity': 0.782,
#    'profile_path': None,
#    'credit_id': '6515a2c5cadb6b02c051e044',
#    'department': 'Lighting',
#    'job': 'Electrician'},
#   {'adult': False,
#    'gender': 0,
#    'id': 75943,
#    'known_for_department': 'Costume & Make-Up',
#    'name': 'Emily Seresin',
#    'original_name': 'Emily Seresin',
#    'popularity': 1.4,
#    'profile_path': None,
#    'credit_id': '6515a38593bd6900acc5ab65',
#    'department': 'Costume & Make-Up',
#    'job': 'Wardrobe Supervisor'},
#   {'adult': False,
#    'gender': 0,
#    'id': 75438,
#    'known_for_department': 'Sound',
#    'name': 'Phil Judd',
#    'original_name': 'Phil Judd',
#    'popularity': 0.758,
#    'profile_path': None,
#    'credit_id': '6515a615c50ad200ad7f24a7',
#    'department': 'Sound',
#    'job': 'Sound Mixer'},
#   {'adult': False,
#    'gender': 0,
#    'id': 75438,
#    'known_for_department': 'Sound',
#    'name': 'Phil Judd',
#    'original_name': 'Phil Judd',
#    'popularity': 0.758,
#    'profile_path': None,
#    'credit_id': '6515a61ec50ad2012c17b916',
#    'department': 'Sound',
#    'job': 'Sound Supervisor'},
#   {'adult': False,
#    'gender': 0,
#    'id': 88122,
#    'known_for_department': 'Visual Effects',
#    'name': 'Roger Cowland',
#    'original_name': 'Roger Cowland',
#    'popularity': 1.96,
#    'profile_path': None,
#    'credit_id': '626f3ff37cffda5108033026',
#    'department': 'Visual Effects',
#    'job': 'Visual Effects'},
#   {'adult': False,
#    'gender': 0,
#    'id': 126332,
#    'known_for_department': 'Acting',
#    'name': 'Rebel Penfold-Russell',
#    'original_name': 'Rebel Penfold-Russell',
#    'popularity': 2.003,
#    'profile_path': None,
#    'credit_id': '6515895693bd690138fc51d8',
#    'department': 'Production',
#    'job': 'Executive Producer'},
#   {'adult': False,
#    'gender': 1,
#    'id': 213229,
#    'known_for_department': 'Directing',
#    'name': 'Kate Dennis',
#    'original_name': 'Kate Dennis',
#    'popularity': 2.45,
#    'profile_path': None,
#    'credit_id': '6515a07da199a6011b21a255',
#    'department': 'Directing',
#    'job': 'Continuity'},
#   {'adult': False,
#    'gender': 2,
#    'id': 939990,
#    'known_for_department': 'Art',
#    'name': 'Colin Gibson',
#    'original_name': 'Colin Gibson',
#    'popularity': 1.036,
#    'profile_path': None,
#    'credit_id': '651588e3a199a60138b79bec',
#    'department': 'Art',
#    'job': 'Art Direction'},
#   {'adult': False,
#    'gender': 0,
#    'id': 1188046,
#    'known_for_department': 'Sound',
#    'name': 'Guntis Sics',
#    'original_name': 'Guntis Sics',
#    'popularity': 1.214,
#    'profile_path': None,
#    'credit_id': '6515a62e93bd6900e12c837f',
#    'department': 'Sound',
#    'job': 'Sound Designer'},
#   {'adult': False,
#    'gender': 0,
#    'id': 1188046,
#    'known_for_department': 'Sound',
#    'name': 'Guntis Sics',
#    'original_name': 'Guntis Sics',
#    'popularity': 1.214,
#    'profile_path': None,
#    'credit_id': '6515a3060499f2011b09f938',
#    'department': 'Sound',
#    'job': 'Sound Recordist'},
#   {'adult': False,
#    'gender': 2,
#    'id': 1249772,
#    'known_for_department': 'Costume & Make-Up',
#    'name': 'Tim Chappel',
#    'original_name': 'Tim Chappel',
#    'popularity': 1.112,
#    'profile_path': '/9K3HMYVWLHOIXTxoMaBIiqwiJaN.jpg',
#    'credit_id': '6410e78a176a94007c2c314d',
#    'department': 'Costume & Make-Up',
#    'job': 'Costume Design'},
#   {'adult': False,
#    'gender': 0,
#    'id': 1375094,
#    'known_for_department': 'Sound',
#    'name': 'Fiona McBain',
#    'original_name': 'Fiona McBain',
#    'popularity': 0.6,
#    'profile_path': None,
#    'credit_id': '6515a32b0499f200abbd8e68',
#    'department': 'Sound',
#    'job': 'Boom Operator'},
#   {'adult': False,
#    'gender': 0,
#    'id': 1386395,
#    'known_for_department': 'Directing',
#    'name': 'Emma Schofield',
#    'original_name': 'Emma Schofield',
#    'popularity': 0.753,
#    'profile_path': None,
#    'credit_id': '6515a01ccadb6b02be553131',
#    'department': 'Directing',
#    'job': 'Second Assistant Director'},
#   {'adult': False,
#    'gender': 2,
#    'id': 1392698,
#    'known_for_department': 'Sound',
#    'name': 'Gerry Long',
#    'original_name': 'Gerry Long',
#    'popularity': 1.38,
#    'profile_path': None,
#    'credit_id': '6515a6b9cadb6b02bc0be1c0',
#    'department': 'Sound',
#    'job': 'Foley Editor'},
#   {'adult': False,
#    'gender': 0,
#    'id': 1394860,
#    'known_for_department': 'Sound',
#    'name': 'Simon Hewitt',
#    'original_name': 'Simon Hewitt',
#    'popularity': 0.6,
#    'profile_path': None,
#    'credit_id': '6515a69893bd6900c4ddd755',
#    'department': 'Sound',
#    'job': 'ADR Recordist'},
#   {'adult': False,
#    'gender': 0,
#    'id': 1438637,
#    'known_for_department': 'Costume & Make-Up',
#    'name': 'Angela Conte',
#    'original_name': 'Angela Conte',
#    'popularity': 2.495,
#    'profile_path': None,
#    'credit_id': '6515a3649b861600ff68221b',
#    'department': 'Costume & Make-Up',
#    'job': 'Makeup & Hair'},
#   {'adult': False,
#    'gender': 0,
#    'id': 1445964,
#    'known_for_department': 'Sound',
#    'name': 'Steve Burgess',
#    'original_name': 'Steve Burgess',
#    'popularity': 1.4,
#    'profile_path': None,
#    'credit_id': '6515a6aa1db65d00e31c462b',
#    'department': 'Sound',
#    'job': 'Foley Editor'},
#   {'adult': False,
#    'gender': 0,
#    'id': 1745244,
#    'known_for_department': 'Sound',
#    'name': 'Angus Robertson',
#    'original_name': 'Angus Robertson',
#    'popularity': 1.096,
#    'profile_path': None,
#    'credit_id': '6515a6871db65d00adc66ac9',
#    'department': 'Sound',
#    'job': 'Dialogue Editor'},
#   {'adult': False,
#    'gender': 0,
#    'id': 1751463,
#    'known_for_department': 'Costume & Make-Up',
#    'name': 'Brett Cooper',
#    'original_name': 'Brett Cooper',
#    'popularity': 0.631,
#    'profile_path': None,
#    'credit_id': '6515a3980499f2013865671f',
#    'department': 'Costume & Make-Up',
#    'job': 'Wardrobe Coordinator'},
#   {'adult': False,
#    'gender': 0,
#    'id': 1919789,
#    'known_for_department': 'Art',
#    'name': 'Libby Blainey',
#    'original_name': 'Libby Blainey',
#    'popularity': 0.662,
#    'profile_path': None,
#    'credit_id': '6515a5f71db65d011d1ee366',
#    'department': 'Art',
#    'job': 'Title Designer'},
#   {'adult': False,
#    'gender': 0,
#    'id': 1929521,
#    'known_for_department': 'Camera',
#    'name': 'Ian McAlpine',
#    'original_name': 'Ian McAlpine',
#    'popularity': 0.6,
#    'profile_path': None,
#    'credit_id': '6515a2e5a199a600ab17f4ae',
#    'department': 'Camera',
#    'job': 'Grip'},
#   {'adult': False,
#    'gender': 0,
#    'id': 1985712,
#    'known_for_department': 'Sound',
#    'name': 'Grant Shepherd',
#    'original_name': 'Grant Shepherd',
#    'popularity': 0.6,
#    'profile_path': None,
#    'credit_id': '6515a317ea84c700ca0649da',
#    'department': 'Sound',
#    'job': 'Sound Recordist'},
#   {'adult': False,
#    'gender': 0,
#    'id': 2064520,
#    'known_for_department': 'Lighting',
#    'name': 'Paul Booth',
#    'original_name': 'Paul Booth',
#    'popularity': 0.627,
#    'profile_path': None,
#    'credit_id': '6515a2380499f200fe98c85a',
#    'department': 'Lighting',
#    'job': 'Gaffer'},
#   {'adult': False,
#    'gender': 0,
#    'id': 2096085,
#    'known_for_department': 'Costume & Make-Up',
#    'name': 'Cassie Hanlon',
#    'original_name': 'Cassie Hanlon',
#    'popularity': 1.4,
#    'profile_path': None,
#    'credit_id': '6515a3589b861600ff682213',
#    'department': 'Costume & Make-Up',
#    'job': 'Key Hair Stylist'},
#   {'adult': False,
#    'gender': 0,
#    'id': 2096085,
#    'known_for_department': 'Costume & Make-Up',
#    'name': 'Cassie Hanlon',
#    'original_name': 'Cassie Hanlon',
#    'popularity': 1.4,
#    'profile_path': None,
#    'credit_id': '6515a349c50ad2014dcc3d86',
#    'department': 'Costume & Make-Up',
#    'job': 'Key Makeup Artist'},
#   {'adult': False,
#    'gender': 0,
#    'id': 2110806,
#    'known_for_department': 'Costume & Make-Up',
#    'name': 'Adam Dalli',
#    'original_name': 'Adam Dalli',
#    'popularity': 0.694,
#    'profile_path': None,
#    'credit_id': '6515a3b693bd690138fc5b77',
#    'department': 'Costume & Make-Up',
#    'job': 'Costume Assistant'},
#   {'adult': False,
#    'gender': 2,
#    'id': 2298125,
#    'known_for_department': 'Directing',
#    'name': 'Stuart Freeman',
#    'original_name': 'Stuart Freeman',
#    'popularity': 0.6,
#    'profile_path': None,
#    'credit_id': '65159f61cadb6b02bdec4c88',
#    'department': 'Directing',
#    'job': 'First Assistant Director'},
#   {'adult': False,
#    'gender': 1,
#    'id': 2517476,
#    'known_for_department': 'Production',
#    'name': 'Sue Seeary',
#    'original_name': 'Sue Seeary',
#    'popularity': 0.6,
#    'profile_path': None,
#    'credit_id': '6515a58a93bd6900fe478bc7',
#    'department': 'Crew',
#    'job': 'Post Production Supervisor'},
#   {'adult': False,
#    'gender': 1,
#    'id': 2517476,
#    'known_for_department': 'Production',
#    'name': 'Sue Seeary',
#    'original_name': 'Sue Seeary',
#    'popularity': 0.6,
#    'profile_path': None,
#    'credit_id': '65159f3f9b861600acae386e',
#    'department': 'Production',
#    'job': 'Associate Producer'},
#   {'adult': False,
#    'gender': 1,
#    'id': 2517476,
#    'known_for_department': 'Production',
#    'name': 'Sue Seeary',
#    'original_name': 'Sue Seeary',
#    'popularity': 0.6,
#    'profile_path': None,
#    'credit_id': '65159f4acadb6b02bdec4c7f',
#    'department': 'Production',
#    'job': 'Production Secretary'},
#   {'adult': False,
#    'gender': 0,
#    'id': 2683553,
#    'known_for_department': 'Production',
#    'name': 'Esther Rodewald',
#    'original_name': 'Esther Rodewald',
#    'popularity': 0.6,
#    'profile_path': None,
#    'credit_id': '65159fd093bd6900acc5aa28',
#    'department': 'Production',
#    'job': 'Production Coordinator'},
#   {'adult': False,
#    'gender': 0,
#    'id': 2930156,
#    'known_for_department': 'Camera',
#    'name': 'Adrien Seffrin',
#    'original_name': 'Adrien Seffrin',
#    'popularity': 0.828,
#    'profile_path': None,
#    'credit_id': '626f3fa968ff70009eb71d1b',
#    'department': 'Camera',
#    'job': 'Focus Puller'},
#   {'adult': False,
#    'gender': 0,
#    'id': 3029548,
#    'known_for_department': 'Camera',
#    'name': 'Pat Nash',
#    'original_name': 'Pat Nash',
#    'popularity': 0.833,
#    'profile_path': None,
#    'credit_id': '626f3f6cd55e4d009f7e4689',
#    'department': 'Camera',
#    'job': 'Key Grip'},
#   {'adult': False,
#    'gender': 0,
#    'id': 3144353,
#    'known_for_department': 'Production',
#    'name': 'Rick Kornaat',
#    'original_name': 'Rick Kornaat',
#    'popularity': 0.6,
#    'profile_path': None,
#    'credit_id': '6515a3dc1db65d00e31c4526',
#    'department': 'Production',
#    'job': 'Location Manager'},
#   {'adult': False,
#    'gender': 0,
#    'id': 3144353,
#    'known_for_department': 'Production',
#    'name': 'Rick Kornaat',
#    'original_name': 'Rick Kornaat',
#    'popularity': 0.6,
#    'profile_path': None,
#    'credit_id': '6515a3cf1db65d0100ac94f7',
#    'department': 'Production',
#    'job': 'Unit Manager'},
#   {'adult': False,
#    'gender': 0,
#    'id': 3189514,
#    'known_for_department': 'Directing',
#    'name': 'Maria Phillips',
#    'original_name': 'Maria Phillips',
#    'popularity': 0.6,
#    'profile_path': None,
#    'credit_id': '6515a02d1db65d011d1ee195',
#    'department': 'Directing',
#    'job': 'Second Assistant Director'},
#   {'adult': False,
#    'gender': 0,
#    'id': 3506408,
#    'known_for_department': 'Acting',
#    'name': 'Jenny Lee-Robinson',
#    'original_name': 'Jenny Lee-Robinson',
#    'popularity': 0.6,
#    'profile_path': None,
#    'credit_id': '6515a519cadb6b02c1d0a0aa',
#    'department': 'Crew',
#    'job': 'Studio Teacher'},
#   {'adult': False,
#    'gender': 0,
#    'id': 3514173,
#    'known_for_department': 'Art',
#    'name': 'Yann Vignes',
#    'original_name': 'Yann Vignes',
#    'popularity': 0.6,
#    'profile_path': None,
#    'credit_id': '6515a4041db65d011d1ee2c0',
#    'department': 'Art',
#    'job': 'Art Department Assistant'},
#   {'adult': False,
#    'gender': 0,
#    'id': 3518887,
#    'known_for_department': 'Camera',
#    'name': 'Elise Lockwood',
#    'original_name': 'Elise Lockwood',
#    'popularity': 0.772,
#    'profile_path': None,
#    'credit_id': '626f3f2dd1332400668215f3',
#    'department': 'Camera',
#    'job': 'Still Photographer'},
#   {'adult': False,
#    'gender': 0,
#    'id': 3532758,
#    'known_for_department': 'Camera',
#    'name': 'Anna Wareham',
#    'original_name': 'Anna Wareham',
#    'popularity': 0.6,
#    'profile_path': None,
#    'credit_id': '626f3fd1d133240066821a8e',
#    'department': 'Camera',
#    'job': 'Clapper Loader'},
#   {'adult': False,
#    'gender': 0,
#    'id': 4295715,
#    'known_for_department': 'Production',
#    'name': 'John May',
#    'original_name': 'John May',
#    'popularity': 0.6,
#    'profile_path': None,
#    'credit_id': '65159f9ecadb6b02c051df0c',
#    'department': 'Production',
#    'job': 'Production Accountant'},
#   {'adult': False,
#    'gender': 0,
#    'id': 4295722,
#    'known_for_department': 'Directing',
#    'name': 'Jamie Platt',
#    'original_name': 'Jamie Platt',
#    'popularity': 0.6,
#    'profile_path': None,
#    'credit_id': '6515a0560499f200fe98c7c4',
#    'department': 'Directing',
#    'job': 'Third Assistant Director'},
#   {'adult': False,
#    'gender': 0,
#    'id': 4295733,
#    'known_for_department': 'Lighting',
#    'name': 'Matt Inglis',
#    'original_name': 'Matt Inglis',
#    'popularity': 0.6,
#    'profile_path': None,
#    'credit_id': '6515a294a199a600fe74d939',
#    'department': 'Lighting',
#    'job': 'Best Boy Electric'},
#   {'adult': False,
#    'gender': 0,
#    'id': 4295756,
#    'known_for_department': 'Crew',
#    'name': 'Mark White',
#    'original_name': 'Mark White',
#    'popularity': 0.6,
#    'profile_path': None,
#    'credit_id': '6515a4321db65d0100ac951e',
#    'department': 'Crew',
#    'job': 'Choreographer'},
#   {'adult': False,
#    'gender': 0,
#    'id': 4295760,
#    'known_for_department': 'Crew',
#    'name': 'Catherine Lavelle',
#    'original_name': 'Catherine Lavelle',
#    'popularity': 0.6,
#    'profile_path': None,
#    'credit_id': '6515a4e9ea84c700ca064aa3',
#    'department': 'Crew',
#    'job': 'Unit Publicist'},
#   {'adult': False,
#    'gender': 0,
#    'id': 4295763,
#    'known_for_department': 'Production',
#    'name': 'Bobbie Pick-up',
#    'original_name': 'Bobbie Pick-up',
#    'popularity': 0.6,
#    'profile_path': None,
#    'credit_id': '6515a552ea84c7014efa5728',
#    'department': 'Production',
#    'job': 'Local Casting'},
#   {'adult': False,
#    'gender': 0,
#    'id': 4295769,
#    'known_for_department': 'Editing',
#    'name': 'Andrew Yuncken',
#    'original_name': 'Andrew Yuncken',
#    'popularity': 0.6,
#    'profile_path': None,
#    'credit_id': '6515a5a0cadb6b02bdec4ea4',
#    'department': 'Editing',
#    'job': 'Assistant Editor'},
#   {'adult': False,
#    'gender': 0,
#    'id': 4295784,
#    'known_for_department': 'Sound',
#    'name': 'Steve Erskine',
#    'original_name': 'Steve Erskine',
#    'popularity': 0.6,
#    'profile_path': None,
#    'credit_id': '6515a6519b861600e24ec071',
#    'department': 'Sound',
#    'job': 'Sound Effects Editor'},
#   {'adult': False,
#    'gender': 0,
#    'id': 4295787,
#    'known_for_department': 'Sound',
#    'name': 'Tim Colvin',
#    'original_name': 'Tim Colvin',
#    'popularity': 0.6,
#    'profile_path': None,
#    'credit_id': '6515a676ea84c700ca064b3d',
#    'department': 'Sound',
#    'job': 'Sound Effects'}]}

# %%
# Moana request
# Save a movie title to search for as a variable
movie_title = "Moana"

# Concatenate request_url, title, and api_key. Store as new variable
request_url = f"https://api.themoviedb.org/3/search/movie?api_key={api_key}&query={movie_title}"


# Execute get request
response = requests.get(request_url)


# Get movie ID
movie_data = response.json()
movie_id = movie_data['results'][0]['id']


# Call get_credits function
get_movie_credits(movie_id, api_key)
# Out:
# {'id': 1108427,
#  'cast': [{'adult': False,
#    'gender': 2,
#    'id': 18918,
#    'known_for_department': 'Acting',
#    'name': 'Dwayne Johnson',
#    'original_name': 'Dwayne Johnson',
#    'popularity': 35.666,
#    'profile_path': '/fJMovbkSh9QkPOy0x8Ekdm4fZQS.jpg',
#    'cast_id': 2,
#    'character': 'Maui',
#    'credit_id': '642b4306bf31f200b4bf829d',
#    'order': 0}],
#  'crew': [{'adult': False,
#    'gender': 2,
#    'id': 9543,
#    'known_for_department': 'Production',
#    'name': 'Beau Flynn',
#    'original_name': 'Beau Flynn',
#    'popularity': 1.805,
#    'profile_path': None,
#    'credit_id': '642b46ddc0a30800b43bd717',
#    'department': 'Production',
#    'job': 'Producer'},
#   {'adult': False,
#    'gender': 2,
#    'id': 18918,
#    'known_for_department': 'Acting',
#    'name': 'Dwayne Johnson',
#    'original_name': 'Dwayne Johnson',
#    'popularity': 35.666,
#    'profile_path': '/fJMovbkSh9QkPOy0x8Ekdm4fZQS.jpg',
#    'credit_id': '6434776a9b86160114cb2143',
#    'department': 'Production',
#    'job': 'Producer'},
#   {'adult': False,
#    'gender': 1,
#    'id': 1039217,
#    'known_for_department': 'Production',
#    'name': 'Dany Garcia',
#    'original_name': 'Dany Garcia',
#    'popularity': 4.769,
#    'profile_path': '/tagn66w0Y17fq7yZz5epMa7JF5M.jpg',
#    'credit_id': '642b47288de0ae00f4c14fcb',
#    'department': 'Production',
#    'job': 'Producer'},
#   {'adult': False,
#    'gender': 2,
#    'id': 1318201,
#    'known_for_department': 'Writing',
#    'name': 'Jared Bush',
#    'original_name': 'Jared Bush',
#    'popularity': 4.709,
#    'profile_path': '/2gIwj1cnqZIKWaFg0ihmZnuZypR.jpg',
#    'credit_id': '642b46f301b1ca0113ccd188',
#    'department': 'Production',
#    'job': 'Executive Producer'},
#   {'adult': False,
#    'gender': 2,
#    'id': 1318201,
#    'known_for_department': 'Writing',
#    'name': 'Jared Bush',
#    'original_name': 'Jared Bush',
#    'popularity': 4.709,
#    'profile_path': '/2gIwj1cnqZIKWaFg0ihmZnuZypR.jpg',
#    'credit_id': '6477b731e323f300e522d712',
#    'department': 'Writing',
#    'job': 'Writer'},
#   {'adult': False,
#    'gender': 2,
#    'id': 1466097,
#    'known_for_department': 'Production',
#    'name': 'Hiram Garcia',
#    'original_name': 'Hiram Garcia',
#    'popularity': 1.225,
#    'profile_path': '/y0SbPe6zqfPnpEWNKo7EP1bHQjK.jpg',
#    'credit_id': '642b470d01b1ca0113ccd192',
#    'department': 'Production',
#    'job': 'Producer'},
#   {'adult': False,
#    'gender': 2,
#    'id': 1485823,
#    'known_for_department': 'Production',
#    'name': 'Thomas Kail',
#    'original_name': 'Thomas Kail',
#    'popularity': 6.986,
#    'profile_path': '/fe568wCZjaM7ZmSMcraYe3XN3tt.jpg',
#    'credit_id': '6477b716076ce801079b2619',
#    'department': 'Directing',
#    'job': 'Director'},
#   {'adult': False,
#    'gender': 0,
#    'id': 1513971,
#    'known_for_department': 'Writing',
#    'name': 'Dana Ledoux Miller',
#    'original_name': 'Dana Ledoux Miller',
#    'popularity': 1.842,
#    'profile_path': None,
#    'credit_id': '6434779f22af3e00f491e7be',
#    'department': 'Production',
#    'job': 'Executive Producer'},
#   {'adult': False,
#    'gender': 0,
#    'id': 1513971,
#    'known_for_department': 'Writing',
#    'name': 'Dana Ledoux Miller',
#    'original_name': 'Dana Ledoux Miller',
#    'popularity': 1.842,
#    'profile_path': None,
#    'credit_id': '6477b73acf4b8b01031ca46e',
#    'department': 'Writing',
#    'job': 'Writer'},
#   {'adult': False,
#    'gender': 1,
#    'id': 1564846,
#    'known_for_department': 'Acting',
#    'name': "Auli'i Cravalho",
#    'original_name': "Auli'i Cravalho",
#    'popularity': 16.411,
#    'profile_path': '/aLYuYXqjESo8IWu2nfQjauGrPUT.jpg',
#    'credit_id': '642b4434ac8e6b0111c70185',
#    'department': 'Production',
#    'job': 'Executive Producer'},
#   {'adult': False,
#    'gender': 0,
#    'id': 2026870,
#    'known_for_department': 'Production',
#    'name': 'Scott Sheldon',
#    'original_name': 'Scott Sheldon',
#    'popularity': 0.988,
#    'profile_path': None,
#    'credit_id': '64347791391b9c11e1494713',
#    'department': 'Production',
#    'job': 'Executive Producer'}]}
